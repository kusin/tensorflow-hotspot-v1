# %% [markdown]
# ## How to Grid Search Hyperparameters for Deep Learning Models in Python with Keras

# %% [markdown]
# - https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %%
# Use scikit-learn to grid search the activation function
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier

# %%
# Function to create model, required for KerasClassifier
def create_model(activation='relu'):
    # create model
    model = Sequential()
    model.add(Dense(12, input_shape=(8,), kernel_initializer='uniform', activation=activation))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # return values
    return model

# %%
# fix random seed for reproducibility
tf.random.set_seed(seed = 7)

# %%
# load dataset
dataset = np.loadtxt("dataset/diabetes.csv", delimiter=",")

# %%
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# show to dataset
pd.concat([
    pd.DataFrame(X, columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']),
    pd.DataFrame(Y, columns=['Y'])
], axis=1)
# Out:
#        x1     x2    x3    x4     x5    x6     x7    x8    Y
# 0     6.0  148.0  72.0  35.0    0.0  33.6  0.627  50.0  1.0
# 1     1.0   85.0  66.0  29.0    0.0  26.6  0.351  31.0  0.0
# 2     8.0  183.0  64.0   0.0    0.0  23.3  0.672  32.0  1.0
# 3     1.0   89.0  66.0  23.0   94.0  28.1  0.167  21.0  0.0
# 4     0.0  137.0  40.0  35.0  168.0  43.1  2.288  33.0  1.0
# ..    ...    ...   ...   ...    ...   ...    ...   ...  ...
# 763  10.0  101.0  76.0  48.0  180.0  32.9  0.171  63.0  0.0
# 764   2.0  122.0  70.0  27.0    0.0  36.8  0.340  27.0  0.0
# 765   5.0  121.0  72.0  23.0  112.0  26.2  0.245  30.0  0.0
# 766   1.0  126.0  60.0   0.0    0.0  30.1  0.349  47.0  1.0
# 767   1.0   93.0  70.0  31.0    0.0  30.4  0.315  23.0  0.0
#
# [768 rows x 9 columns]

# %%
# create model
model = KerasClassifier(model=create_model, epochs=100, batch_size=10, verbose=1)

# %%
model
# Out:
# KerasClassifier(
# 	model=<function create_model at 0x0000028F93E073A0>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=10
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=100
# 	class_weight=None
# )

# %%
# define the grid search parameters
activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']

# %%
param_grid = dict(model__activation=activation)

# %%
param_grid
# Out:
# {'model__activation': ['softmax',
#   'softplus',
#   'softsign',
#   'relu',
#   'tanh',
#   'sigmoid',
#   'hard_sigmoid',
#   'linear']}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
grid_result = grid.fit(X, Y)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 2ms/step - loss: 0.6662 - accuracy: 0.6510
# Epoch 2/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6536
# Epoch 3/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6398 - accuracy: 0.6523
# Epoch 4/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6341 - accuracy: 0.6602
# Epoch 5/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6244 - accuracy: 0.6667
# Epoch 6/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6158 - accuracy: 0.6732
# Epoch 7/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6062 - accuracy: 0.6810
# Epoch 8/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6057 - accuracy: 0.6862
# Epoch 9/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.6836
# Epoch 10/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5932 - accuracy: 0.6966
# Epoch 11/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5911 - accuracy: 0.6979
# Epoch 12/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.7031
# Epoch 13/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5928 - accuracy: 0.6914
# Epoch 14/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5855 - accuracy: 0.6875
# Epoch 15/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.6927
# Epoch 16/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5825 - accuracy: 0.6992
# Epoch 17/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5815 - accuracy: 0.6953
# Epoch 18/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5937 - accuracy: 0.7070
# Epoch 19/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5899 - accuracy: 0.6888
# Epoch 20/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.6992
# Epoch 21/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.5767 - accuracy: 0.7044
# Epoch 22/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5799 - accuracy: 0.6979
# Epoch 23/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7109
# Epoch 24/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.7018
# Epoch 25/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5827 - accuracy: 0.7031
# Epoch 26/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.7070
# Epoch 27/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.7018
# Epoch 28/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.7135
# Epoch 29/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5676 - accuracy: 0.7096
# Epoch 30/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5704 - accuracy: 0.7135
# Epoch 31/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.7083
# Epoch 32/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.7070
# Epoch 33/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5649 - accuracy: 0.7044
# Epoch 34/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5610 - accuracy: 0.7044
# Epoch 35/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5615 - accuracy: 0.7174
# Epoch 36/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5645 - accuracy: 0.7083
# Epoch 37/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5606 - accuracy: 0.7031
# Epoch 38/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5570 - accuracy: 0.7227
# Epoch 39/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5629 - accuracy: 0.7174
# Epoch 40/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.7109
# Epoch 41/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5616 - accuracy: 0.7109
# Epoch 42/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5620 - accuracy: 0.7083
# Epoch 43/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5560 - accuracy: 0.7083
# Epoch 44/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5529 - accuracy: 0.7188
# Epoch 45/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5608 - accuracy: 0.7214
# Epoch 46/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5584 - accuracy: 0.7188
# Epoch 47/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.7292
# Epoch 48/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5475 - accuracy: 0.7370
# Epoch 49/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5614 - accuracy: 0.7135
# Epoch 50/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5515 - accuracy: 0.7266
# Epoch 51/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.7279
# Epoch 52/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5415 - accuracy: 0.7383
# Epoch 53/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5515 - accuracy: 0.7240
# Epoch 54/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.7318
# Epoch 55/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.7305
# Epoch 56/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5478 - accuracy: 0.7240
# Epoch 57/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5668 - accuracy: 0.7240
# Epoch 58/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5502 - accuracy: 0.7174
# Epoch 59/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5480 - accuracy: 0.7292
# Epoch 60/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7383
# Epoch 61/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5424 - accuracy: 0.7474
# Epoch 62/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5395 - accuracy: 0.7344
# Epoch 63/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5446 - accuracy: 0.7305
# Epoch 64/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5461 - accuracy: 0.7331
# Epoch 65/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.7227
# Epoch 66/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5506 - accuracy: 0.7240
# Epoch 67/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.7370
# Epoch 68/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5395 - accuracy: 0.7318
# Epoch 69/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7279
# Epoch 70/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.7331
# Epoch 71/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5329 - accuracy: 0.7357
# Epoch 72/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5382 - accuracy: 0.7331
# Epoch 73/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5346 - accuracy: 0.7448
# Epoch 74/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.7344
# Epoch 75/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7383
# Epoch 76/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5449 - accuracy: 0.7331
# Epoch 77/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5333 - accuracy: 0.7344
# Epoch 78/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5332 - accuracy: 0.7474
# Epoch 79/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5328 - accuracy: 0.7474
# Epoch 80/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.7331
# Epoch 81/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5308 - accuracy: 0.7435
# Epoch 82/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5298 - accuracy: 0.7409
# Epoch 83/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5296 - accuracy: 0.7331
# Epoch 84/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5291 - accuracy: 0.7409
# Epoch 85/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.7396
# Epoch 86/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5251 - accuracy: 0.7461
# Epoch 87/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5218 - accuracy: 0.7448
# Epoch 88/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.7188
# Epoch 89/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.7422
# Epoch 90/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5230 - accuracy: 0.7448
# Epoch 91/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5287 - accuracy: 0.7409
# Epoch 92/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5246 - accuracy: 0.7344
# Epoch 93/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5207 - accuracy: 0.7487
# Epoch 94/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5154 - accuracy: 0.7526
# Epoch 95/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5190 - accuracy: 0.7474
# Epoch 96/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7435
# Epoch 97/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5183 - accuracy: 0.7448
# Epoch 98/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5193 - accuracy: 0.7448
# Epoch 99/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5180 - accuracy: 0.7500
# Epoch 100/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5281 - accuracy: 0.7461

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.721354 using {'model__activation': 'relu'}

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 0.638021 (0.017566) with: {'model__activation': 'softmax'}
# 0.704427 (0.036690) with: {'model__activation': 'softplus'}
# 0.661458 (0.012890) with: {'model__activation': 'softsign'}
# 0.721354 (0.028764) with: {'model__activation': 'relu'}
# 0.675781 (0.006379) with: {'model__activation': 'tanh'}
# 0.688802 (0.031948) with: {'model__activation': 'sigmoid'}
# 0.707031 (0.031412) with: {'model__activation': 'hard_sigmoid'}
# 0.704427 (0.012890) with: {'model__activation': 'linear'}
