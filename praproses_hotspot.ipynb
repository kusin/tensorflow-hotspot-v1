# %% [markdown]
# ## Pra Proses Data Hotspot Sensor MODIS

# %%
# => load file lain
from ipynb.fs.full.class_akuisisi_data import *
from ipynb.fs.full.class_praproses_data import *
from ipynb.fs.full.class_visualisasi_data import *

# %% [markdown]
# ### Membaca dataset hotspot MODIS

# %%
# => proses membaca dataset
# 2001 - 2020
df_hotspot_modis = data_hotspot("modis_indonesia_2020_2020.csv")

# %%
df_hotspot_modis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413238 entries, 0 to 1413237
# Data columns (total 15 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   latitude    1413238 non-null  float64
#  1   longitude   1413238 non-null  float64
#  2   brightness  1413238 non-null  float64
#  3   scan        1413238 non-null  float64
#  4   track       1413238 non-null  float64
#  5   acq_date    1413238 non-null  datetime64[ns]
#  6   acq_time    1413238 non-null  int64
#  7   satellite   1413238 non-null  object
#  8   instrument  1413238 non-null  object
#  9   confidence  1413238 non-null  int64
#  10  version     1413238 non-null  float64
#  11  bright_t31  1413238 non-null  float64
#  12  frp         1413238 non-null  float64
#  13  daynight    1413238 non-null  object
#  14  type        1413238 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(3)
# memory usage: 172.5+ MB

# %%
df_hotspot_modis
# Out:
#          latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0         -8.4825   121.2763       311.5   4.2    1.9 2001-01-31       311
# 1         -2.5743   121.3820       311.3   1.0    1.0 2001-02-01      1434
# 2         -2.5756   121.3730       315.5   1.0    1.0 2001-02-01      1434
# 3          1.4389   100.0967       310.6   1.9    1.3 2001-02-03       340
# 4         -0.1928    99.8484       316.4   1.9    1.3 2001-02-04       423
# ...           ...        ...         ...   ...    ...        ...       ...
# 1413232   -2.9151   129.2944       314.7   1.1    1.1 2020-12-31       451
# 1413233   -3.3010   128.9608       316.6   1.2    1.1 2020-12-31       451
# 1413234   -2.5768   121.3746       347.1   1.2    1.1 2020-12-31      1416
# 1413235   -2.5754   121.3848       313.9   1.2    1.1 2020-12-31      1416
# 1413237   -1.4573   127.4369       316.1   1.1    1.1 2020-12-31      1713
#
#         satellite instrument  confidence  version  bright_t31   frp daynight  \
# 0           Terra      MODIS           0     6.03       290.6  47.0        D
# 1           Terra      MODIS          75     6.03       274.9  12.6        N
# 2           Terra      MODIS          88     6.03       271.7  16.1        N
# 3           Terra      MODIS          39     6.03       276.6  16.6        D
# 4           Terra      MODIS          35     6.03       296.0  18.1        D
# ...           ...        ...         ...      ...         ...   ...      ...
# 1413232      Aqua      MODIS          54     6.03       299.5   9.6        D
# 1413233      Aqua      MODIS          32     6.03       299.0   9.2        D
# 1413234     Terra      MODIS         100     6.03       281.9  73.0        N
# 1413235     Terra      MODIS          84     6.03       281.1  17.3        N
# 1413237      Aqua      MODIS          90     6.03       292.1  15.4        N
#
#          type
# 0           0
# 1           2
# 2           2
# 3           0
# 4           0
# ...       ...
# 1413232     2
# 1413233     0
# 1413234     2
# 1413235     2
# 1413237     2
#
# [1413238 rows x 15 columns]

# %% [markdown]
# ### Aggregasi data hotspot MODIS Indonesia

# %% [markdown]
# - Data harian

# %%
df_hotspot_modis_indo_harian = hotspot_harian(df_hotspot_modis)
df_hotspot_modis_indo_harian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7196 entries, 2001-01-31 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  7196 non-null   int64
# dtypes: int64(1)
# memory usage: 112.4 KB

# %%
# reset index
df_hotspot_modis_indo_harian = df_hotspot_modis_indo_harian.reset_index()

# %%
df_hotspot_modis_indo_harian
# Out:
#        acq_date  hotspot
# 0    2001-01-31        1
# 1    2001-02-01        2
# 2    2001-02-03        1
# 3    2001-02-04        2
# 4    2001-02-06        2
# ...         ...      ...
# 7191 2020-12-27       25
# 7192 2020-12-28        5
# 7193 2020-12-29        1
# 7194 2020-12-30        6
# 7195 2020-12-31        8
#
# [7196 rows x 2 columns]

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_indo_harian["acq_date"],
                   df_hotspot_modis_indo_harian["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot harian", "Hotspot Indonesia tahun 2001 - 2020", "True")

# %% [markdown]
# - Data Bulanan

# %%
df_hotspot_modis_indo_bulanan = hotspot_bulanan(df_hotspot_modis)
df_hotspot_modis_indo_bulanan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  240 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8 KB

# %%
# reset index
df_hotspot_modis_indo_bulanan = df_hotspot_modis_indo_bulanan.reset_index()

# %%
df_hotspot_modis_indo_bulanan
# Out:
#       acq_date  hotspot
# 0   2001-01-31        1
# 1   2001-02-28      299
# 2   2001-03-31      784
# 3   2001-04-30      246
# 4   2001-05-31      549
# ..         ...      ...
# 235 2020-08-31     1918
# 236 2020-09-30     3048
# 237 2020-10-31     2392
# 238 2020-11-30     1445
# 239 2020-12-31      377
#
# [240 rows x 2 columns]

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_indo_bulanan["acq_date"],
                   df_hotspot_modis_indo_bulanan["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot bulanan", "Hotspot Indonesia tahun 2001 - 2020", "True")

# %% [markdown]
# ### Membaca data hotspot MODIS Sumatra Selatan

# %%
import pandas as pd;

# %%
# versi lama
# df_hotspot_modis_sumsel = data_hotspot("modis_sumsel_v1.csv")
# df_hotspot_modis_sumsel.info()

# versi baru
# load dataset csv
df_hotspot_modis_sumsel = pd.read_csv("dataset/modis_sumsel_harian.csv", engine="python")

# melakukan konversi data menjadi format tanggal pada kolom acq_date
df_hotspot_modis_sumsel["acq_date"] = pd.to_datetime(df_hotspot_modis_sumsel["acq_date"], format="%Y-%m-%d")

# seorting berdasarkan tanggal
df_hotspot_modis_sumsel = df_hotspot_modis_sumsel.sort_values(by=["acq_date"])

# %%
df_hotspot_modis_sumsel
# Out:
#         latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 127864   -2.8277   104.0809       313.9   1.9    1.3 2001-01-14       405
# 127863   -2.8225   104.0882       313.2   1.9    1.3 2001-01-14       405
# 127862   -2.8201   104.0716       307.4   1.9    1.3 2001-01-14       405
# 127865   -2.8246   104.0782       302.3   1.8    1.3 2001-02-10      1607
# 127866   -2.8216   104.0829       306.1   1.2    1.1 2001-02-23      1536
# ...          ...        ...         ...   ...    ...        ...       ...
# 127842   -2.5987   102.6988       313.5   1.0    1.0 2020-12-04       648
# 154995   -2.6521   103.7410       315.6   1.1    1.0 2020-12-04       648
# 154996   -2.1625   104.3411       311.7   1.0    1.0 2020-12-08       328
# 154997   -1.9285   104.2109       310.6   1.4    1.2 2020-12-08       624
# 27085    -3.7903   103.5361       318.0   1.7    1.3 2020-12-08       623
#
#        satellite instrument  confidence  version  bright_t31   frp daynight  \
# 127864     Terra      MODIS          68     6.03       290.8  19.4        D
# 127863     Terra      MODIS          68     6.03       290.7  17.7        D
# 127862     Terra      MODIS          41     6.03       288.7   7.6        D
# 127865     Terra      MODIS          48     6.03       279.1  11.8        N
# 127866     Terra      MODIS          67     6.03       290.8   7.3        N
# ...          ...        ...         ...      ...         ...   ...      ...
# 127842      Aqua      MODIS          52     6.03       298.4   4.2        D
# 154995      Aqua      MODIS          41     6.03       296.4  10.0        D
# 154996     Terra      MODIS          58     6.03       290.4   5.9        D
# 154997      Aqua      MODIS          33     6.03       291.5   6.7        D
# 27085       Aqua      MODIS          45     6.03       297.7  21.0        D
#
#         type
# 127864     2
# 127863     2
# 127862     2
# 127865     2
# 127866     2
# ...      ...
# 127842     0
# 154995     0
# 154996     0
# 154997     0
# 27085      2
#
# [155661 rows x 15 columns]

# %% [markdown]
# - aggregasi data harian

# %%
# load dataset
df_hotspot_modis_sumsel_harian = hotspot_harian(df_hotspot_modis_sumsel)
df_hotspot_modis_sumsel_harian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3453 entries, 2001-01-14 to 2020-12-08
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  3453 non-null   int64
# dtypes: int64(1)
# memory usage: 54.0 KB

# %%
# reset index
df_hotspot_modis_sumsel_harian = df_hotspot_modis_sumsel_harian.reset_index()

# %%
df_hotspot_modis_sumsel_harian
# Out:
#        acq_date  hotspot
# 0    2001-01-14        3
# 1    2001-02-10        1
# 2    2001-02-23        1
# 3    2001-02-25        2
# 4    2001-02-26        1
# ...         ...      ...
# 3448 2020-11-18        7
# 3449 2020-11-20        1
# 3450 2020-11-22        1
# 3451 2020-12-04        5
# 3452 2020-12-08        3
#
# [3453 rows x 2 columns]

# %%
df_hotspot_modis_sumsel_harian.describe()
# Out:
#            hotspot
# count  3453.000000
# mean     45.079930
# std     118.209763
# min       1.000000
# 25%       2.000000
# 50%       6.000000
# 75%      29.000000
# max    1874.000000

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_sumsel_harian["acq_date"],
                   df_hotspot_modis_sumsel_harian["hotspot"],
                   "", "", "Hotspot Sumsel", "", "True")

# %% [markdown]
# - aggregasi data bulanan

# %%
# load dataset
df_hotspot_modis_sumsel_bulanan = hotspot_bulanan(df_hotspot_modis_sumsel)
df_hotspot_modis_sumsel_bulanan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  240 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8 KB

# %%
# reset index
df_hotspot_modis_sumsel_bulanan = df_hotspot_modis_sumsel_bulanan.reset_index()

# %%
df_hotspot_modis_sumsel_bulanan
# Out:
#       acq_date  hotspot
# 0   2001-01-31        3
# 1   2001-02-28        5
# 2   2001-03-31       10
# 3   2001-04-30       20
# 4   2001-05-31       39
# ..         ...      ...
# 235 2020-08-31       65
# 236 2020-09-30       29
# 237 2020-10-31       40
# 238 2020-11-30       30
# 239 2020-12-31        8
#
# [240 rows x 2 columns]

# %%
df_hotspot_modis_sumsel_bulanan.describe()
# Out:
#             hotspot
# count    240.000000
# mean     648.587500
# std     1747.365812
# min        1.000000
# 25%       21.750000
# 50%       59.500000
# 75%      313.250000
# max    14416.000000

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_sumsel_bulanan["acq_date"],
                   df_hotspot_modis_sumsel_bulanan["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot bulanan", "Hotspot Provinsi Sumatra Selatan tahun 2001 - 2020", "True")

# %% [markdown]
# - export pandas to csv

# %%
df = df_hotspot_modis_sumsel_bulanan.to_csv("dataset/modis_sumsel_bulanan.csv", index=False)

# %%
pd.read_csv("dataset/modis_sumsel_bulanan.csv")
# Out:
#        acq_date  hotspot
# 0    2001-01-31        3
# 1    2001-02-28        5
# 2    2001-03-31       10
# 3    2001-04-30       20
# 4    2001-05-31       39
# ..          ...      ...
# 235  2020-08-31       65
# 236  2020-09-30       29
# 237  2020-10-31       40
# 238  2020-11-30       30
# 239  2020-12-31        8
#
# [240 rows x 2 columns]

# %% [markdown]
# ### Dekomposisi Musiman Riau

# %%
# from jcopml.time_series.decomposition import additive_decomposition
# from jcopml.time_series.decomposition import multiplicative_decomposition
# from jcopml.time_series.decomposition import stl_decomposition

# %%
# dekomposisi_riau = data_hotspot("modis_riau_bulanan.csv")
# dekomposisi_riau = dekomposisi_riau.set_index("acq_date")
# dekomposisi_riau = dekomposisi_riau.hotspot

# %%
# hasil = additive_decomposition(dekomposisi_riau, plot=True)

# %%
# hasil = multiplicative_decomposition(dekomposisi_riau, plot=True)

# %%
# hasil = stl_decomposition(dekomposisi_riau, plot=True)

# %% [markdown]
# ### Dekomposisi Musiman Sumsel

# %%
# dekomposisi_sumsel = data_hotspot("modis_sumsel_bulanan_v2.csv")
# dekomposisi_sumsel = dekomposisi_sumsel.set_index("acq_date")
# dekomposisi_sumsel = dekomposisi_sumsel.hotspot

# %%
# hasil = additive_decomposition(dekomposisi_sumsel, plot=True)

# %%
# hasil = multiplicative_decomposition(dekomposisi_sumsel, plot=True)

# %%
# hasil = stl_decomposition(dekomposisi_sumsel, plot=True)
