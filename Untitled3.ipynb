# %%
# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library data visualization
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka normalisasi data / membuat data latih dan data uji.
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
# fix random seed for reproducibility
np.random.seed(1234)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tanggal         240 non-null    datetime64[ns]
#  1   sst             240 non-null    float64
#  2   soi             240 non-null    float64
#  3   oni             240 non-null    float64
#  4   curah_hujan     240 non-null    float64
#  5   hotspot_sumsel  240 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.4 KB

# %%
dataset
# Out:
#        tanggal   sst  soi   oni  curah_hujan  hotspot_sumsel
# 0   2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 1   2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2   2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 3   2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 4   2001-05-31 -0.46 -0.5 -0.25   116.900002              39
# ..         ...   ...  ...   ...          ...             ...
# 235 2020-08-31 -0.52  1.1 -0.57    82.700005              65
# 236 2020-09-30 -0.64  0.9 -0.89   211.800003              29
# 237 2020-10-31 -1.13  0.5 -1.17   437.300018              40
# 238 2020-11-30 -1.23  0.7 -1.27   237.400009              30
# 239 2020-12-31 -0.99  1.8 -1.19   405.800018               8
#
# [240 rows x 6 columns]

# %% [markdown]
# ### visualisasi data

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], dataset["hotspot_sumsel"], color="tab:blue", label="Titik Panas", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], dataset["curah_hujan"], color="tab:green", label="Curah Hujan", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], dataset["sst"], color="tab:orange", label="SST Nina 3.4", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="upper right")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], dataset["soi"], color="tab:red", label="SOI Index", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="upper right")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Normalisasi data

# %%
# membaca dataset
df_norm = read_excel("dataset/dataset.xlsx")

# %%
# set index tanggal
df_norm = dataset.set_index("tanggal")

# %%
print(df_norm)
# Out:
#              sst  soi   oni  curah_hujan  hotspot_sumsel
# tanggal
# 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 2001-05-31 -0.46 -0.5 -0.25   116.900002              39
# ...          ...  ...   ...          ...             ...
# 2020-08-31 -0.52  1.1 -0.57    82.700005              65
# 2020-09-30 -0.64  0.9 -0.89   211.800003              29
# 2020-10-31 -1.13  0.5 -1.17   437.300018              40
# 2020-11-30 -1.23  0.7 -1.27   237.400009              30
# 2020-12-31 -0.99  1.8 -1.19   405.800018               8
#
# [240 rows x 5 columns]

# %%
# memanggil fungsi max min scaler
scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1))

# %%
# proses max min scaler
df_norm = scaler.fit_transform(df_norm)

# %%
df_norm = pd.DataFrame(df_norm, columns=['sst', 'soi', 'oni', 'curah_hujan', 'hotspot_sumsel'])

# %%
df_norm
# Out:
#           sst       soi       oni  curah_hujan  hotspot_sumsel
# 0   -0.614849  0.366667 -0.551402     0.549573       -0.999723
# 1   -0.522042  0.600000 -0.476636     0.082464       -0.999445
# 2   -0.433875  0.333333 -0.439252     0.329668       -0.998751
# 3   -0.522042  0.100000 -0.392523     0.493081       -0.997364
# 4   -0.475638 -0.133333 -0.350467    -0.594313       -0.994728
# ..        ...       ...       ...          ...             ...
# 235 -0.503480  0.400000 -0.500000    -0.723981       -0.991120
# 236 -0.559165  0.333333 -0.649533    -0.234502       -0.996115
# 237 -0.786543  0.200000 -0.780374     0.620474       -0.994589
# 238 -0.832947  0.266667 -0.827103    -0.137441       -0.995976
# 239 -0.721578  0.633333 -0.789720     0.501043       -0.999029
#
# [240 rows x 5 columns]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], df_norm["hotspot_sumsel"], color="tab:blue", label="Titik Panas", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="upper right")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], df_norm["curah_hujan"], color="tab:green", label="Curah Hujan", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], df_norm["sst"], color="tab:orange", label="SST Nina 3.4", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="upper right")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(dataset["tanggal"], df_norm["soi"], color="tab:red", label="SOI Index", linewidth=1.5)

# membuat label-label
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="upper right")
ax.grid(True)

# menampilkan plot
plt.show()
