# %% [markdown]
# ## Univariate LSTM-RNN Sumatera Selatan Percobaan 1

# %% [markdown]
# ### 1. Deklarasi Pustaka

# %%
# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library configuration date and time
import time
from datetime import datetime

# library data visualization
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib import pyplot
from matplotlib import pyplot as plt

# library analysis acf and pacf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# library algorithm lstm-rnn with keras
import tensorflow as tf
from tensorflow.keras import models
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# Early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# library evaluation model
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from epftoolbox.evaluation import sMAPE

# %% [markdown]
# ### 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
# fix random seed for reproducibility
np.random.seed(1234)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
# # set index tanggal
# dataset = dataset.set_index("tanggal")

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tanggal         240 non-null    datetime64[ns]
#  1   sst             240 non-null    float64
#  2   soi             240 non-null    float64
#  3   oni             240 non-null    float64
#  4   curah_hujan     240 non-null    float64
#  5   hotspot_sumsel  240 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.4 KB

# %%
dataset.describe()
# Out:
#               sst         soi         oni  curah_hujan  hotspot_sumsel
# count  240.000000  240.000000  240.000000   240.000000      240.000000
# mean     0.037917    0.167500    0.002708   232.780420      648.587500
# std      0.748704    0.909564    0.789896   121.096391     1747.365812
# min     -1.590000   -3.100000   -1.640000     9.900001        1.000000
# 25%     -0.480000   -0.400000   -0.505000   129.325006       21.750000
# 50%     -0.010000    0.100000   -0.050000   229.400002       59.500000
# 75%      0.500000    0.700000    0.472500   326.424995      313.250000
# max      2.720000    2.900000    2.640000   537.400024    14416.000000

# %%
print(dataset.head())
# Out:
#      tanggal   sst  soi   oni  curah_hujan  hotspot_sumsel
# 0 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 1 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 3 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 4 2001-05-31 -0.46 -0.5 -0.25   116.900002              39

# %% [markdown]
# ### 3. Exploration Data Analysis

# %% [markdown]
# - Data Visualization

# %%
# make frame
fig, ax = plt.subplots(figsize = (20,6))

# make time series plot
ax.plot(dataset["tanggal"], dataset["hotspot_sumsel"], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax.set_xlabel("Date", fontsize=12)
ax.set_ylabel("Sum of hostpot", fontsize=12)
ax.legend(loc='best')
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# - Analysis ACF and PACF

# %%
# make frame
fig, ax= plt.subplots(nrows=1, ncols=2, facecolor="#F0F0F0", figsize = (20,5))

# plot acf
plot_acf(dataset["hotspot_sumsel"], lags=24, ax=ax[0])
ax[0].grid(True)

# plot pacf
plot_pacf(dataset["hotspot_sumsel"],lags=24, ax=ax[1], method="yw")
ax[1].grid(True)

# show plot acf and pacf
plt.show()

# %% [markdown]
# ### 4. Praproses Data

# %% [markdown]
# - 1. feature selection (studi kasus sumatera selatan)

# %%
# memilih area studi
df_sumsel = dataset[["hotspot_sumsel"]]

# %%
# ensure all data is float
df_sumsel = df_sumsel.values
df_sumsel = df_sumsel.astype('float64');

# %%
# show a dataset
np.round(df_sumsel[:5],4)
# Out:
# array([[ 3.],
#        [ 5.],
#        [10.],
#        [20.],
#        [39.]])

# %%
# view a dimension dataset
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.set_xlabel("Tanggal", fontsize=12)
ax.set_ylabel("Jumlah Hostpot", fontsize=12)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - 2. Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1,1))
df_sumsel = scaler.fit_transform(df_sumsel)

# %%
np.round(df_sumsel[:5],6)
# Out:
# array([[-0.999723],
#        [-0.999445],
#        [-0.998751],
#        [-0.997364],
#        [-0.994728]])

# %%
# view a dimension dataset after normalize
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="data aktual", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.set_xlabel("Tanggal", fontsize=12)
ax.set_ylabel("Jumlah Hostpot", fontsize=12)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - 3. set data train and data test

# %%
# set data train
train_size = int(len(df_sumsel) * 0.8)

# %%
# set loc data train
train = df_sumsel[0:train_size,:]

# %%
# show data train
np.round(train[:5],4)
# Out:
# array([[-0.9997],
#        [-0.9994],
#        [-0.9988],
#        [-0.9974],
#        [-0.9947]])

# %%
# view dimension of data train
train.shape
# Out:
# (192, 1)

# %%
# set data test
test_size = len(df_sumsel) - train_size

# %%
# set loc data test
test = df_sumsel[train_size:len(df_sumsel),:]

# %%
# show data test
np.round(test[:5],4)
# Out:
# array([[-0.9985],
#        [-0.9997],
#        [-0.9975],
#        [-0.9974],
#        [-0.9945]])

# %%
# view dimension of data test
test.shape
# Out:
# (48, 1)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:train_size,0], train, color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[train_size:len(dataset),0], test, color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
# ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
# ax.set_xlabel("Years", fontsize=12)
# ax.set_ylabel("Sum of hotspot", fontsize=12)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 5. Supervised Learning

# %%
# function for supervised learning
def create_dataset(dataset, look_back=1):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(len(dataset)-look_back):
        
        # insert value X and Y 
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# - process supervised learning, with look back t-1 into X=t and Y=t+1

# %%
# set look back -1
look_back = 1

# %%
# set supervised learning for data train
trainX, trainY = create_dataset(train, look_back)

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (191, 1) (191,)

# %%
# set supervised learning for data test
testX, testY = create_dataset(test, look_back)

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (47, 1) (47,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX, columns=['x train'])
temp_trainY = pd.DataFrame(trainY, columns=['y train'])

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x train  191 non-null    float64
#  1   y train  191 non-null    float64
# dtypes: float64(2)
# memory usage: 3.1 KB

# %%
hasil_train.head()
# Out:
#     x train   y train
# 0 -0.999723 -0.999445
# 1 -0.999445 -0.998751
# 2 -0.998751 -0.997364
# 3 -0.997364 -0.994728
# 4 -0.994728 -0.999029

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX, columns=['x test'])
temp_testY = pd.DataFrame(testY, columns=['y test'])

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x test  47 non-null     float64
#  1   y test  47 non-null     float64
# dtypes: float64(2)
# memory usage: 880.0 bytes

# %%
hasil_test.head()
# Out:
#      x test    y test
# 0 -0.998474 -0.999723
# 1 -0.999723 -0.997503
# 2 -0.997503 -0.997364
# 3 -0.997364 -0.994450
# 4 -0.994450 -0.991537

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (191, 1, 1) (191,)

# %%
# reshape data test
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
print(testX.shape, testY.shape)
# Out:
# (47, 1, 1) (47,)

# %% [markdown]
# ### 6. Modeling LSTM-RNN

# %%
# Design network
model = Sequential()

# First LSTM layer with Dropout regularisation
model.add(
    LSTM(
        units=10,
        activation="selu",
        input_shape=(trainX.shape[1], 1)
    )
)
model.add(Dropout(0.25))

# The output layer
model.add(Dense(1))

# Compiling model the LSTM-RNN
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.MeanSquaredError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# %%
# fit network
history = model.fit(trainX, trainY, epochs=2000, batch_size=8,
                    validation_data=(testX, testY),
                    verbose=1, shuffle=False)
# Out:
# Epoch 1/2000
# 24/24 [==============================] - 2s 15ms/step - loss: 0.7290 - mean_absolute_error: 0.7290 - mean_squared_error: 0.5685 - root_mean_squared_error: 0.7540 - val_loss: 0.5704 - val_mean_absolute_error: 0.5704 - val_mean_squared_error: 0.3362 - val_root_mean_squared_error: 0.5798
# Epoch 2/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4023 - mean_absolute_error: 0.4023 - mean_squared_error: 0.1976 - root_mean_squared_error: 0.4445 - val_loss: 0.2558 - val_mean_absolute_error: 0.2558 - val_mean_squared_error: 0.0662 - val_root_mean_squared_error: 0.2574
# Epoch 3/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1931 - mean_absolute_error: 0.1931 - mean_squared_error: 0.0749 - root_mean_squared_error: 0.2736 - val_loss: 0.0856 - val_mean_absolute_error: 0.0856 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 4/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - mean_squared_error: 0.0633 - root_mean_squared_error: 0.2516 - val_loss: 0.0912 - val_mean_absolute_error: 0.0912 - val_mean_squared_error: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 5/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0892 - val_mean_absolute_error: 0.0892 - val_mean_squared_error: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 6/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1374 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0618 - root_mean_squared_error: 0.2486 - val_loss: 0.0859 - val_mean_absolute_error: 0.0859 - val_mean_squared_error: 0.0122 - val_root_mean_squared_error: 0.1102
# Epoch 7/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1371 - mean_absolute_error: 0.1371 - mean_squared_error: 0.0615 - root_mean_squared_error: 0.2479 - val_loss: 0.0859 - val_mean_absolute_error: 0.0859 - val_mean_squared_error: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 8/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1364 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0635 - root_mean_squared_error: 0.2520 - val_loss: 0.0749 - val_mean_absolute_error: 0.0749 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 9/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1292 - mean_absolute_error: 0.1292 - mean_squared_error: 0.0634 - root_mean_squared_error: 0.2517 - val_loss: 0.0741 - val_mean_absolute_error: 0.0741 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 10/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1246 - mean_absolute_error: 0.1246 - mean_squared_error: 0.0594 - root_mean_squared_error: 0.2438 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 11/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1243 - mean_absolute_error: 0.1243 - mean_squared_error: 0.0640 - root_mean_squared_error: 0.2529 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 12/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1206 - mean_absolute_error: 0.1206 - mean_squared_error: 0.0620 - root_mean_squared_error: 0.2489 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 13/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1258 - mean_absolute_error: 0.1258 - mean_squared_error: 0.0665 - root_mean_squared_error: 0.2579 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 14/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1253 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0635 - root_mean_squared_error: 0.2519 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 15/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1069
# Epoch 16/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1177 - mean_absolute_error: 0.1177 - mean_squared_error: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 17/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1116 - mean_absolute_error: 0.1116 - mean_squared_error: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 18/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1132 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0648 - root_mean_squared_error: 0.2546 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 19/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1076 - mean_absolute_error: 0.1076 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2539 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 20/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1106 - mean_absolute_error: 0.1106 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2570 - val_loss: 0.0401 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 21/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1059 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0652 - root_mean_squared_error: 0.2553 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 22/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1077 - mean_absolute_error: 0.1077 - mean_squared_error: 0.0638 - root_mean_squared_error: 0.2526 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 23/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1093 - mean_absolute_error: 0.1093 - mean_squared_error: 0.0678 - root_mean_squared_error: 0.2603 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 24/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1107 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2577 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 25/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1093 - mean_absolute_error: 0.1093 - mean_squared_error: 0.0656 - root_mean_squared_error: 0.2561 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 26/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1064 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0688 - root_mean_squared_error: 0.2623 - val_loss: 0.0447 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 27/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1043 - mean_absolute_error: 0.1043 - mean_squared_error: 0.0654 - root_mean_squared_error: 0.2557 - val_loss: 0.0369 - val_mean_absolute_error: 0.0369 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 28/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1032 - mean_absolute_error: 0.1032 - mean_squared_error: 0.0653 - root_mean_squared_error: 0.2555 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 29/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1041 - mean_absolute_error: 0.1041 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2581 - val_loss: 0.0364 - val_mean_absolute_error: 0.0364 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 30/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1029 - mean_absolute_error: 0.1029 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2601 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 31/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1040 - mean_absolute_error: 0.1040 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2568 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 32/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1019 - mean_absolute_error: 0.1019 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2606 - val_loss: 0.0473 - val_mean_absolute_error: 0.0473 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1070
# Epoch 33/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1023 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0657 - root_mean_squared_error: 0.2563 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 34/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0980 - mean_absolute_error: 0.0980 - mean_squared_error: 0.0667 - root_mean_squared_error: 0.2582 - val_loss: 0.0370 - val_mean_absolute_error: 0.0370 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 35/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1002 - mean_absolute_error: 0.1002 - mean_squared_error: 0.0653 - root_mean_squared_error: 0.2555 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 36/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1016 - mean_absolute_error: 0.1016 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.0373 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 37/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0989 - mean_absolute_error: 0.0989 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2605 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 38/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0991 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0359 - val_mean_absolute_error: 0.0359 - val_mean_squared_error: 0.0122 - val_root_mean_squared_error: 0.1102
# Epoch 39/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0979 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0668 - root_mean_squared_error: 0.2584 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 40/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0987 - mean_absolute_error: 0.0987 - mean_squared_error: 0.0663 - root_mean_squared_error: 0.2575 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 41/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0981 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0691 - root_mean_squared_error: 0.2629 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 42/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1001 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2618 - val_loss: 0.0401 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 43/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0963 - mean_absolute_error: 0.0963 - mean_squared_error: 0.0672 - root_mean_squared_error: 0.2593 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 44/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0966 - mean_absolute_error: 0.0966 - mean_squared_error: 0.0693 - root_mean_squared_error: 0.2633 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 45/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0994 - mean_absolute_error: 0.0994 - mean_squared_error: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.0382 - val_mean_absolute_error: 0.0382 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 46/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0968 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 47/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0680 - root_mean_squared_error: 0.2607 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 48/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0971 - mean_absolute_error: 0.0971 - mean_squared_error: 0.0682 - root_mean_squared_error: 0.2611 - val_loss: 0.0385 - val_mean_absolute_error: 0.0385 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 49/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0968 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0689 - root_mean_squared_error: 0.2626 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 50/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2570 - val_loss: 0.0350 - val_mean_absolute_error: 0.0350 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 51/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - mean_squared_error: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0385 - val_mean_absolute_error: 0.0385 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 52/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0963 - mean_absolute_error: 0.0963 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2581 - val_loss: 0.0399 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 53/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0946 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0647 - root_mean_squared_error: 0.2544 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 54/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1046
# Epoch 55/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0950 - mean_absolute_error: 0.0950 - mean_squared_error: 0.0663 - root_mean_squared_error: 0.2574 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 56/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - mean_squared_error: 0.0686 - root_mean_squared_error: 0.2620 - val_loss: 0.0350 - val_mean_absolute_error: 0.0350 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 57/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0944 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0658 - root_mean_squared_error: 0.2564 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 58/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 59/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2538 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 60/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0942 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0682 - root_mean_squared_error: 0.2612 - val_loss: 0.0397 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 61/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0962 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.0352 - val_mean_absolute_error: 0.0352 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 62/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0655 - root_mean_squared_error: 0.2559 - val_loss: 0.0332 - val_mean_absolute_error: 0.0332 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 63/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0934 - mean_absolute_error: 0.0934 - mean_squared_error: 0.0655 - root_mean_squared_error: 0.2559 - val_loss: 0.0348 - val_mean_absolute_error: 0.0348 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 64/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0668 - root_mean_squared_error: 0.2584 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 65/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0366 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 66/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0950 - mean_absolute_error: 0.0950 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0356 - val_mean_absolute_error: 0.0356 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 67/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0647 - root_mean_squared_error: 0.2544 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 68/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1056
# Epoch 69/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0364 - val_mean_absolute_error: 0.0364 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 70/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0646 - root_mean_squared_error: 0.2541 - val_loss: 0.0364 - val_mean_absolute_error: 0.0364 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 71/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2537 - val_loss: 0.0354 - val_mean_absolute_error: 0.0354 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 72/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0649 - root_mean_squared_error: 0.2547 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 73/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0352 - val_mean_absolute_error: 0.0352 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 74/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - mean_squared_error: 0.0700 - root_mean_squared_error: 0.2647 - val_loss: 0.0358 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 75/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0665 - root_mean_squared_error: 0.2579 - val_loss: 0.0361 - val_mean_absolute_error: 0.0361 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1032
# Epoch 76/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0656 - root_mean_squared_error: 0.2560 - val_loss: 0.0360 - val_mean_absolute_error: 0.0360 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1032
# Epoch 77/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2605 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 78/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.0326 - val_mean_absolute_error: 0.0326 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1056
# Epoch 79/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0655 - root_mean_squared_error: 0.2559 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 80/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2587 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 81/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0640 - root_mean_squared_error: 0.2529 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 82/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - mean_squared_error: 0.0658 - root_mean_squared_error: 0.2565 - val_loss: 0.0349 - val_mean_absolute_error: 0.0349 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 83/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2572 - val_loss: 0.0348 - val_mean_absolute_error: 0.0348 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1023
# Epoch 84/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2567 - val_loss: 0.0356 - val_mean_absolute_error: 0.0356 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 85/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0637 - root_mean_squared_error: 0.2525 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 86/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0651 - root_mean_squared_error: 0.2551 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 87/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0348 - val_mean_absolute_error: 0.0348 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 88/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0377 - val_mean_absolute_error: 0.0377 - val_mean_squared_error: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 89/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2568 - val_loss: 0.0354 - val_mean_absolute_error: 0.0354 - val_mean_squared_error: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 90/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0930 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0660 - root_mean_squared_error: 0.2568 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1032
# Epoch 91/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0657 - root_mean_squared_error: 0.2563 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 92/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0636 - root_mean_squared_error: 0.2522 - val_loss: 0.0317 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 93/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2568 - val_loss: 0.0328 - val_mean_absolute_error: 0.0328 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 94/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0342 - val_mean_absolute_error: 0.0342 - val_mean_squared_error: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 95/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0908 - mean_absolute_error: 0.0908 - mean_squared_error: 0.0620 - root_mean_squared_error: 0.2489 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 96/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0689 - root_mean_squared_error: 0.2625 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 97/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0643 - root_mean_squared_error: 0.2536 - val_loss: 0.0343 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 98/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0665 - root_mean_squared_error: 0.2578 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 99/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0635 - root_mean_squared_error: 0.2520 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 100/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0900 - mean_absolute_error: 0.0900 - mean_squared_error: 0.0626 - root_mean_squared_error: 0.2503 - val_loss: 0.0328 - val_mean_absolute_error: 0.0328 - val_mean_squared_error: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 101/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2538 - val_loss: 0.0354 - val_mean_absolute_error: 0.0354 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 102/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0649 - root_mean_squared_error: 0.2547 - val_loss: 0.0328 - val_mean_absolute_error: 0.0328 - val_mean_squared_error: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 103/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 104/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0627 - root_mean_squared_error: 0.2505 - val_loss: 0.0329 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 105/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0624 - root_mean_squared_error: 0.2499 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 106/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - mean_squared_error: 0.0602 - root_mean_squared_error: 0.2454 - val_loss: 0.0350 - val_mean_absolute_error: 0.0350 - val_mean_squared_error: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 107/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0595 - root_mean_squared_error: 0.2440 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 108/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0640 - root_mean_squared_error: 0.2530 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 109/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0609 - root_mean_squared_error: 0.2468 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 110/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0616 - root_mean_squared_error: 0.2481 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 111/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0590 - root_mean_squared_error: 0.2428 - val_loss: 0.0384 - val_mean_absolute_error: 0.0384 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 112/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0913 - mean_absolute_error: 0.0913 - mean_squared_error: 0.0618 - root_mean_squared_error: 0.2487 - val_loss: 0.0318 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 113/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0629 - root_mean_squared_error: 0.2509 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 114/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0593 - root_mean_squared_error: 0.2434 - val_loss: 0.0312 - val_mean_absolute_error: 0.0312 - val_mean_squared_error: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 115/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2571 - val_loss: 0.0343 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 116/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0912 - mean_absolute_error: 0.0912 - mean_squared_error: 0.0606 - root_mean_squared_error: 0.2462 - val_loss: 0.0313 - val_mean_absolute_error: 0.0313 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 117/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0640 - root_mean_squared_error: 0.2530 - val_loss: 0.0311 - val_mean_absolute_error: 0.0311 - val_mean_squared_error: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 118/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0907 - mean_absolute_error: 0.0907 - mean_squared_error: 0.0605 - root_mean_squared_error: 0.2460 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 119/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - mean_squared_error: 0.0637 - root_mean_squared_error: 0.2523 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 120/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0622 - root_mean_squared_error: 0.2494 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 121/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0617 - root_mean_squared_error: 0.2483 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 122/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0888 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0587 - root_mean_squared_error: 0.2422 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 123/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0901 - mean_absolute_error: 0.0901 - mean_squared_error: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 124/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0905 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0617 - root_mean_squared_error: 0.2484 - val_loss: 0.0345 - val_mean_absolute_error: 0.0345 - val_mean_squared_error: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 125/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0888 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0601 - root_mean_squared_error: 0.2451 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307 - val_mean_squared_error: 0.0098 - val_root_mean_squared_error: 0.0991
# Epoch 126/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0601 - root_mean_squared_error: 0.2451 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 127/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0598 - root_mean_squared_error: 0.2446 - val_loss: 0.0312 - val_mean_absolute_error: 0.0312 - val_mean_squared_error: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 128/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - mean_squared_error: 0.0575 - root_mean_squared_error: 0.2399 - val_loss: 0.0342 - val_mean_absolute_error: 0.0342 - val_mean_squared_error: 0.0093 - val_root_mean_squared_error: 0.0967
# Epoch 129/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0903 - mean_absolute_error: 0.0903 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2487 - val_loss: 0.0321 - val_mean_absolute_error: 0.0321 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 130/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0601 - root_mean_squared_error: 0.2452 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0093 - val_root_mean_squared_error: 0.0963
# Epoch 131/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0590 - root_mean_squared_error: 0.2428 - val_loss: 0.0345 - val_mean_absolute_error: 0.0345 - val_mean_squared_error: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 132/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0657 - root_mean_squared_error: 0.2563 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0972
# Epoch 133/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0904 - mean_absolute_error: 0.0904 - mean_squared_error: 0.0598 - root_mean_squared_error: 0.2445 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 134/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0584 - root_mean_squared_error: 0.2416 - val_loss: 0.0366 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 135/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - mean_squared_error: 0.0593 - root_mean_squared_error: 0.2435 - val_loss: 0.0319 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0093 - val_root_mean_squared_error: 0.0967
# Epoch 136/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0627 - root_mean_squared_error: 0.2503 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 137/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0907 - mean_absolute_error: 0.0907 - mean_squared_error: 0.0598 - root_mean_squared_error: 0.2445 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 138/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0607 - root_mean_squared_error: 0.2464 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 139/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - mean_squared_error: 0.0588 - root_mean_squared_error: 0.2424 - val_loss: 0.0318 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 140/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0876 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0566 - root_mean_squared_error: 0.2378 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 141/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0564 - root_mean_squared_error: 0.2375 - val_loss: 0.0304 - val_mean_absolute_error: 0.0304 - val_mean_squared_error: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 142/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0318 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 143/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0564 - root_mean_squared_error: 0.2375 - val_loss: 0.0334 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0090 - val_root_mean_squared_error: 0.0949
# Epoch 144/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0583 - root_mean_squared_error: 0.2415 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 145/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0881 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0593 - root_mean_squared_error: 0.2436 - val_loss: 0.0308 - val_mean_absolute_error: 0.0308 - val_mean_squared_error: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 146/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0909 - mean_absolute_error: 0.0909 - mean_squared_error: 0.0603 - root_mean_squared_error: 0.2456 - val_loss: 0.0349 - val_mean_absolute_error: 0.0349 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 147/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0572 - root_mean_squared_error: 0.2391 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0090 - val_root_mean_squared_error: 0.0948
# Epoch 148/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0624 - root_mean_squared_error: 0.2498 - val_loss: 0.0348 - val_mean_absolute_error: 0.0348 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 149/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0594 - root_mean_squared_error: 0.2436 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 150/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0589 - root_mean_squared_error: 0.2426 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 151/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0575 - root_mean_squared_error: 0.2398 - val_loss: 0.0311 - val_mean_absolute_error: 0.0311 - val_mean_squared_error: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 152/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0604 - root_mean_squared_error: 0.2458 - val_loss: 0.0309 - val_mean_absolute_error: 0.0309 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 153/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0304 - val_mean_absolute_error: 0.0304 - val_mean_squared_error: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 154/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - mean_squared_error: 0.0571 - root_mean_squared_error: 0.2390 - val_loss: 0.0309 - val_mean_absolute_error: 0.0309 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 155/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0928 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0650 - root_mean_squared_error: 0.2549 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0090 - val_root_mean_squared_error: 0.0946
# Epoch 156/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0561 - root_mean_squared_error: 0.2370 - val_loss: 0.0323 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0946
# Epoch 157/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0605 - root_mean_squared_error: 0.2460 - val_loss: 0.0353 - val_mean_absolute_error: 0.0353 - val_mean_squared_error: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 158/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0607 - root_mean_squared_error: 0.2463 - val_loss: 0.0329 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 159/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0584 - root_mean_squared_error: 0.2417 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 160/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0599 - root_mean_squared_error: 0.2448 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0941
# Epoch 161/2000
# ...
# Epoch 1948/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0514 - root_mean_squared_error: 0.2267 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 1949/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0922 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0534 - root_mean_squared_error: 0.2311 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1950/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0542 - root_mean_squared_error: 0.2327 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 1951/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2189 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 1952/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0848 - mean_absolute_error: 0.0848 - mean_squared_error: 0.0499 - root_mean_squared_error: 0.2234 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 1953/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0489 - root_mean_squared_error: 0.2212 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 1954/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0836 - mean_absolute_error: 0.0836 - mean_squared_error: 0.0446 - root_mean_squared_error: 0.2111 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 1955/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0496 - root_mean_squared_error: 0.2226 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 1956/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0848 - mean_absolute_error: 0.0848 - mean_squared_error: 0.0463 - root_mean_squared_error: 0.2153 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1957/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0500 - root_mean_squared_error: 0.2236 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 1958/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0532 - root_mean_squared_error: 0.2307 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1959/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0815 - mean_absolute_error: 0.0815 - mean_squared_error: 0.0460 - root_mean_squared_error: 0.2144 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 1960/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2243 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1961/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0846 - mean_absolute_error: 0.0846 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2186 - val_loss: 0.0279 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1962/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0535 - root_mean_squared_error: 0.2313 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 1963/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0886 - mean_absolute_error: 0.0886 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2321 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0818
# Epoch 1964/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0852 - mean_absolute_error: 0.0852 - mean_squared_error: 0.0464 - root_mean_squared_error: 0.2153 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 1965/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0440 - root_mean_squared_error: 0.2097 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 1966/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0499 - root_mean_squared_error: 0.2234 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 1967/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0509 - root_mean_squared_error: 0.2257 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0822
# Epoch 1968/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0504 - root_mean_squared_error: 0.2245 - val_loss: 0.0282 - val_mean_absolute_error: 0.0282 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 1969/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0475 - root_mean_squared_error: 0.2179 - val_loss: 0.0286 - val_mean_absolute_error: 0.0286 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 1970/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0480 - root_mean_squared_error: 0.2191 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1971/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0843 - mean_absolute_error: 0.0843 - mean_squared_error: 0.0463 - root_mean_squared_error: 0.2151 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 1972/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0897 - mean_absolute_error: 0.0897 - mean_squared_error: 0.0543 - root_mean_squared_error: 0.2329 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1973/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0582 - root_mean_squared_error: 0.2412 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 1974/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0838 - mean_absolute_error: 0.0838 - mean_squared_error: 0.0480 - root_mean_squared_error: 0.2192 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 1975/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2186 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1976/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0477 - root_mean_squared_error: 0.2183 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1977/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0484 - root_mean_squared_error: 0.2201 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 1978/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0848 - mean_absolute_error: 0.0848 - mean_squared_error: 0.0471 - root_mean_squared_error: 0.2169 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1979/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0870 - mean_absolute_error: 0.0870 - mean_squared_error: 0.0484 - root_mean_squared_error: 0.2199 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 1980/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0504 - root_mean_squared_error: 0.2245 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 1981/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2157 - val_loss: 0.0282 - val_mean_absolute_error: 0.0282 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 1982/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0527 - root_mean_squared_error: 0.2296 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 1983/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0491 - root_mean_squared_error: 0.2215 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 1984/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0847 - mean_absolute_error: 0.0847 - mean_squared_error: 0.0472 - root_mean_squared_error: 0.2173 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1985/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0523 - root_mean_squared_error: 0.2287 - val_loss: 0.0269 - val_mean_absolute_error: 0.0269 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 1986/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0533 - root_mean_squared_error: 0.2310 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1987/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2250 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 1988/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0477 - root_mean_squared_error: 0.2183 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 1989/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0501 - root_mean_squared_error: 0.2238 - val_loss: 0.0279 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 1990/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0828 - mean_absolute_error: 0.0828 - mean_squared_error: 0.0447 - root_mean_squared_error: 0.2114 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 1991/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0467 - root_mean_squared_error: 0.2161 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 1992/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0519 - root_mean_squared_error: 0.2278 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 1993/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0827 - mean_absolute_error: 0.0827 - mean_squared_error: 0.0455 - root_mean_squared_error: 0.2133 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 1994/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0553 - root_mean_squared_error: 0.2352 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 1995/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0533 - root_mean_squared_error: 0.2308 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 1996/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0840 - mean_absolute_error: 0.0840 - mean_squared_error: 0.0466 - root_mean_squared_error: 0.2159 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1997/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0490 - root_mean_squared_error: 0.2214 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 1998/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0876 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0493 - root_mean_squared_error: 0.2220 - val_loss: 0.0269 - val_mean_absolute_error: 0.0269 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 1999/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0502 - root_mean_squared_error: 0.2240 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 2000/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0839 - mean_absolute_error: 0.0839 - mean_squared_error: 0.0490 - root_mean_squared_error: 0.2213 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                480
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=2)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=2)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-1.0012537  -1.0016965  -1.0009094  -1.0008602  -0.99982834 -0.9987149
#  -0.9946796  -0.9891357  -0.9777383  -0.99877596 -1.0008111  -1.0005653
#  -1.0005653  -1.0012045  -1.0014504  -1.0004178  -1.0001721  -1.000467
#  -0.990332   -0.98653454 -0.96231574 -0.96845305 -0.9999757  -1.0005653
#  -1.0013521  -1.0014997  -1.0009586  -1.0008111  -0.9977592  -0.999681
#  -0.9938166  -0.93027526 -0.6959325  -0.69855106 -0.84198534 -0.999681
#  -1.0005162  -1.0006636  -0.9988981  -0.99883705 -1.0005162  -1.0006636
#  -1.0004178  -0.9985317  -1.0004178  -0.99987745 -1.0003687 ]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN
# - https://www.datatechnotes.com/2019/02/regression-model-accuracy-mae-mse-rmse.html
# - https://lms.onnocenter.or.id/wiki/index.php/Orange:_Metric_Evaluation_Model#Mean_Squared_Error_.28MSE.29
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0844 - mean_absolute_error: 0.0844 - mean_squared_error: 0.0484 - root_mean_squared_error: 0.2199
# [0.0843561589717865,
#  0.0843561589717865,
#  0.048360928893089294,
#  0.21991118788719177]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0291 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0070 - root_mean_squared_error: 0.0836
# [0.029090680181980133,
#  0.029090680181980133,
#  0.006995996925979853,
#  0.08364207297563553]

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE : %.4f' % mae)
# Out:
# Test MAE : 0.0291

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0070

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
# calculate RMSE
rmse = sqrt(mse)
print('Test RMSE: %.4f' % rmse)
# Out:
# Test RMSE: 0.0836

# %% [markdown]
# - MAPE dan sMAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions)
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 0.0484

# %%
smape = sMAPE(testY, predictions)
print('Test sMAPE: %.4f' % smape)
# Out:
# Test sMAPE: 0.0654

# %% [markdown]
# - Korelasi dan Signifikansi

# %%
hasil = np.stack((testY.reshape(-1), predictions.reshape(-1)), axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999723 -1.001254
# 1    -0.997503 -1.001696
# 2    -0.997364 -1.000909
# 3    -0.994450 -1.000860
# 4    -0.991537 -0.999828

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.7073 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:02:38.46

# %% [markdown]
# ### 8. Visualisasi Data LSTM-RNN

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testY, color="tab:blue", label="actual data", linewidth=2.5)
ax.plot(x, predictions, color="tab:red", label="prediction data", linewidth=2.5)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)
testActual = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testActual, color="tab:blue", label="actual data", linewidth=2.5)
ax.plot(x, testPredictions, color="tab:red", label="prediction data", linewidth=2.5)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
#  shift test predictions for plotting
testPredictionsPlot = np.empty_like(df_sumsel)
testPredictionsPlot[:, :] = np.nan
testPredictionsPlot[(len(dataset) - testPredictions.shape[0]):len(dataset), :] = testPredictions

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["tanggal"], scaler.inverse_transform(df_sumsel), color="tab:blue", label="actual data", linewidth=2)
ax.plot(dataset["tanggal"], testPredictionsPlot, color="tab:red", label="predictions data", linewidth=2)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
temp_aktual = pd.DataFrame(scaler.inverse_transform(df_sumsel), columns=['Aktual'])
temp_prediksi = pd.DataFrame(testPredictionsPlot, columns=['Percobaan 1'])

# %%
hasil_percobaan_1 = pd.concat([temp_aktual, temp_prediksi], axis=1)

# %%
hasil_percobaan_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Aktual       240 non-null    float64
#  1   Percobaan 1  47 non-null     float64
# dtypes: float64(2)
# memory usage: 3.9 KB

# %%
hasil_percobaan_1.head()
# Out:
#    Aktual  Percobaan 1
# 0     3.0          NaN
# 1     5.0          NaN
# 2    10.0          NaN
# 3    20.0          NaN
# 4    39.0          NaN

# %%
hasil_percobaan_1.to_csv('hasil_percobaan_1.csv',index=False)

# %%
type(testY)
# Out:
# numpy.ndarray

# %%
type(predictions)
# Out:
# numpy.ndarray
