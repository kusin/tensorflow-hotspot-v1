# %% [markdown]
# ## Univariate LSTM-RNN Sumatera Selatan Percobaan 1

# %% [markdown]
# ### 1. Deklarasi Pustaka

# %%
# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library configuration date and time
import time
from datetime import datetime

# library data visualization
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib import pyplot
from matplotlib import pyplot as plt

# library analysis acf and pacf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# library algorithm lstm-rnn with keras
import tensorflow as tf
from tensorflow.keras import models
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# Early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# library evaluation model
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from epftoolbox.evaluation import sMAPE

# %% [markdown]
# ### 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
# fix random seed for reproducibility
np.random.seed(1234)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
# # set index tanggal
# dataset = dataset.set_index("tanggal")

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tanggal         240 non-null    datetime64[ns]
#  1   sst             240 non-null    float64
#  2   soi             240 non-null    float64
#  3   oni             240 non-null    float64
#  4   curah_hujan     240 non-null    float64
#  5   hotspot_sumsel  240 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.4 KB

# %%
dataset.describe()
# Out:
#               sst         soi         oni  curah_hujan  hotspot_sumsel
# count  240.000000  240.000000  240.000000   240.000000      240.000000
# mean     0.037917    0.167500    0.002708   232.780420      648.587500
# std      0.748704    0.909564    0.789896   121.096391     1747.365812
# min     -1.590000   -3.100000   -1.640000     9.900001        1.000000
# 25%     -0.480000   -0.400000   -0.505000   129.325006       21.750000
# 50%     -0.010000    0.100000   -0.050000   229.400002       59.500000
# 75%      0.500000    0.700000    0.472500   326.424995      313.250000
# max      2.720000    2.900000    2.640000   537.400024    14416.000000

# %%
print(dataset.head())
# Out:
#      tanggal   sst  soi   oni  curah_hujan  hotspot_sumsel
# 0 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 1 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 3 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 4 2001-05-31 -0.46 -0.5 -0.25   116.900002              39

# %% [markdown]
# ### 3. Exploration Data Analysis

# %% [markdown]
# - Data Visualization

# %%
# make frame
fig, ax = plt.subplots(figsize = (20,6))

# make time series plot
ax.plot(dataset["tanggal"], dataset["hotspot_sumsel"], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax.set_xlabel("Date", fontsize=12)
ax.set_ylabel("Sum of hostpot", fontsize=12)
ax.legend(loc='best')
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# - Analysis ACF and PACF

# %%
# make frame
fig, ax= plt.subplots(nrows=1, ncols=2, facecolor="#F0F0F0", figsize = (20,5))

# plot acf
plot_acf(dataset["hotspot_sumsel"], lags=24, ax=ax[0])
ax[0].grid(True)

# plot pacf
plot_pacf(dataset["hotspot_sumsel"],lags=24, ax=ax[1], method="yw")
ax[1].grid(True)

# show plot acf and pacf
plt.show()

# %% [markdown]
# ### 4. Praproses Data

# %% [markdown]
# - 1. feature selection (studi kasus sumatera selatan)

# %%
# memilih area studi
df_sumsel = dataset[["hotspot_sumsel"]]

# %%
# ensure all data is float
df_sumsel = df_sumsel.values
df_sumsel = df_sumsel.astype('float64');

# %%
# show a dataset
np.round(df_sumsel[:5],4)
# Out:
# array([[ 3.],
#        [ 5.],
#        [10.],
#        [20.],
#        [39.]])

# %%
# view a dimension dataset
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.set_xlabel("Tanggal", fontsize=12)
ax.set_ylabel("Jumlah Hostpot", fontsize=12)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - 2. Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1,1))
df_sumsel = scaler.fit_transform(df_sumsel)

# %%
np.round(df_sumsel[:5],6)
# Out:
# array([[-0.999723],
#        [-0.999445],
#        [-0.998751],
#        [-0.997364],
#        [-0.994728]])

# %%
# view a dimension dataset after normalize
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="data aktual", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.set_xlabel("Tanggal", fontsize=12)
ax.set_ylabel("Jumlah Hostpot", fontsize=12)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - 3. set data train and data test

# %%
# set data train
train_size = int(len(df_sumsel) * 0.8)

# %%
# set loc data train
train = df_sumsel[0:train_size,:]

# %%
# show data train
np.round(train[:5],4)
# Out:
# array([[-0.9997],
#        [-0.9994],
#        [-0.9988],
#        [-0.9974],
#        [-0.9947]])

# %%
# view dimension of data train
train.shape
# Out:
# (192, 1)

# %%
# set data test
test_size = len(df_sumsel) - train_size

# %%
# set loc data test
test = df_sumsel[train_size:len(df_sumsel),:]

# %%
# show data test
np.round(test[:5],4)
# Out:
# array([[-0.9985],
#        [-0.9997],
#        [-0.9975],
#        [-0.9974],
#        [-0.9945]])

# %%
# view dimension of data test
test.shape
# Out:
# (48, 1)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.iloc[0:train_size,0], train, color="tab:blue", label="Data Train", linewidth=2.5)
ax.plot(dataset.iloc[train_size:len(dataset),0], test, color="tab:red", label="Data Test", linewidth=2.5)

# make are labels
# ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
# ax.set_xlabel("Years", fontsize=12)
# ax.set_ylabel("Sum of hotspot", fontsize=12)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 5. Supervised Learning

# %%
# function for supervised learning
def create_dataset(dataset, look_back=1):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(len(dataset)-look_back):
        
        # insert value X and Y 
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# - process supervised learning, with look back t-1 into X=t and Y=t+1

# %%
# set look back -1
look_back = 1

# %%
# set supervised learning for data train
trainX, trainY = create_dataset(train, look_back)

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (191, 1) (191,)

# %%
# set supervised learning for data test
testX, testY = create_dataset(test, look_back)

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (47, 1) (47,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX, columns=['x train'])
temp_trainY = pd.DataFrame(trainY, columns=['y train'])

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x train  191 non-null    float64
#  1   y train  191 non-null    float64
# dtypes: float64(2)
# memory usage: 3.1 KB

# %%
hasil_train.head()
# Out:
#     x train   y train
# 0 -0.999723 -0.999445
# 1 -0.999445 -0.998751
# 2 -0.998751 -0.997364
# 3 -0.997364 -0.994728
# 4 -0.994728 -0.999029

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX, columns=['x test'])
temp_testY = pd.DataFrame(testY, columns=['y test'])

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x test  47 non-null     float64
#  1   y test  47 non-null     float64
# dtypes: float64(2)
# memory usage: 880.0 bytes

# %%
hasil_test.head()
# Out:
#      x test    y test
# 0 -0.998474 -0.999723
# 1 -0.999723 -0.997503
# 2 -0.997503 -0.997364
# 3 -0.997364 -0.994450
# 4 -0.994450 -0.991537

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (191, 1, 1) (191,)

# %%
# reshape data test
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
print(testX.shape, testY.shape)
# Out:
# (47, 1, 1) (47,)

# %% [markdown]
# ### 6. Modeling LSTM-RNN

# %%
# Design network
model = Sequential()

# First LSTM layer with Dropout regularisation
model.add(
    LSTM(
        units=10,
        activation="selu",
        input_shape=(trainX.shape[1], 1)
    )
)
model.add(Dropout(0.25))

# The output layer
model.add(Dense(1))

# Compiling model the LSTM-RNN
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.MeanSquaredError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# %%
# fit network
history = model.fit(trainX, trainY, epochs=2000, batch_size=8,
                    validation_data=(testX, testY),
                    verbose=1, shuffle=False)
# Out:
# Epoch 1/2000
# 24/24 [==============================] - 2s 15ms/step - loss: 0.7315 - mean_absolute_error: 0.7315 - mean_squared_error: 0.5799 - root_mean_squared_error: 0.7615 - val_loss: 0.5878 - val_mean_absolute_error: 0.5878 - val_mean_squared_error: 0.3573 - val_root_mean_squared_error: 0.5977
# Epoch 2/2000
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4250 - mean_absolute_error: 0.4250 - mean_squared_error: 0.2169 - root_mean_squared_error: 0.4657 - val_loss: 0.2851 - val_mean_absolute_error: 0.2851 - val_mean_squared_error: 0.0825 - val_root_mean_squared_error: 0.2872
# Epoch 3/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2085 - mean_absolute_error: 0.2085 - mean_squared_error: 0.0921 - root_mean_squared_error: 0.3034 - val_loss: 0.1141 - val_mean_absolute_error: 0.1141 - val_mean_squared_error: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 4/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - mean_squared_error: 0.0722 - root_mean_squared_error: 0.2687 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962 - val_mean_squared_error: 0.0141 - val_root_mean_squared_error: 0.1186
# Epoch 5/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1637 - mean_absolute_error: 0.1637 - mean_squared_error: 0.0797 - root_mean_squared_error: 0.2824 - val_loss: 0.0914 - val_mean_absolute_error: 0.0914 - val_mean_squared_error: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 6/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1651 - mean_absolute_error: 0.1651 - mean_squared_error: 0.0783 - root_mean_squared_error: 0.2798 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985 - val_mean_squared_error: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 7/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - mean_squared_error: 0.0730 - root_mean_squared_error: 0.2702 - val_loss: 0.0920 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 8/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1544 - mean_absolute_error: 0.1544 - mean_squared_error: 0.0730 - root_mean_squared_error: 0.2702 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012 - val_mean_squared_error: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 9/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1455 - mean_absolute_error: 0.1455 - mean_squared_error: 0.0674 - root_mean_squared_error: 0.2596 - val_loss: 0.0910 - val_mean_absolute_error: 0.0910 - val_mean_squared_error: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 10/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1428 - mean_absolute_error: 0.1428 - mean_squared_error: 0.0697 - root_mean_squared_error: 0.2640 - val_loss: 0.0847 - val_mean_absolute_error: 0.0847 - val_mean_squared_error: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 11/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940 - val_mean_squared_error: 0.0139 - val_root_mean_squared_error: 0.1177
# Epoch 12/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2587 - val_loss: 0.0810 - val_mean_absolute_error: 0.0810 - val_mean_squared_error: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 13/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1307 - mean_absolute_error: 0.1307 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0864 - val_mean_absolute_error: 0.0864 - val_mean_squared_error: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 14/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1316 - mean_absolute_error: 0.1316 - mean_squared_error: 0.0694 - root_mean_squared_error: 0.2634 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 15/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1333 - mean_absolute_error: 0.1333 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2580 - val_loss: 0.0802 - val_mean_absolute_error: 0.0802 - val_mean_squared_error: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 16/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1287 - mean_absolute_error: 0.1287 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2570 - val_loss: 0.0663 - val_mean_absolute_error: 0.0663 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 17/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1172 - mean_absolute_error: 0.1172 - mean_squared_error: 0.0631 - root_mean_squared_error: 0.2511 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 18/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1322 - mean_absolute_error: 0.1322 - mean_squared_error: 0.0683 - root_mean_squared_error: 0.2612 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 19/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1212 - mean_absolute_error: 0.1212 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 20/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1202 - mean_absolute_error: 0.1202 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2618 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 21/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1145 - mean_absolute_error: 0.1145 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2533 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 22/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1175 - mean_absolute_error: 0.1175 - mean_squared_error: 0.0656 - root_mean_squared_error: 0.2560 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 23/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1101 - mean_absolute_error: 0.1101 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2577 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 24/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1083 - mean_absolute_error: 0.1083 - mean_squared_error: 0.0681 - root_mean_squared_error: 0.2610 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 25/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1023 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0646 - root_mean_squared_error: 0.2542 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 26/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1021 - mean_absolute_error: 0.1021 - mean_squared_error: 0.0650 - root_mean_squared_error: 0.2550 - val_loss: 0.0433 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 27/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1026 - mean_absolute_error: 0.1026 - mean_squared_error: 0.0650 - root_mean_squared_error: 0.2549 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 28/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1045 - mean_absolute_error: 0.1045 - mean_squared_error: 0.0683 - root_mean_squared_error: 0.2613 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 29/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0999 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.0422 - val_mean_absolute_error: 0.0422 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 30/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0989 - mean_absolute_error: 0.0989 - mean_squared_error: 0.0649 - root_mean_squared_error: 0.2548 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 31/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1000 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2622 - val_loss: 0.0405 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 32/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1008 - mean_absolute_error: 0.1008 - mean_squared_error: 0.0693 - root_mean_squared_error: 0.2632 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 33/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1006 - mean_absolute_error: 0.1006 - mean_squared_error: 0.0682 - root_mean_squared_error: 0.2612 - val_loss: 0.0411 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 34/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0981 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0672 - root_mean_squared_error: 0.2592 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 35/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0977 - mean_absolute_error: 0.0977 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2622 - val_loss: 0.0377 - val_mean_absolute_error: 0.0377 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 36/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0981 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0678 - root_mean_squared_error: 0.2604 - val_loss: 0.0410 - val_mean_absolute_error: 0.0410 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 37/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2616 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 38/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0979 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2618 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 39/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2620 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 40/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0996 - mean_absolute_error: 0.0996 - mean_squared_error: 0.0689 - root_mean_squared_error: 0.2626 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 41/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0963 - mean_absolute_error: 0.0963 - mean_squared_error: 0.0695 - root_mean_squared_error: 0.2636 - val_loss: 0.0346 - val_mean_absolute_error: 0.0346 - val_mean_squared_error: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 42/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0964 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0693 - root_mean_squared_error: 0.2633 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1075
# Epoch 43/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0951 - mean_absolute_error: 0.0951 - mean_squared_error: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0358 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 44/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0964 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0707 - root_mean_squared_error: 0.2660 - val_loss: 0.0373 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 45/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0969 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0703 - root_mean_squared_error: 0.2651 - val_loss: 0.0368 - val_mean_absolute_error: 0.0368 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1084
# Epoch 46/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0967 - mean_absolute_error: 0.0967 - mean_squared_error: 0.0693 - root_mean_squared_error: 0.2632 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 47/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0701 - root_mean_squared_error: 0.2649 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 48/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0964 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0701 - root_mean_squared_error: 0.2649 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 49/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0964 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0708 - root_mean_squared_error: 0.2662 - val_loss: 0.0367 - val_mean_absolute_error: 0.0367 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 50/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0716 - root_mean_squared_error: 0.2676 - val_loss: 0.0381 - val_mean_absolute_error: 0.0381 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 51/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0962 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1084
# Epoch 52/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0965 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0691 - root_mean_squared_error: 0.2629 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 53/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0951 - mean_absolute_error: 0.0951 - mean_squared_error: 0.0696 - root_mean_squared_error: 0.2639 - val_loss: 0.0424 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 54/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 55/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0961 - mean_absolute_error: 0.0961 - mean_squared_error: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.0386 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 56/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0684 - root_mean_squared_error: 0.2615 - val_loss: 0.0354 - val_mean_absolute_error: 0.0354 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 57/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0676 - root_mean_squared_error: 0.2599 - val_loss: 0.0336 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 58/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0953 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0681 - root_mean_squared_error: 0.2609 - val_loss: 0.0358 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 59/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0950 - mean_absolute_error: 0.0950 - mean_squared_error: 0.0687 - root_mean_squared_error: 0.2622 - val_loss: 0.0340 - val_mean_absolute_error: 0.0340 - val_mean_squared_error: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 60/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0953 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2616 - val_loss: 0.0336 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 61/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0961 - mean_absolute_error: 0.0961 - mean_squared_error: 0.0714 - root_mean_squared_error: 0.2671 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 62/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0956 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0703 - root_mean_squared_error: 0.2650 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 63/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0397 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 64/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0961 - mean_absolute_error: 0.0961 - mean_squared_error: 0.0691 - root_mean_squared_error: 0.2629 - val_loss: 0.0349 - val_mean_absolute_error: 0.0349 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 65/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0954 - mean_absolute_error: 0.0954 - mean_squared_error: 0.0683 - root_mean_squared_error: 0.2613 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 66/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0946 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0686 - root_mean_squared_error: 0.2620 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 67/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0942 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0692 - root_mean_squared_error: 0.2631 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 68/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - mean_squared_error: 0.0682 - root_mean_squared_error: 0.2611 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 69/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0964 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0680 - root_mean_squared_error: 0.2608 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 70/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0702 - root_mean_squared_error: 0.2650 - val_loss: 0.0343 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1089
# Epoch 71/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - mean_squared_error: 0.0678 - root_mean_squared_error: 0.2605 - val_loss: 0.0403 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 72/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2606 - val_loss: 0.0342 - val_mean_absolute_error: 0.0342 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 73/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0946 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0717 - root_mean_squared_error: 0.2677 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 74/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0946 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2618 - val_loss: 0.0334 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 75/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0660 - root_mean_squared_error: 0.2570 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 76/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0711 - root_mean_squared_error: 0.2667 - val_loss: 0.0336 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 77/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0942 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0688 - root_mean_squared_error: 0.2623 - val_loss: 0.0336 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0120 - val_root_mean_squared_error: 0.1098
# Epoch 78/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0119 - val_root_mean_squared_error: 0.1089
# Epoch 79/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0694 - root_mean_squared_error: 0.2634 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 80/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 81/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0942 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2595 - val_loss: 0.0341 - val_mean_absolute_error: 0.0341 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 82/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2578 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 83/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0962 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0699 - root_mean_squared_error: 0.2644 - val_loss: 0.0358 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 84/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0942 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2599 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 85/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0663 - root_mean_squared_error: 0.2575 - val_loss: 0.0347 - val_mean_absolute_error: 0.0347 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 86/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0710 - root_mean_squared_error: 0.2664 - val_loss: 0.0350 - val_mean_absolute_error: 0.0350 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 87/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0660 - root_mean_squared_error: 0.2568 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1070
# Epoch 88/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0665 - root_mean_squared_error: 0.2579 - val_loss: 0.0368 - val_mean_absolute_error: 0.0368 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 89/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0680 - root_mean_squared_error: 0.2608 - val_loss: 0.0399 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 90/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0944 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0334 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 91/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0681 - root_mean_squared_error: 0.2610 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 92/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 93/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0948 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.0359 - val_mean_absolute_error: 0.0359 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 94/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0928 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2577 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1056
# Epoch 95/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2580 - val_loss: 0.0368 - val_mean_absolute_error: 0.0368 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 96/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2607 - val_loss: 0.0351 - val_mean_absolute_error: 0.0351 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 97/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0692 - root_mean_squared_error: 0.2631 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 98/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0676 - root_mean_squared_error: 0.2601 - val_loss: 0.0358 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1065
# Epoch 99/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0643 - root_mean_squared_error: 0.2536 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 100/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0656 - root_mean_squared_error: 0.2561 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 101/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0689 - root_mean_squared_error: 0.2626 - val_loss: 0.0358 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 102/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0663 - root_mean_squared_error: 0.2574 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 103/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2607 - val_loss: 0.0329 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 104/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0915 - mean_absolute_error: 0.0915 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0403 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 105/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0652 - root_mean_squared_error: 0.2553 - val_loss: 0.0329 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 106/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0930 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0649 - root_mean_squared_error: 0.2547 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 107/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0953 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 108/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0649 - root_mean_squared_error: 0.2548 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 109/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 110/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0655 - root_mean_squared_error: 0.2560 - val_loss: 0.0361 - val_mean_absolute_error: 0.0361 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 111/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0944 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0689 - root_mean_squared_error: 0.2624 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 112/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0942 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2568 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330 - val_mean_squared_error: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 113/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0691 - root_mean_squared_error: 0.2630 - val_loss: 0.0352 - val_mean_absolute_error: 0.0352 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 114/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0655 - root_mean_squared_error: 0.2560 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1065
# Epoch 115/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2572 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 116/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0668 - root_mean_squared_error: 0.2585 - val_loss: 0.0343 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 117/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0929 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0671 - root_mean_squared_error: 0.2591 - val_loss: 0.0333 - val_mean_absolute_error: 0.0333 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 118/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2577 - val_loss: 0.0326 - val_mean_absolute_error: 0.0326 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1065
# Epoch 119/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2582 - val_loss: 0.0325 - val_mean_absolute_error: 0.0325 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 120/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0929 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0648 - root_mean_squared_error: 0.2545 - val_loss: 0.0370 - val_mean_absolute_error: 0.0370 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 121/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0915 - mean_absolute_error: 0.0915 - mean_squared_error: 0.0634 - root_mean_squared_error: 0.2517 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 122/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2576 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 123/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0631 - root_mean_squared_error: 0.2512 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 124/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0934 - mean_absolute_error: 0.0934 - mean_squared_error: 0.0668 - root_mean_squared_error: 0.2585 - val_loss: 0.0356 - val_mean_absolute_error: 0.0356 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 125/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0674 - root_mean_squared_error: 0.2597 - val_loss: 0.0347 - val_mean_absolute_error: 0.0347 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 126/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0652 - root_mean_squared_error: 0.2554 - val_loss: 0.0350 - val_mean_absolute_error: 0.0350 - val_mean_squared_error: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 127/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0643 - root_mean_squared_error: 0.2536 - val_loss: 0.0332 - val_mean_absolute_error: 0.0332 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 128/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0662 - root_mean_squared_error: 0.2573 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 129/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0640 - root_mean_squared_error: 0.2530 - val_loss: 0.0327 - val_mean_absolute_error: 0.0327 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 130/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2538 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330 - val_mean_squared_error: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 131/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2581 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 132/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 133/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0652 - root_mean_squared_error: 0.2553 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 134/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0656 - root_mean_squared_error: 0.2561 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 135/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.0353 - val_mean_absolute_error: 0.0353 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 136/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0922 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0638 - root_mean_squared_error: 0.2526 - val_loss: 0.0347 - val_mean_absolute_error: 0.0347 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 137/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0641 - root_mean_squared_error: 0.2533 - val_loss: 0.0366 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1037
# Epoch 138/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0633 - root_mean_squared_error: 0.2517 - val_loss: 0.0336 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 139/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0641 - root_mean_squared_error: 0.2531 - val_loss: 0.0349 - val_mean_absolute_error: 0.0349 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 140/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2571 - val_loss: 0.0361 - val_mean_absolute_error: 0.0361 - val_mean_squared_error: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 141/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0667 - root_mean_squared_error: 0.2582 - val_loss: 0.0334 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 142/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2533 - val_loss: 0.0328 - val_mean_absolute_error: 0.0328 - val_mean_squared_error: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 143/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0930 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 0.0329 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 144/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0632 - root_mean_squared_error: 0.2515 - val_loss: 0.0342 - val_mean_absolute_error: 0.0342 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 145/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2567 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 146/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0623 - root_mean_squared_error: 0.2496 - val_loss: 0.0339 - val_mean_absolute_error: 0.0339 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 147/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0630 - root_mean_squared_error: 0.2511 - val_loss: 0.0325 - val_mean_absolute_error: 0.0325 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 148/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0643 - root_mean_squared_error: 0.2536 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 149/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0638 - root_mean_squared_error: 0.2525 - val_loss: 0.0353 - val_mean_absolute_error: 0.0353 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 150/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - mean_squared_error: 0.0616 - root_mean_squared_error: 0.2483 - val_loss: 0.0364 - val_mean_absolute_error: 0.0364 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 151/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2599 - val_loss: 0.0323 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 152/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0634 - root_mean_squared_error: 0.2519 - val_loss: 0.0321 - val_mean_absolute_error: 0.0321 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 153/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0909 - mean_absolute_error: 0.0909 - mean_squared_error: 0.0639 - root_mean_squared_error: 0.2529 - val_loss: 0.0366 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 154/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0652 - root_mean_squared_error: 0.2553 - val_loss: 0.0319 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 155/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0638 - root_mean_squared_error: 0.2526 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 156/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0635 - root_mean_squared_error: 0.2519 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 157/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0922 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0342 - val_mean_absolute_error: 0.0342 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 158/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 0.0343 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 159/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0611 - root_mean_squared_error: 0.2472 - val_loss: 0.0337 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 160/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0611 - root_mean_squared_error: 0.2471 - val_loss: 0.0351 - val_mean_absolute_error: 0.0351 - val_mean_squared_error: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 161/2000
# ...
# Epoch 1948/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0847 - mean_absolute_error: 0.0847 - mean_squared_error: 0.0476 - root_mean_squared_error: 0.2182 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1949/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0501 - root_mean_squared_error: 0.2239 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0840
# Epoch 1950/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0829 - mean_absolute_error: 0.0829 - mean_squared_error: 0.0456 - root_mean_squared_error: 0.2134 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 1951/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0502 - root_mean_squared_error: 0.2241 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 1952/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0493 - root_mean_squared_error: 0.2220 - val_loss: 0.0265 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1953/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0464 - root_mean_squared_error: 0.2153 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 1954/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0552 - root_mean_squared_error: 0.2350 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 1955/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0837 - mean_absolute_error: 0.0837 - mean_squared_error: 0.0483 - root_mean_squared_error: 0.2198 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0840
# Epoch 1956/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0489 - root_mean_squared_error: 0.2212 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1957/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0448 - root_mean_squared_error: 0.2116 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 1958/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0460 - root_mean_squared_error: 0.2145 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1959/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0913 - mean_absolute_error: 0.0913 - mean_squared_error: 0.0526 - root_mean_squared_error: 0.2294 - val_loss: 0.0285 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 1960/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0837 - mean_absolute_error: 0.0837 - mean_squared_error: 0.0432 - root_mean_squared_error: 0.2078 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1961/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0846 - mean_absolute_error: 0.0846 - mean_squared_error: 0.0447 - root_mean_squared_error: 0.2114 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 1962/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0841 - mean_absolute_error: 0.0841 - mean_squared_error: 0.0450 - root_mean_squared_error: 0.2122 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 1963/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0843 - mean_absolute_error: 0.0843 - mean_squared_error: 0.0454 - root_mean_squared_error: 0.2132 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 1964/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0440 - root_mean_squared_error: 0.2097 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1965/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0505 - root_mean_squared_error: 0.2247 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 1966/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2186 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 1967/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0488 - root_mean_squared_error: 0.2208 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 1968/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0515 - root_mean_squared_error: 0.2268 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 1969/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0870 - mean_absolute_error: 0.0870 - mean_squared_error: 0.0514 - root_mean_squared_error: 0.2268 - val_loss: 0.0305 - val_mean_absolute_error: 0.0305 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1970/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0527 - root_mean_squared_error: 0.2295 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1971/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0498 - root_mean_squared_error: 0.2231 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0844
# Epoch 1972/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0480 - root_mean_squared_error: 0.2191 - val_loss: 0.0279 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 1973/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0514 - root_mean_squared_error: 0.2267 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1974/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0852 - mean_absolute_error: 0.0852 - mean_squared_error: 0.0472 - root_mean_squared_error: 0.2174 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1975/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0452 - root_mean_squared_error: 0.2125 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1976/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0458 - root_mean_squared_error: 0.2141 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 1977/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0827 - mean_absolute_error: 0.0827 - mean_squared_error: 0.0440 - root_mean_squared_error: 0.2099 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 1978/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2242 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 1979/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0564 - root_mean_squared_error: 0.2376 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 1980/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0827 - mean_absolute_error: 0.0827 - mean_squared_error: 0.0436 - root_mean_squared_error: 0.2089 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 1981/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0470 - root_mean_squared_error: 0.2168 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 1982/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0486 - root_mean_squared_error: 0.2204 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 1983/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0838 - mean_absolute_error: 0.0838 - mean_squared_error: 0.0443 - root_mean_squared_error: 0.2106 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 1984/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0846 - mean_absolute_error: 0.0846 - mean_squared_error: 0.0463 - root_mean_squared_error: 0.2152 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 1985/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0477 - root_mean_squared_error: 0.2183 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1986/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0460 - root_mean_squared_error: 0.2144 - val_loss: 0.0291 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 1987/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0482 - root_mean_squared_error: 0.2196 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 1988/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0819 - mean_absolute_error: 0.0819 - mean_squared_error: 0.0442 - root_mean_squared_error: 0.2102 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1989/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0829 - mean_absolute_error: 0.0829 - mean_squared_error: 0.0435 - root_mean_squared_error: 0.2087 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 1990/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0490 - root_mean_squared_error: 0.2214 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 1991/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0515 - root_mean_squared_error: 0.2269 - val_loss: 0.0271 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 1992/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0826 - mean_absolute_error: 0.0826 - mean_squared_error: 0.0450 - root_mean_squared_error: 0.2122 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 1993/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0510 - root_mean_squared_error: 0.2259 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 1994/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0522 - root_mean_squared_error: 0.2285 - val_loss: 0.0269 - val_mean_absolute_error: 0.0269 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 1995/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0462 - root_mean_squared_error: 0.2150 - val_loss: 0.0286 - val_mean_absolute_error: 0.0286 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 1996/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0500 - root_mean_squared_error: 0.2236 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 1997/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0568 - root_mean_squared_error: 0.2382 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0840
# Epoch 1998/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0858 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0467 - root_mean_squared_error: 0.2161 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0844
# Epoch 1999/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0828 - mean_absolute_error: 0.0828 - mean_squared_error: 0.0441 - root_mean_squared_error: 0.2100 - val_loss: 0.0279 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 2000/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0530 - root_mean_squared_error: 0.2303 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0834

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                480
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=2)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=2)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-0.9948108  -0.9953797  -0.99436855 -0.9943054  -0.9929793  -0.9913087
#  -0.9873967  -0.98280257 -0.9733369  -0.99139434 -0.99424213 -0.99392635
#  -0.99392635 -0.9947476  -0.99506366 -0.99373686 -0.99342114 -0.99380004
#  -0.9837913  -0.9806497  -0.96039134 -0.9655622  -0.9931686  -0.99392635
#  -0.99493724 -0.99512684 -0.9944317  -0.99424213 -0.9901953  -0.9927899
#  -0.98667437 -0.9328775  -0.70104426 -0.70407856 -0.8530786  -0.9927899
#  -0.9938632  -0.9940527  -0.9915658  -0.99148005 -0.9938632  -0.9940527
#  -0.99373686 -0.99105155 -0.99373686 -0.99304235 -0.99367374]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN
# - https://www.datatechnotes.com/2019/02/regression-model-accuracy-mae-mse-rmse.html
# - https://lms.onnocenter.or.id/wiki/index.php/Orange:_Metric_Evaluation_Model#Mean_Squared_Error_.28MSE.29
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0833 - mean_absolute_error: 0.0833 - mean_squared_error: 0.0468 - root_mean_squared_error: 0.2164
# [0.08329658210277557,
#  0.08329658210277557,
#  0.046825747936964035,
#  0.21639257669448853]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0270 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0070 - root_mean_squared_error: 0.0834
# [0.027006035670638084,
#  0.027006035670638084,
#  0.006952962838113308,
#  0.0833844244480133]

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE : %.4f' % mae)
# Out:
# Test MAE : 0.0270

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0070

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
# calculate RMSE
rmse = sqrt(mse)
print('Test RMSE: %.4f' % rmse)
# Out:
# Test RMSE: 0.0834

# %% [markdown]
# - MAPE dan sMAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions)
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 0.0464

# %%
smape = sMAPE(testY, predictions)
print('Test sMAPE: %.4f' % smape)
# Out:
# Test sMAPE: 0.0633

# %% [markdown]
# - Korelasi dan Signifikansi

# %%
hasil = np.stack((testY.reshape(-1), predictions.reshape(-1)), axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999723 -0.994811
# 1    -0.997503 -0.995380
# 2    -0.997364 -0.994369
# 3    -0.994450 -0.994305
# 4    -0.991537 -0.992979

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.7061 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:02:42.62

# %% [markdown]
# ### 8. Visualisasi Data LSTM-RNN

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testY, color="tab:blue", label="actual data", linewidth=2.5)
ax.plot(x, predictions, color="tab:red", label="prediction data", linewidth=2.5)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)
testActual = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testActual, color="tab:blue", label="actual data", linewidth=2.5)
ax.plot(x, testPredictions, color="tab:red", label="prediction data", linewidth=2.5)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
#  shift test predictions for plotting
testPredictionsPlot = np.empty_like(df_sumsel)
testPredictionsPlot[:, :] = np.nan
testPredictionsPlot[(len(dataset) - testPredictions.shape[0]):len(dataset), :] = testPredictions

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset["tanggal"], scaler.inverse_transform(df_sumsel), color="tab:blue", label="actual data", linewidth=2)
ax.plot(dataset["tanggal"], testPredictionsPlot, color="tab:red", label="predictions data", linewidth=2)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
temp_aktual = pd.DataFrame(scaler.inverse_transform(df_sumsel), columns=['Aktual'])
temp_prediksi = pd.DataFrame(testPredictionsPlot, columns=['Percobaan 1'])

# %%
hasil_percobaan_1 = pd.concat([temp_aktual, temp_prediksi], axis=1)

# %%
hasil_percobaan_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Aktual       240 non-null    float64
#  1   Percobaan 1  47 non-null     float64
# dtypes: float64(2)
# memory usage: 3.9 KB

# %%
hasil_percobaan_1.head()
# Out:
#    Aktual  Percobaan 1
# 0     3.0          NaN
# 1     5.0          NaN
# 2    10.0          NaN
# 3    20.0          NaN
# 4    39.0          NaN

# %%
hasil_percobaan_1.to_csv('hasil_percobaan_1.csv',index=False)

# %%
type(testY)
# Out:
# numpy.ndarray

# %%
type(predictions)
# Out:
# numpy.ndarray
