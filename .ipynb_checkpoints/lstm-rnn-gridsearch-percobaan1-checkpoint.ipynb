# %% [markdown]
# ### Hyperparameter GridSearchCV LSTM-RNN Percobaan 1

# %% [markdown]
# ### 1. Declaration Library

# %%
# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library configuration date and time
import time
from datetime import datetime

# library data visualization
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# library analysis acf and pacf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# library algorithm lstm-rnn with keras
import tensorflow as tf
from tensorflow.keras import models
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# Early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# library evaluation model
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
# fix random seed for reproducibility
np.random.seed(7)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
# set index tanggal
# dataset = dataset.set_index("tanggal")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tanggal         240 non-null    datetime64[ns]
#  1   sst             240 non-null    float64
#  2   soi             240 non-null    float64
#  3   oni             240 non-null    float64
#  4   curah_hujan     240 non-null    float64
#  5   hotspot_sumsel  240 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.4 KB

# %%
print(dataset.head())
# Out:
#      tanggal   sst  soi   oni  curah_hujan  hotspot_sumsel
# 0 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 1 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 3 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 4 2001-05-31 -0.46 -0.5 -0.25   116.900002              39

# %% [markdown]
# ### 3. Exploration Data Analysis

# %% [markdown]
# - Data Visualization

# %%
# make frame
fig, ax = plt.subplots(figsize = (20,6))

# make time series plot
ax.plot(dataset["tanggal"], dataset["hotspot_sumsel"], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax.set_xlabel("Date", fontsize=12)
ax.set_ylabel("Sum of hostpot", fontsize=12)
ax.legend(loc='best')
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# - Analysis ACF and PACF

# %%
# make frame
fig, ax= plt.subplots(nrows=1, ncols=2, facecolor="#F0F0F0", figsize = (20,5))

# plot acf
plot_acf(dataset["hotspot_sumsel"], lags=24, ax=ax[0])
ax[0].grid(True)

# plot pacf
plot_pacf(dataset["hotspot_sumsel"],lags=24, ax=ax[1], method="yw")
ax[1].grid(True)

# show plot acf and pacf
plt.show()

# %% [markdown]
# ### 4. Praproses Data

# %% [markdown]
# - feature selection (studi kasus sumatera selatan)

# %%
# memilih area studi
df_sumsel = dataset[["hotspot_sumsel"]]

# %%
# ensure all data is float
df_sumsel = df_sumsel.values
df_sumsel = df_sumsel.astype('float64')

# %%
# show a dataset
np.round(df_sumsel[:5],7)
# Out:
# array([[ 3.],
#        [ 5.],
#        [10.],
#        [20.],
#        [39.]])

# %%
# view a dimension dataset
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="data aktual", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - normalization data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
df_sumsel = scaler.fit_transform(df_sumsel)

# %%
# show a dataset after normalize
np.round(df_sumsel[:5],7)
# Out:
# array([[-0.9997225],
#        [-0.999445 ],
#        [-0.9987513],
#        [-0.9973639],
#        [-0.9947277]])

# %%
# view a dimension dataset after normalize
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="data aktual", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - set data train and data test

# %%
# set data train
train_size = int(len(df_sumsel) * 0.8)

# %%
# set loc data train
train= df_sumsel[0:train_size,:]

# %%
# show data train
np.round(train[:5],7)
# Out:
# array([[-0.9997225],
#        [-0.999445 ],
#        [-0.9987513],
#        [-0.9973639],
#        [-0.9947277]])

# %%
# view dimension of data train
train.shape
# Out:
# (192, 1)

# %%
# set data test
test_size = len(df_sumsel) - train_size

# %%
# set loc data test
test = df_sumsel[train_size:len(df_sumsel),:]

# %%
# show data test
np.round(test[:5],6)
# Out:
# array([[-0.998474],
#        [-0.999723],
#        [-0.997503],
#        [-0.997364],
#        [-0.99445 ]])

# %%
# view dimension of data test
test.shape
# Out:
# (48, 1)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (20,7))

# make a time series plot
ax.plot(dataset.iloc[0:train_size,0], train, color="tab:blue", label="Data Latih", linewidth=2.5)
ax.plot(dataset.iloc[train_size:len(dataset),0], test, color="tab:red", label="Data Uji", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 5. Supervised Learning

# %%
# function for supervised learning
def create_dataset(dataset, look_back=1):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(len(dataset)-look_back):
        
        # insert value X and Y 
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# - process supervised learning, with look back t-1 into X=t and Y=t+1

# %%
# set look back -1
look_back = 1

# %%
# set supervised learning for data train
trainX, trainY = create_dataset(train, look_back)

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (191, 1) (191,)

# %%
# set supervised learning for data test
testX, testY = create_dataset(test, look_back)

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (47, 1) (47,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX, columns=['x train'])
temp_trainY = pd.DataFrame(trainY, columns=['y train'])

# %%
hasil = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x train  191 non-null    float64
#  1   y train  191 non-null    float64
# dtypes: float64(2)
# memory usage: 3.1 KB

# %%
hasil.head()
# Out:
#     x train   y train
# 0 -0.999723 -0.999445
# 1 -0.999445 -0.998751
# 2 -0.998751 -0.997364
# 3 -0.997364 -0.994728
# 4 -0.994728 -0.999029

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX, columns=['x test'])
temp_testY = pd.DataFrame(testY, columns=['y test'])

# %%
hasil = pd.concat([temp_testX, temp_testY], axis=1)
hasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x test  47 non-null     float64
#  1   y test  47 non-null     float64
# dtypes: float64(2)
# memory usage: 880.0 bytes

# %%
hasil.head()
# Out:
#      x test    y test
# 0 -0.998474 -0.999723
# 1 -0.999723 -0.997503
# 2 -0.997503 -0.997364
# 3 -0.997364 -0.994450
# 4 -0.994450 -0.991537

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (191, 1, 1) (191,)

# %%
# reshape data test
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
print(testX.shape, testY.shape)
# Out:
# (47, 1, 1) (47,)

# %% [markdown]
# ### 6. Hyperparameter GridSearchCV LSTM-RNN

# %% [markdown]
# - library for hyperparameter

# %%
import itertools
from scikeras.wrappers import KerasRegressor
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# - set models lstm-rnn with sliding windows and timestep

# %%
# function models lstm-rnn
def get_model(activation='tanh', optimizer='adam', dropout_rate=0.0):
    
    # reset of session model
    tf.keras.backend.clear_session()
    
    # design network
    model = Sequential()
    
    # first LSTM-RNN layer with dropout regularisation
    model.add(LSTM(units=10, activation=activation, input_shape=(trainX.shape[1], 1)))
    model.add(Dropout(dropout_rate))
    
    # the output layer
    model.add(Dense(1))

    # compiling model the LSTM-RNN
    model.compile(
        optimizer=optimizer,
        loss="mae",
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(),
            tf.keras.metrics.MeanSquaredError(),
            tf.keras.metrics.RootMeanSquaredError()
        ]
    )
    
    # return value
    return model

# %% [markdown]
# Set parameter
# - activation function = tanh, sigmoid, relu, selu, softplus, elu.
# - optimizers = adam, adamax, rmsprop, sgd.
# - droupout = 0.00, 0.05, 0.1, 0.15, 0.2, 0.25
# - batch size = 2, 4, 8, 16, 32, 64
# - epoch = 500, 1000, 1500, 2000

# %%
# set parameter activation
activation = ['tanh', 'sigmoid', 'relu', 'selu', 'elu', 'softplus']

# %%
# set parameter optimizer
optimizer = ['adam', 'adamax', 'rmsprop', 'sgd']

# %%
# set parameter dropout_rate
dropout_rate = [0.05, 0.1, 0.15, 0.2, 0.25]

# %%
# set parameters batch sizes
batch_size = [2, 4, 8, 16, 32]

# %%
# set parameter epochs
epochs = [2000]

# %%
# set all parameter to dictionary
param_grid = dict(
    model__activation=activation,
    model__optimizer=optimizer,
    model__dropout_rate=dropout_rate,
    batch_size=batch_size,
    epochs=epochs
)

# %%
# show parameter a gridsearch
param_grid
# Out:
# {'model__activation': ['tanh', 'sigmoid', 'relu', 'selu', 'elu', 'softplus'],
#  'model__optimizer': ['adam', 'adamax', 'rmsprop', 'sgd'],
#  'model__dropout_rate': [0.05, 0.1, 0.15, 0.2, 0.25],
#  'batch_size': [2, 4, 8, 16, 32],
#  'epochs': [2000]}

# %%
keys = param_grid.keys()
values = (param_grid[key] for key in keys)
combinations = [dict(zip(keys, combination)) for combination in itertools.product(*values)]
print(len(combinations), str('kombinasi hyperparameter'))
# Out:
# 600 kombinasi hyperparameter

# %%
# set grid model with KerasRegressor
grid_model = KerasRegressor(model=get_model, verbose=1)

# %%
# process a gridsearchCV
grid_search = GridSearchCV(estimator=grid_model, param_grid=param_grid, n_jobs=-1, cv=2, scoring='neg_root_mean_squared_error')

# %%
# show a result gridsearchCV
grid_result = grid_search.fit(trainX, trainY)
# Out:
# C:\Users\lunox\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/2000
# 96/96 [==============================] - 2s 1ms/step - loss: 0.4998 - mean_absolute_error: 0.4998 - mean_squared_error: 0.3849 - root_mean_squared_error: 0.6204
# Epoch 2/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1116 - mean_absolute_error: 0.1116 - mean_squared_error: 0.0746 - root_mean_squared_error: 0.2731
# Epoch 3/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1091 - mean_absolute_error: 0.1091 - mean_squared_error: 0.0695 - root_mean_squared_error: 0.2636
# Epoch 4/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1134 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0727 - root_mean_squared_error: 0.2696
# Epoch 5/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1076 - mean_absolute_error: 0.1076 - mean_squared_error: 0.0678 - root_mean_squared_error: 0.2604
# Epoch 6/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1028 - mean_absolute_error: 0.1028 - mean_squared_error: 0.0685 - root_mean_squared_error: 0.2618
# Epoch 7/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1030 - mean_absolute_error: 0.1030 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2595
# Epoch 8/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0974 - mean_absolute_error: 0.0974 - mean_squared_error: 0.0667 - root_mean_squared_error: 0.2583
# Epoch 9/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1030 - mean_absolute_error: 0.1030 - mean_squared_error: 0.0677 - root_mean_squared_error: 0.2601
# Epoch 10/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1021 - mean_absolute_error: 0.1021 - mean_squared_error: 0.0645 - root_mean_squared_error: 0.2540
# Epoch 11/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1022 - mean_absolute_error: 0.1022 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2577
# Epoch 12/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1007 - mean_absolute_error: 0.1007 - mean_squared_error: 0.0660 - root_mean_squared_error: 0.2569
# Epoch 13/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1002 - mean_absolute_error: 0.1002 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2595
# Epoch 14/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1003 - mean_absolute_error: 0.1003 - mean_squared_error: 0.0690 - root_mean_squared_error: 0.2627
# Epoch 15/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0979 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0672 - root_mean_squared_error: 0.2592
# Epoch 16/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0969 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0661 - root_mean_squared_error: 0.2571
# Epoch 17/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0971 - mean_absolute_error: 0.0971 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2567
# Epoch 18/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0981 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0680 - root_mean_squared_error: 0.2607
# Epoch 19/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0684 - root_mean_squared_error: 0.2615
# Epoch 20/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0975 - mean_absolute_error: 0.0975 - mean_squared_error: 0.0686 - root_mean_squared_error: 0.2619
# Epoch 21/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2576
# Epoch 22/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - mean_squared_error: 0.0666 - root_mean_squared_error: 0.2581
# Epoch 23/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0980 - mean_absolute_error: 0.0980 - mean_squared_error: 0.0683 - root_mean_squared_error: 0.2614
# Epoch 24/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0964 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0670 - root_mean_squared_error: 0.2588
# Epoch 25/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0961 - mean_absolute_error: 0.0961 - mean_squared_error: 0.0670 - root_mean_squared_error: 0.2588
# Epoch 26/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0971 - mean_absolute_error: 0.0971 - mean_squared_error: 0.0675 - root_mean_squared_error: 0.2599
# Epoch 27/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2586
# Epoch 28/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - mean_squared_error: 0.0655 - root_mean_squared_error: 0.2560
# Epoch 29/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0959 - mean_absolute_error: 0.0959 - mean_squared_error: 0.0665 - root_mean_squared_error: 0.2578
# Epoch 30/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2567
# Epoch 31/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2537
# Epoch 32/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - mean_squared_error: 0.0653 - root_mean_squared_error: 0.2556
# Epoch 33/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0657 - root_mean_squared_error: 0.2564
# Epoch 34/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - mean_squared_error: 0.0653 - root_mean_squared_error: 0.2555
# Epoch 35/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0951 - mean_absolute_error: 0.0951 - mean_squared_error: 0.0664 - root_mean_squared_error: 0.2576
# Epoch 36/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0946 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0648 - root_mean_squared_error: 0.2547
# Epoch 37/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - mean_squared_error: 0.0650 - root_mean_squared_error: 0.2550
# Epoch 38/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0647 - root_mean_squared_error: 0.2543
# Epoch 39/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0665 - root_mean_squared_error: 0.2579
# Epoch 40/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0634 - root_mean_squared_error: 0.2518
# Epoch 41/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0946 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0643 - root_mean_squared_error: 0.2536
# Epoch 42/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - mean_squared_error: 0.0644 - root_mean_squared_error: 0.2537
# Epoch 43/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0642 - root_mean_squared_error: 0.2533
# Epoch 44/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0934 - mean_absolute_error: 0.0934 - mean_squared_error: 0.0647 - root_mean_squared_error: 0.2543
# Epoch 45/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0928 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0653 - root_mean_squared_error: 0.2555
# Epoch 46/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0633 - root_mean_squared_error: 0.2516
# Epoch 47/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0928 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0623 - root_mean_squared_error: 0.2496
# Epoch 48/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0956 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0643 - root_mean_squared_error: 0.2535
# Epoch 49/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0923 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0622 - root_mean_squared_error: 0.2494
# Epoch 50/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2488
# Epoch 51/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0614 - root_mean_squared_error: 0.2478
# Epoch 52/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0629 - root_mean_squared_error: 0.2508
# Epoch 53/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0613 - root_mean_squared_error: 0.2476
# Epoch 54/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0611 - root_mean_squared_error: 0.2472
# Epoch 55/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0944 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0638 - root_mean_squared_error: 0.2526
# Epoch 56/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2488
# Epoch 57/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0923 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0616 - root_mean_squared_error: 0.2483
# Epoch 58/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2487
# Epoch 59/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0923 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0616 - root_mean_squared_error: 0.2482
# Epoch 60/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0612 - root_mean_squared_error: 0.2474
# Epoch 61/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0622 - root_mean_squared_error: 0.2494
# Epoch 62/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0614 - root_mean_squared_error: 0.2477
# Epoch 63/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0612 - root_mean_squared_error: 0.2474
# Epoch 64/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0915 - mean_absolute_error: 0.0915 - mean_squared_error: 0.0609 - root_mean_squared_error: 0.2468
# Epoch 65/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0606 - root_mean_squared_error: 0.2462
# Epoch 66/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0602 - root_mean_squared_error: 0.2454
# Epoch 67/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0589 - root_mean_squared_error: 0.2427
# Epoch 68/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0596 - root_mean_squared_error: 0.2442
# Epoch 69/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0923 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0607 - root_mean_squared_error: 0.2464
# Epoch 70/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0595 - root_mean_squared_error: 0.2440
# Epoch 71/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0607 - root_mean_squared_error: 0.2463
# Epoch 72/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0617 - root_mean_squared_error: 0.2484
# Epoch 73/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0933 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2488
# Epoch 74/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0594 - root_mean_squared_error: 0.2437
# Epoch 75/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - mean_squared_error: 0.0598 - root_mean_squared_error: 0.2446
# Epoch 76/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - mean_squared_error: 0.0579 - root_mean_squared_error: 0.2406
# Epoch 77/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0922 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0602 - root_mean_squared_error: 0.2453
# Epoch 78/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0603 - root_mean_squared_error: 0.2455
# Epoch 79/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - mean_squared_error: 0.0591 - root_mean_squared_error: 0.2432
# Epoch 80/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0913 - mean_absolute_error: 0.0913 - mean_squared_error: 0.0574 - root_mean_squared_error: 0.2397
# Epoch 81/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - mean_squared_error: 0.0593 - root_mean_squared_error: 0.2436
# Epoch 82/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0923 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0581 - root_mean_squared_error: 0.2410
# Epoch 83/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0600 - root_mean_squared_error: 0.2450
# Epoch 84/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - mean_squared_error: 0.0589 - root_mean_squared_error: 0.2427
# Epoch 85/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0915 - mean_absolute_error: 0.0915 - mean_squared_error: 0.0581 - root_mean_squared_error: 0.2410
# Epoch 86/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0573 - root_mean_squared_error: 0.2393
# Epoch 87/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0594 - root_mean_squared_error: 0.2437
# Epoch 88/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - mean_squared_error: 0.0585 - root_mean_squared_error: 0.2419
# Epoch 89/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0904 - mean_absolute_error: 0.0904 - mean_squared_error: 0.0561 - root_mean_squared_error: 0.2369
# Epoch 90/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0554 - root_mean_squared_error: 0.2354
# Epoch 91/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0905 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0567 - root_mean_squared_error: 0.2381
# Epoch 92/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0559 - root_mean_squared_error: 0.2365
# Epoch 93/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0583 - root_mean_squared_error: 0.2415
# Epoch 94/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0563 - root_mean_squared_error: 0.2373
# Epoch 95/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0562 - root_mean_squared_error: 0.2371
# Epoch 96/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0568 - root_mean_squared_error: 0.2383
# Epoch 97/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0549 - root_mean_squared_error: 0.2343
# Epoch 98/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2317
# Epoch 99/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0546 - root_mean_squared_error: 0.2337
# Epoch 100/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0535 - root_mean_squared_error: 0.2313
# Epoch 101/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0913 - mean_absolute_error: 0.0913 - mean_squared_error: 0.0557 - root_mean_squared_error: 0.2361
# Epoch 102/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0594 - root_mean_squared_error: 0.2437
# Epoch 103/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0903 - mean_absolute_error: 0.0903 - mean_squared_error: 0.0545 - root_mean_squared_error: 0.2335
# Epoch 104/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0542 - root_mean_squared_error: 0.2328
# Epoch 105/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0895 - mean_absolute_error: 0.0895 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2317
# Epoch 106/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0552 - root_mean_squared_error: 0.2349
# Epoch 107/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0570 - root_mean_squared_error: 0.2387
# Epoch 108/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0556 - root_mean_squared_error: 0.2357
# Epoch 109/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - mean_squared_error: 0.0571 - root_mean_squared_error: 0.2390
# Epoch 110/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2322
# Epoch 111/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2317
# Epoch 112/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0536 - root_mean_squared_error: 0.2314
# Epoch 113/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0907 - mean_absolute_error: 0.0907 - mean_squared_error: 0.0560 - root_mean_squared_error: 0.2367
# Epoch 114/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0870 - mean_absolute_error: 0.0870 - mean_squared_error: 0.0516 - root_mean_squared_error: 0.2272
# Epoch 115/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0526 - root_mean_squared_error: 0.2294
# Epoch 116/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0536 - root_mean_squared_error: 0.2315
# Epoch 117/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0530 - root_mean_squared_error: 0.2303
# Epoch 118/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0524 - root_mean_squared_error: 0.2289
# Epoch 119/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0895 - mean_absolute_error: 0.0895 - mean_squared_error: 0.0531 - root_mean_squared_error: 0.2304
# Epoch 120/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0524 - root_mean_squared_error: 0.2289
# Epoch 121/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2251
# Epoch 122/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0527 - root_mean_squared_error: 0.2297
# Epoch 123/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0541 - root_mean_squared_error: 0.2325
# Epoch 124/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2275
# Epoch 125/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 126/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0543 - root_mean_squared_error: 0.2331
# Epoch 127/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 128/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0905 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0555 - root_mean_squared_error: 0.2356
# Epoch 129/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0518 - root_mean_squared_error: 0.2276
# Epoch 130/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0535 - root_mean_squared_error: 0.2312
# Epoch 131/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0522 - root_mean_squared_error: 0.2286
# Epoch 132/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 133/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0535 - root_mean_squared_error: 0.2313
# Epoch 134/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0538 - root_mean_squared_error: 0.2319
# Epoch 135/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0905 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0551 - root_mean_squared_error: 0.2348
# Epoch 136/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0563 - root_mean_squared_error: 0.2373
# Epoch 137/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - mean_squared_error: 0.0560 - root_mean_squared_error: 0.2367
# Epoch 138/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0540 - root_mean_squared_error: 0.2324
# Epoch 139/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0883 - mean_absolute_error: 0.0883 - mean_squared_error: 0.0508 - root_mean_squared_error: 0.2254
# Epoch 140/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2249
# Epoch 141/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0512 - root_mean_squared_error: 0.2263
# Epoch 142/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2249
# Epoch 143/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0543 - root_mean_squared_error: 0.2331
# Epoch 144/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2317
# Epoch 145/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0513 - root_mean_squared_error: 0.2265
# Epoch 146/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0510 - root_mean_squared_error: 0.2259
# Epoch 147/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0521 - root_mean_squared_error: 0.2283
# Epoch 148/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0512 - root_mean_squared_error: 0.2263
# Epoch 149/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2250
# Epoch 150/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0509 - root_mean_squared_error: 0.2255
# Epoch 151/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0513 - root_mean_squared_error: 0.2264
# Epoch 152/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2275
# Epoch 153/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0497 - root_mean_squared_error: 0.2230
# Epoch 154/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0508 - root_mean_squared_error: 0.2255
# Epoch 155/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0499 - root_mean_squared_error: 0.2234
# Epoch 156/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0495 - root_mean_squared_error: 0.2224
# Epoch 157/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - mean_squared_error: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 158/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2321
# Epoch 159/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0524 - root_mean_squared_error: 0.2288
# Epoch 160/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0493 - root_mean_squared_error: 0.2221
# Epoch 161/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0493 - root_mean_squared_error: 0.2221
# Epoch 162/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0876 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0521 - root_mean_squared_error: 0.2283
# Epoch 163/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0500 - root_mean_squared_error: 0.2237
# Epoch 164/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2250
# Epoch 165/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2322
# Epoch 166/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2155
# Epoch 167/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0897 - mean_absolute_error: 0.0897 - mean_squared_error: 0.0528 - root_mean_squared_error: 0.2297
# Epoch 168/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0493 - root_mean_squared_error: 0.2220
# Epoch 169/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2187
# Epoch 170/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0502 - root_mean_squared_error: 0.2240
# Epoch 171/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 172/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0474 - root_mean_squared_error: 0.2177
# Epoch 173/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0481 - root_mean_squared_error: 0.2193
# Epoch 174/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0518 - root_mean_squared_error: 0.2276
# Epoch 175/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0549 - root_mean_squared_error: 0.2343
# Epoch 176/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0888 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0507 - root_mean_squared_error: 0.2251
# Epoch 177/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0861 - mean_absolute_error: 0.0861 - mean_squared_error: 0.0487 - root_mean_squared_error: 0.2206
# Epoch 178/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0487 - root_mean_squared_error: 0.2206
# Epoch 179/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0486 - root_mean_squared_error: 0.2204
# Epoch 180/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2187
# Epoch 181/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0489 - root_mean_squared_error: 0.2211
# Epoch 182/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0481 - root_mean_squared_error: 0.2193
# Epoch 183/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0488 - root_mean_squared_error: 0.2208
# Epoch 184/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0496 - root_mean_squared_error: 0.2226
# Epoch 185/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0494 - root_mean_squared_error: 0.2223
# Epoch 186/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0538 - root_mean_squared_error: 0.2319
# Epoch 187/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0484 - root_mean_squared_error: 0.2199
# Epoch 188/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0851 - mean_absolute_error: 0.0851 - mean_squared_error: 0.0475 - root_mean_squared_error: 0.2181
# Epoch 189/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2188
# Epoch 190/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2203
# Epoch 191/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0469 - root_mean_squared_error: 0.2166
# Epoch 192/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0473 - root_mean_squared_error: 0.2176
# Epoch 193/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0475 - root_mean_squared_error: 0.2180
# Epoch 194/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2188
# Epoch 195/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0846 - mean_absolute_error: 0.0846 - mean_squared_error: 0.0470 - root_mean_squared_error: 0.2167
# Epoch 196/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0486 - root_mean_squared_error: 0.2205
# Epoch 197/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0489 - root_mean_squared_error: 0.2211
# Epoch 198/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0505 - root_mean_squared_error: 0.2247
# Epoch 199/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0840 - mean_absolute_error: 0.0840 - mean_squared_error: 0.0462 - root_mean_squared_error: 0.2149
# Epoch 200/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0886 - mean_absolute_error: 0.0886 - mean_squared_error: 0.0486 - root_mean_squared_error: 0.2203
# Epoch 201/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0494 - root_mean_squared_error: 0.2222
# Epoch 202/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0494 - root_mean_squared_error: 0.2223
# Epoch 203/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0474 - root_mean_squared_error: 0.2177
# Epoch 204/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0481 - root_mean_squared_error: 0.2192
# Epoch 205/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2189
# Epoch 206/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0483 - root_mean_squared_error: 0.2197
# Epoch 207/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0491 - root_mean_squared_error: 0.2216
# Epoch 208/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2190
# Epoch 209/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - mean_squared_error: 0.0462 - root_mean_squared_error: 0.2151
# Epoch 210/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0460 - root_mean_squared_error: 0.2145
# Epoch 211/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0495 - root_mean_squared_error: 0.2224
# Epoch 212/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0888 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0474 - root_mean_squared_error: 0.2177
# Epoch 213/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2186
# Epoch 214/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0903 - mean_absolute_error: 0.0903 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2274
# Epoch 215/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0496 - root_mean_squared_error: 0.2228
# Epoch 216/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2202
# Epoch 217/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0472 - root_mean_squared_error: 0.2173
# Epoch 218/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0888 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2244
# Epoch 219/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0501 - root_mean_squared_error: 0.2239
# Epoch 220/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0849 - mean_absolute_error: 0.0849 - mean_squared_error: 0.0470 - root_mean_squared_error: 0.2167
# Epoch 221/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0858 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0475 - root_mean_squared_error: 0.2180
# Epoch 222/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0474 - root_mean_squared_error: 0.2178
# Epoch 223/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0881 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0525 - root_mean_squared_error: 0.2291
# Epoch 224/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0468 - root_mean_squared_error: 0.2164
# Epoch 225/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2188
# Epoch 226/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0483 - root_mean_squared_error: 0.2198
# Epoch 227/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0496 - root_mean_squared_error: 0.2227
# Epoch 228/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0469 - root_mean_squared_error: 0.2166
# Epoch 229/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0457 - root_mean_squared_error: 0.2137
# Epoch 230/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0467 - root_mean_squared_error: 0.2160
# Epoch 231/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0844 - mean_absolute_error: 0.0844 - mean_squared_error: 0.0453 - root_mean_squared_error: 0.2129
# Epoch 232/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0876 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0484 - root_mean_squared_error: 0.2199
# Epoch 233/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0493 - root_mean_squared_error: 0.2220
# Epoch 234/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0468 - root_mean_squared_error: 0.2162
# Epoch 235/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0900 - mean_absolute_error: 0.0900 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2202
# Epoch 236/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0455 - root_mean_squared_error: 0.2132
# Epoch 237/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0883 - mean_absolute_error: 0.0883 - mean_squared_error: 0.0501 - root_mean_squared_error: 0.2237
# Epoch 238/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - mean_squared_error: 0.0466 - root_mean_squared_error: 0.2158
# Epoch 239/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0863 - mean_absolute_error: 0.0863 - mean_squared_error: 0.0469 - root_mean_squared_error: 0.2165
# Epoch 240/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0462 - root_mean_squared_error: 0.2149
# Epoch 241/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0451 - root_mean_squared_error: 0.2124
# Epoch 242/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0469 - root_mean_squared_error: 0.2166
# Epoch 243/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0857 - mean_absolute_error: 0.0857 - mean_squared_error: 0.0452 - root_mean_squared_error: 0.2125
# Epoch 244/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0453 - root_mean_squared_error: 0.2128
# Epoch 245/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0480 - root_mean_squared_error: 0.2190
# Epoch 246/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0472 - root_mean_squared_error: 0.2173
# Epoch 247/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0862 - mean_absolute_error: 0.0862 - mean_squared_error: 0.0475 - root_mean_squared_error: 0.2180
# Epoch 248/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2186
# Epoch 249/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0473 - root_mean_squared_error: 0.2174
# Epoch 250/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0853 - mean_absolute_error: 0.0853 - mean_squared_error: 0.0454 - root_mean_squared_error: 0.2131
# Epoch 251/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0475 - root_mean_squared_error: 0.2179
# Epoch 252/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0499 - root_mean_squared_error: 0.2235
# Epoch 253/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0490 - root_mean_squared_error: 0.2214
# Epoch 254/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2157
# Epoch 255/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0468 - root_mean_squared_error: 0.2163
# Epoch 256/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - mean_squared_error: 0.0468 - root_mean_squared_error: 0.2162
# Epoch 257/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0835 - mean_absolute_error: 0.0835 - mean_squared_error: 0.0441 - root_mean_squared_error: 0.2099
# Epoch 258/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2243
# Epoch 259/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0852 - mean_absolute_error: 0.0852 - mean_squared_error: 0.0450 - root_mean_squared_error: 0.2122
# Epoch 260/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2185
# Epoch 261/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0857 - mean_absolute_error: 0.0857 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2157
# Epoch 262/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0466 - root_mean_squared_error: 0.2159
# Epoch 263/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2202
# Epoch 264/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0895 - mean_absolute_error: 0.0895 - mean_squared_error: 0.0494 - root_mean_squared_error: 0.2223
# Epoch 265/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0478 - root_mean_squared_error: 0.2186
# Epoch 266/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0859 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0458 - root_mean_squared_error: 0.2141
# Epoch 267/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0871 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2202
# Epoch 268/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0460 - root_mean_squared_error: 0.2145
# Epoch 269/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0900 - mean_absolute_error: 0.0900 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2274
# Epoch 270/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0858 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2157
# Epoch 271/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0456 - root_mean_squared_error: 0.2135
# Epoch 272/2000
# ...
# Epoch 1911/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0494 - root_mean_squared_error: 0.2222
# Epoch 1912/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0854 - mean_absolute_error: 0.0854 - mean_squared_error: 0.0515 - root_mean_squared_error: 0.2269
# Epoch 1913/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2244
# Epoch 1914/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0515 - root_mean_squared_error: 0.
- mean_squared_error: 0.0496 - root_mean_squared_error: 0.2228
# Epoch 1981/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0835 - mean_absolute_error: 0.0835 - mean_squared_error: 0.0514 - root_mean_squared_error: 0.2267
# Epoch 1982/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0830 - mean_absolute_error: 0.0830 - mean_squared_error: 0.0499 - root_mean_squared_error: 0.2233
# Epoch 1983/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0832 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0518 - root_mean_squared_error: 0.2276
# Epoch 1984/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0845 - mean_absolute_error: 0.0845 - mean_squared_error: 0.0511 - root_mean_squared_error: 0.2260
# Epoch 1985/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0852 - mean_absolute_error: 0.0852 - mean_squared_error: 0.0511 - root_mean_squared_error: 0.2260
# Epoch 1986/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0840 - mean_absolute_error: 0.0840 - mean_squared_error: 0.0507 - root_mean_squared_error: 0.2252
# Epoch 1987/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 1988/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0508 - root_mean_squared_error: 0.2254
# Epoch 1989/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0845 - mean_absolute_error: 0.0845 - mean_squared_error: 0.0510 - root_mean_squared_error: 0.2257
# Epoch 1990/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0504 - root_mean_squared_error: 0.2245
# Epoch 1991/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0838 - mean_absolute_error: 0.0838 - mean_squared_error: 0.0500 - root_mean_squared_error: 0.2235
# Epoch 1992/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0841 - mean_absolute_error: 0.0841 - mean_squared_error: 0.0498 - root_mean_squared_error: 0.2232
# Epoch 1993/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0555 - root_mean_squared_error: 0.2357
# Epoch 1994/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - mean_squared_error: 0.0545 - root_mean_squared_error: 0.2334
# Epoch 1995/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0849 - mean_absolute_error: 0.0849 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2249
# Epoch 1996/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0846 - mean_absolute_error: 0.0846 - mean_squared_error: 0.0530 - root_mean_squared_error: 0.2303
# Epoch 1997/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0835 - mean_absolute_error: 0.0835 - mean_squared_error: 0.0502 - root_mean_squared_error: 0.2241
# Epoch 1998/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0861 - mean_absolute_error: 0.0861 - mean_squared_error: 0.0508 - root_mean_squared_error: 0.2254
# Epoch 1999/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0513 - root_mean_squared_error: 0.2266
# Epoch 2000/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2249

# %%
# summarize results
print("Best parameters: %f using %s\n" % (grid_search.best_score_, grid_search.best_params_))
# Out:
# Best parameters: -0.207961 using {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}

# %%
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.233100 (0.065653) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.220039 (0.062293) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.229159 (0.066194) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.216042 (0.049776) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.287891 (0.121234) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.220788 (0.061676) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.225383 (0.065635) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.212027 (0.055309) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.252018 (0.087298) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.220901 (0.061868) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.225917 (0.068332) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.211468 (0.049112) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.313365 (0.150386) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.221533 (0.063896) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.226719 (0.067415) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.210389 (0.052692) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.288996 (0.125573) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.220066 (0.063677) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.221410 (0.065448) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.213814 (0.051841) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.223128 (0.051773) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.226200 (0.051801) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.238461 (0.066880) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.254423 (0.069997) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.227202 (0.050744) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.229160 (0.054726) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.230074 (0.055990) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.262073 (0.070937) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.232663 (0.044718) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.228231 (0.052553) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.232020 (0.056879) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.268326 (0.060984) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.228249 (0.051626) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.232485 (0.054841) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.243676 (0.049271) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.263681 (0.067524) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.226801 (0.051509) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.234907 (0.046093) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.252840 (0.056996) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.268709 (0.066421) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.254298 (0.091350) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.238590 (0.075495) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.240610 (0.078555) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.214916 (0.051867) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.734058 (0.552510) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.322306 (0.141066) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.242216 (0.071048) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.214514 (0.049901) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.257871 (0.076044) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.228267 (0.063448) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.242785 (0.078922) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.215444 (0.045015) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.252672 (0.085133) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.245162 (0.079845) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.234853 (0.067097) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.208706 (0.051364) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.244770 (0.089957) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.225398 (0.066081) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.234098 (0.066658) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.220466 (0.061778) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.232283 (0.066217) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.225050 (0.061488) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.226996 (0.063916) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.211342 (0.052108) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.341975 (0.174110) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.222485 (0.059883) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.222668 (0.062284) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.207961 (0.050931) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.332241 (0.161632) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.220312 (0.060958) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.224261 (0.066857) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.209569 (0.051696) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.345284 (0.178900) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.226128 (0.067882) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.222631 (0.063100) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.214342 (0.048872) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.437078 (0.273619) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.220116 (0.062743) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.223342 (0.062095) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.212373 (0.052412) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.253213 (0.086717) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.220973 (0.062059) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.231362 (0.065608) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.210742 (0.050970) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.320822 (0.154939) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.219822 (0.061877) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.226295 (0.065540) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.209953 (0.051667) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0
with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.265944 (0.065474) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.220090 (0.057107) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.214440 (0.052629) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.226794 (0.060409) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.227233 (0.060460) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.218712 (0.054924) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.226233 (0.060306) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.218834 (0.055170) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.221446 (0.058312) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.213956 (0.053157) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.226016 (0.057700) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.216256 (0.054649) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.223614 (0.055640) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.214590 (0.054839) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.233196 (0.062698) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.218601 (0.058236) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.222897 (0.054357) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.211284 (0.053424) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.236236 (0.067365) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.217445 (0.058812) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.219637 (0.054186) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.220414 (0.053718) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.219274 (0.053775) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.222353 (0.054623) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.244314 (0.059857) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.220368 (0.057630) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.227928 (0.058783) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.220018 (0.059525) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.249156 (0.059956) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.215841 (0.056601) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.236345 (0.065267) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.218610 (0.060006) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.245636 (0.060998) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.216511 (0.058080) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.242500 (0.061822) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.218506 (0.060532) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.243428 (0.059302) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.215371 (0.057452) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.237479 (0.058897) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.214926 (0.058376) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.249065 (0.060878) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.243137 (0.061554) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.246217 (0.060732) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.244729 (0.058715) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.265634 (0.064656) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.260116 (0.064249) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.248030 (0.061822) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.249762 (0.058160) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.268217 (0.063538) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.266983 (0.068026) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.256226 (0.066316) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.248331 (0.053433) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.271064 (0.063690) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.267459 (0.066443) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.261657 (0.067609) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.255371 (0.057418) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.270765 (0.063100) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.268227 (0.067330) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.265043 (0.065269) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.264492 (0.068713) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.270407 (0.065323) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}

# %%
result = pd.concat([pd.DataFrame(grid_search.cv_results_["params"]),pd.DataFrame(grid_search.cv_results_["mean_test_score"], columns=["score"])],axis=1)

# %%
result.sort_values(by="score", ascending=False)
# Out:
#      batch_size  epochs model__activation  model__dropout_rate  \
# 67            2    2000              selu                 0.10
# 187           4    2000              selu                 0.10
# 195           4    2000              selu                 0.20
# 307           8    2000              selu                 0.10
# 55            2    2000              relu                 0.20
# ..          ...     ...               ...                  ...
# 166           4    2000              relu                 0.10
# 168           4    2000              relu                 0.15
# 288           8    2000              relu                 0.15
# 296           8    2000              relu                 0.25
# 44            2    2000              relu                 0.10
#
#     model__optimizer     score
# 67               sgd -0.207961
# 187              sgd -0.208168
# 195              sgd -0.208442
# 307              sgd -0.208662
# 55               sgd -0.208706
# ..               ...       ...
# 166          rmsprop -0.485481
# 168             adam -0.487296
# 288             adam -0.525252
# 296             adam -0.570153
# 44              adam -0.734058
#
# [600 rows x 6 columns]

# %%
result.sort_values(by="score", ascending=False).to_csv('gridsearch_percobaan1.csv',index=False)

# %% [markdown]
# ### Evaluasi Model LSTM-RNN

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 03:49:12.71
