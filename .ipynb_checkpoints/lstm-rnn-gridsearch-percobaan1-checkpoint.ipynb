# %% [markdown]
# ### Hyperparameter GridSearchCV LSTM-RNN Percobaan 1

# %% [markdown]
# ### 1. Declaration Library

# %%
import warnings
warnings.filterwarnings("ignore")

# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library configuration date and time
import time
from datetime import datetime

# library data visualization
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# library analysis acf and pacf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# library algorithm lstm-rnn with keras
import tensorflow as tf
from tensorflow.keras import models
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# Early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# library evaluation model
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
# fix random seed for reproducibility
np.random.seed(1234)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
# set index tanggal
# dataset = dataset.set_index("tanggal")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tanggal         240 non-null    datetime64[ns]
#  1   sst             240 non-null    float64
#  2   soi             240 non-null    float64
#  3   oni             240 non-null    float64
#  4   curah_hujan     240 non-null    float64
#  5   hotspot_sumsel  240 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.4 KB

# %%
print(dataset.head())
# Out:
#      tanggal   sst  soi   oni  curah_hujan  hotspot_sumsel
# 0 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 1 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 3 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 4 2001-05-31 -0.46 -0.5 -0.25   116.900002              39

# %% [markdown]
# ### 3. Exploration Data Analysis

# %% [markdown]
# - Data Visualization

# %%
# make frame
fig, ax = plt.subplots(figsize = (20,6))

# make time series plot
ax.plot(dataset["tanggal"], dataset["hotspot_sumsel"], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax.set_xlabel("Date", fontsize=12)
ax.set_ylabel("Sum of hostpot", fontsize=12)
ax.legend(loc='best')
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# - Analysis ACF and PACF

# %%
# make frame
fig, ax= plt.subplots(nrows=1, ncols=2, facecolor="#F0F0F0", figsize = (20,5))

# plot acf
plot_acf(dataset["hotspot_sumsel"], lags=24, ax=ax[0])
ax[0].grid(True)

# plot pacf
plot_pacf(dataset["hotspot_sumsel"],lags=24, ax=ax[1], method="yw")
ax[1].grid(True)

# show plot acf and pacf
plt.show()

# %% [markdown]
# ### 4. Praproses Data

# %% [markdown]
# - feature selection (studi kasus sumatera selatan)

# %%
# memilih area studi
df_sumsel = dataset[["hotspot_sumsel"]]

# %%
# ensure all data is float
df_sumsel = df_sumsel.values
df_sumsel = df_sumsel.astype('float64')

# %%
# show a dataset
np.round(df_sumsel[:5],7)
# Out:
# array([[ 3.],
#        [ 5.],
#        [10.],
#        [20.],
#        [39.]])

# %%
# view a dimension dataset
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="data aktual", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - normalization data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
df_sumsel = scaler.fit_transform(df_sumsel)

# %%
# show a dataset after normalize
np.round(df_sumsel[:5],7)
# Out:
# array([[0.0001387],
#        [0.0002775],
#        [0.0006243],
#        [0.0013181],
#        [0.0026361]])

# %%
# view a dimension dataset after normalize
df_sumsel.shape
# Out:
# (240, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,6))

# membuat time series plot
ax.plot(dataset["tanggal"], df_sumsel, color="tab:blue", label="data aktual", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - set data train and data test

# %%
# set data train
train_size = int(len(df_sumsel) * 0.8)

# %%
# set loc data train
train= df_sumsel[0:train_size,:]

# %%
# show data train
np.round(train[:5],7)
# Out:
# array([[0.0001387],
#        [0.0002775],
#        [0.0006243],
#        [0.0013181],
#        [0.0026361]])

# %%
# view dimension of data train
train.shape
# Out:
# (192, 1)

# %%
# set data test
test_size = len(df_sumsel) - train_size

# %%
# set loc data test
test = df_sumsel[train_size:len(df_sumsel),:]

# %%
# show data test
np.round(test[:5],6)
# Out:
# array([[0.000763],
#        [0.000139],
#        [0.001249],
#        [0.001318],
#        [0.002775]])

# %%
# view dimension of data test
test.shape
# Out:
# (48, 1)

# %%
# make a frame
fig, ax = plt.subplots(figsize = (20,7))

# make a time series plot
ax.plot(dataset.iloc[0:train_size,0], train, color="tab:blue", label="Data Latih", linewidth=2.5)
ax.plot(dataset.iloc[train_size:len(dataset),0], test, color="tab:red", label="Data Uji", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# ### 5. Supervised Learning

# %%
# function for supervised learning
def create_dataset(dataset, look_back=1):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(len(dataset)-look_back):
        
        # insert value X and Y 
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# - process supervised learning, with look back t-1 into X=t and Y=t+1

# %%
# set look back -1
look_back = 1

# %%
# set supervised learning for data train
trainX, trainY = create_dataset(train, look_back)

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (191, 1) (191,)

# %%
# set supervised learning for data test
testX, testY = create_dataset(test, look_back)

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (47, 1) (47,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX, columns=['x train'])
temp_trainY = pd.DataFrame(trainY, columns=['y train'])

# %%
hasil = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x train  191 non-null    float64
#  1   y train  191 non-null    float64
# dtypes: float64(2)
# memory usage: 3.1 KB

# %%
hasil.head()
# Out:
#     x train   y train
# 0  0.000139  0.000277
# 1  0.000277  0.000624
# 2  0.000624  0.001318
# 3  0.001318  0.002636
# 4  0.002636  0.000486

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX, columns=['x test'])
temp_testY = pd.DataFrame(testY, columns=['y test'])

# %%
hasil = pd.concat([temp_testX, temp_testY], axis=1)
hasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x test  47 non-null     float64
#  1   y test  47 non-null     float64
# dtypes: float64(2)
# memory usage: 880.0 bytes

# %%
hasil.head()
# Out:
#      x test    y test
# 0  0.000763  0.000139
# 1  0.000139  0.001249
# 2  0.001249  0.001318
# 3  0.001318  0.002775
# 4  0.002775  0.004232

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (191, 1, 1) (191,)

# %%
# reshape data test
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
print(testX.shape, testY.shape)
# Out:
# (47, 1, 1) (47,)

# %% [markdown]
# ### 6. Hyperparameter GridSearchCV LSTM-RNN

# %% [markdown]
# - library for hyperparameter

# %%
from scikeras.wrappers import KerasRegressor
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# - set models lstm-rnn with sliding windows and timestep

# %%
# function models lstm-rnn
def get_model(activation='tanh', optimizer='adam', dropout_rate=0.0):
    
    # reset of session model
    tf.keras.backend.clear_session()
    
    # design network
    model = Sequential()
    
    # first LSTM-RNN layer with dropout regularisation
    model.add(LSTM(units=10, activation=activation, input_shape=(trainX.shape[1], 1)))
    model.add(Dropout(dropout_rate))
    
    # the output layer
    model.add(Dense(1))

    # compiling model the LSTM-RNN
    model.compile(
        optimizer=optimizer,
        loss="mae",
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(),
            tf.keras.metrics.MeanSquaredError(),
            tf.keras.metrics.RootMeanSquaredError()
        ]
    )
    
    # return value
    return model

# %% [markdown]
# Set parameter
# - activation function = tanh, sigmoid, relu, selu, softplus, elu.
# - optimizers = adam, adamax, rmsprop, sgd.
# - droupout = 0.00, 0.05, 0.1, 0.15, 0.2, 0.25
# - batch size = 2, 4, 8, 16, 32, 64
# - epoch = 500, 1000, 1500, 2000

# %%
# set parameter activation
activation = ['tanh', 'sigmoid', 'relu', 'selu', 'elu', 'softplus']

# %%
# set parameter optimizer
optimizer = ['adam', 'adamax', 'rmsprop', 'sgd']

# %%
# set parameter dropout_rate
dropout_rate = [0.00, 0.05, 0.1, 0.15, 0.2, 0.25]

# %%
# set parameters batch sizes
batch_size = [2, 4, 8, 16, 32]

# %%
# set parameter epochs
epochs = [2000]

# %%
# set all parameter to dictionary
param_grid = dict(
    model__activation=activation,
    model__optimizer=optimizer,
    model__dropout_rate=dropout_rate,
    batch_size=batch_size,
    epochs=epochs
)

# %%
# show parameter a gridsearch
param_grid
# Out:
# {'model__activation': ['tanh', 'sigmoid', 'relu', 'selu', 'elu', 'softplus'],
#  'model__optimizer': ['adam', 'adamax', 'rmsprop', 'sgd'],
#  'model__dropout_rate': [0.0, 0.05, 0.1, 0.15, 0.2, 0.25],
#  'batch_size': [2, 4, 8, 16, 32],
#  'epochs': [2000]}

# %%
# set grid model with KerasRegressor
grid_model = KerasRegressor(model=get_model, verbose=1)

# %%
# process a gridsearchCV
grid_search = GridSearchCV(estimator=grid_model, param_grid=param_grid, n_jobs=-1, cv=2, scoring='neg_root_mean_squared_error')

# %%
# show a result gridsearchCV
grid_result = grid_search.fit(trainX, trainY)
# Out:
# Epoch 1/2000
# 96/96 [==============================] - 2s 2ms/step - loss: 0.0490 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0190 - root_mean_squared_error: 0.1380
# Epoch 2/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0481 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0184 - root_mean_squared_error: 0.1356
# Epoch 3/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0472 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0179 - root_mean_squared_error: 0.1339
# Epoch 4/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0178 - root_mean_squared_error: 0.1333
# Epoch 5/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0463 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0173 - root_mean_squared_error: 0.1314
# Epoch 6/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0174 - root_mean_squared_error: 0.1319
# Epoch 7/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0169 - root_mean_squared_error: 0.1302
# Epoch 8/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0167 - root_mean_squared_error: 0.1293
# Epoch 9/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0164 - root_mean_squared_error: 0.1282
# Epoch 10/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0161 - root_mean_squared_error: 0.1269
# Epoch 11/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0158 - root_mean_squared_error: 0.1255
# Epoch 12/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0156 - root_mean_squared_error: 0.1248
# Epoch 13/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0160 - root_mean_squared_error: 0.1264
# Epoch 14/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0160 - root_mean_squared_error: 0.1265
# Epoch 15/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0151 - root_mean_squared_error: 0.1230
# Epoch 16/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0447 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0151 - root_mean_squared_error: 0.1228
# Epoch 17/2000
# 96/96 [==============================] - 0s 1ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0163 - root_mean_squared_error: 0.1276
# Epoch 18/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0145 - root_mean_squared_error: 0.1202
# Epoch 19/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 20/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0159 - root_mean_squared_error: 0.1259
# Epoch 21/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0440 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0140 - root_mean_squared_error: 0.1183
# Epoch 22/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0137 - root_mean_squared_error: 0.1169
# Epoch 23/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0160 - root_mean_squared_error: 0.1265
# Epoch 24/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0155 - root_mean_squared_error: 0.1247
# Epoch 25/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0133 - root_mean_squared_error: 0.1155
# Epoch 26/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0131 - root_mean_squared_error: 0.1145
# Epoch 27/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 28/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0430 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0128 - root_mean_squared_error: 0.1130
# Epoch 29/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1128
# Epoch 30/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0433 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0126 - root_mean_squared_error: 0.1124
# Epoch 31/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0428 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1117
# Epoch 32/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0430 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0126 - root_mean_squared_error: 0.1120
# Epoch 33/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0433 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1125
# Epoch 34/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0425 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1117
# Epoch 35/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0431 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0131 - root_mean_squared_error: 0.1144
# Epoch 36/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0131 - root_mean_squared_error: 0.1144
# Epoch 37/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0428 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1116
# Epoch 38/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0440 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0129 - root_mean_squared_error: 0.1137
# Epoch 39/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0438 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 40/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0124 - root_mean_squared_error: 0.1115
# Epoch 41/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0123 - root_mean_squared_error: 0.
2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0118 - root_mean_squared_error: 0.1086
# Epoch 1939/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0429 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1128
# Epoch 1940/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0400 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0116 - root_mean_squared_error: 0.1079
# Epoch 1941/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1120
# Epoch 1942/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_absolute_error: 0.0394 - mean_squared_error: 0.0095 - root_mean_squared_error: 0.0974
# Epoch 1943/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0120 - root_mean_squared_error: 0.1097
# Epoch 1944/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0144 - root_mean_squared_error: 0.1202
# Epoch 1945/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 1946/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1126
# Epoch 1947/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0419 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0135 - root_mean_squared_error: 0.1162
# Epoch 1948/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0124 - root_mean_squared_error: 0.1114
# Epoch 1949/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0123 - root_mean_squared_error: 0.1111
# Epoch 1950/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0159 - root_mean_squared_error: 0.1260
# Epoch 1951/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0122 - root_mean_squared_error: 0.1106
# Epoch 1952/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1128
# Epoch 1953/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0384 - mean_absolute_error: 0.0384 - mean_squared_error: 0.0096 - root_mean_squared_error: 0.0980
# Epoch 1954/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0158 - root_mean_squared_error: 0.1257
# Epoch 1955/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0098 - root_mean_squared_error: 0.0989
# Epoch 1956/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0121 - root_mean_squared_error: 0.1100
# Epoch 1957/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0423 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0126 - root_mean_squared_error: 0.1124
# Epoch 1958/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0417 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0121 - root_mean_squared_error: 0.1101
# Epoch 1959/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0124 - root_mean_squared_error: 0.1113
# Epoch 1960/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0381 - mean_absolute_error: 0.0381 - mean_squared_error: 0.0091 - root_mean_squared_error: 0.0951
# Epoch 1961/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0121 - root_mean_squared_error: 0.1102
# Epoch 1962/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1117
# Epoch 1963/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0124 - root_mean_squared_error: 0.1114
# Epoch 1964/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0401 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0118 - root_mean_squared_error: 0.1085
# Epoch 1965/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0132 - root_mean_squared_error: 0.1148
# Epoch 1966/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0429 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0136 - root_mean_squared_error: 0.1168
# Epoch 1967/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0399 - mean_absolute_error: 0.0399 - mean_squared_error: 0.0122 - root_mean_squared_error: 0.1106
# Epoch 1968/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0415 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0128 - root_mean_squared_error: 0.1133
# Epoch 1969/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0401 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0103 - root_mean_squared_error: 0.1015
# Epoch 1970/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1116
# Epoch 1971/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0398 - mean_absolute_error: 0.0398 - mean_squared_error: 0.0120 - root_mean_squared_error: 0.1095
# Epoch 1972/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0130 - root_mean_squared_error: 0.1140
# Epoch 1973/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1129
# Epoch 1974/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0137 - root_mean_squared_error: 0.1172
# Epoch 1975/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0157 - root_mean_squared_error: 0.1253
# Epoch 1976/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0411 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0130 - root_mean_squared_error: 0.1142
# Epoch 1977/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1120
# Epoch 1978/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0415 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0121 - root_mean_squared_error: 0.1099
# Epoch 1979/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0415 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0121 - root_mean_squared_error: 0.1100
# Epoch 1980/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0118 - root_mean_squared_error: 0.1087
# Epoch 1981/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0151 - root_mean_squared_error: 0.1229
# Epoch 1982/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0123 - root_mean_squared_error: 0.1108
# Epoch 1983/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0123 - root_mean_squared_error: 0.1109
# Epoch 1984/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0425 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0151 - root_mean_squared_error: 0.1227
# Epoch 1985/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0128 - root_mean_squared_error: 0.1131
# Epoch 1986/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0137 - root_mean_squared_error: 0.1169
# Epoch 1987/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0409 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0121 - root_mean_squared_error: 0.1099
# Epoch 1988/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0128 - root_mean_squared_error: 0.1132
# Epoch 1989/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0419 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0132 - root_mean_squared_error: 0.1150
# Epoch 1990/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0126 - root_mean_squared_error: 0.1122
# Epoch 1991/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0123 - root_mean_squared_error: 0.1108
# Epoch 1992/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0411 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0129 - root_mean_squared_error: 0.1134
# Epoch 1993/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0127 - root_mean_squared_error: 0.1128
# Epoch 1994/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0157 - root_mean_squared_error: 0.1251
# Epoch 1995/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0410 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0128 - root_mean_squared_error: 0.1132
# Epoch 1996/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0441 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0138 - root_mean_squared_error: 0.1175
# Epoch 1997/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0125 - root_mean_squared_error: 0.1120
# Epoch 1998/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0410 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0130 - root_mean_squared_error: 0.1138
# Epoch 1999/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0401 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0124 - root_mean_squared_error: 0.1113
# Epoch 2000/2000
# 96/96 [==============================] - 0s 2ms/step - loss: 0.0444 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0141 - root_mean_squared_error: 0.1187

# %%
# summarize results
print("Best parameters: %f using %s\n" % (grid_search.best_score_, grid_search.best_params_))
# Out:
# Best parameters: -0.102401 using {'batch_size': 2, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}

# %%
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.113303 (0.031516) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.0, 'model__optimizer': 'adam'}
# -0.107550 (0.025722) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.0, 'model__optimizer': 'adamax'}
# -0.106983 (0.030485) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.0, 'model__optimizer': 'rmsprop'}
# -0.106309 (0.026338) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.0, 'model__optimizer': 'sgd'}
# -0.112342 (0.030161) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.105806 (0.025270) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.105253 (0.025712) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.106653 (0.026627) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.112166 (0.029859) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.104958 (0.024773) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.104059 (0.025444) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.106319 (0.025625) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.110898 (0.030197) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.104660 (0.024894) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.103964 (0.026389) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.106118 (0.021944) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.110951 (0.030918) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.104179 (0.024830) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.103878 (0.026039) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.105051 (0.024817) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.110734 (0.029934) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.104721 (0.024581) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.102964 (0.027016) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.104652 (0.024570) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'tanh', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.105725 (0.025085) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.0, 'model__optimizer': 'adam'}
# -0.106254 (0.024996) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.0, 'model__optimizer': 'adamax'}
# -0.105280 (0.025368) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.0, 'model__optimizer': 'rmsprop'}
# -0.103904 (0.025317) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.0, 'model__optimizer': 'sgd'}
# -0.109766 (0.027530) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.113039 (0.031245) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.109181 (0.027764) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.139791 (0.028502) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.110094 (0.028517) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.117098 (0.031825) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.110687 (0.027827) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.137696 (0.029352) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.110447 (0.027558) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.120166 (0.031191) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.111777 (0.027099) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.137348 (0.027563) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.111376 (0.027087) with: {'batch_size': 2, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0
with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.124044 (0.030637) with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.116261 (0.033986) with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.134345 (0.033821) with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.112448 (0.026702) with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.124399 (0.031605) with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.115958 (0.028026) with: {'batch_size': 8, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# ...
# -0.131518 (0.032437) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.131953 (0.033416) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.135959 (0.031689) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.132536 (0.032985) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.133667 (0.032603) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.133574 (0.034467) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.135623 (0.032276) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.130997 (0.031440) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.134727 (0.032233) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.134140 (0.032528) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.135478 (0.031054) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'sigmoid', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.123404 (0.041822) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.0, 'model__optimizer': 'adam'}
# -0.106627 (0.025555) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.0, 'model__optimizer': 'adamax'}
# -0.106447 (0.025011) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.0, 'model__optimizer': 'rmsprop'}
# -0.124618 (0.026700) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.0, 'model__optimizer': 'sgd'}
# -0.116026 (0.040061) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.107211 (0.024945) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.107029 (0.024351) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.135717 (0.032176) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.103245 (0.026040) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.106908 (0.024457) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.107179 (0.024064) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.122823 (0.031088) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.106062 (0.026710) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.107247 (0.026986) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.104592 (0.024695) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.123989 (0.030926) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.104122 (0.025881) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.104634 (0.025298) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.103763 (0.025962) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.121309 (0.031111) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.104639 (0.025212) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.105794 (0.025964) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.124361 (0.045880) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.128293 (0.032991) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'relu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.120641 (0.039065) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.0, 'model__optimizer': 'adam'}
# -0.107489 (0.026633) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.0, 'model__optimizer': 'adamax'}
# -0.109736 (0.028223) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.0, 'model__optimizer': 'rmsprop'}
# -0.110224 (0.028685) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.0, 'model__optimizer': 'sgd'}
# -0.106624 (0.026600) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.105619 (0.025290) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.106315 (0.025155) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.108075 (0.027358) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.104814 (0.024724) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.104115 (0.024946) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.103542 (0.025362) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.109841 (0.026149) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.105024 (0.025955) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.103927 (0.024470) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.104179 (0.024982) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.112840 (0.033332) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.105302 (0.026272) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.103795 (0.025281) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.104415 (0.025973) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.108995 (0.023909) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.105071 (0.026637) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.104290 (0.024999) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.104476 (0.025549) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.107508 (0.023754) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'selu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.108375 (0.028906) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.0, 'model__optimizer': 'adam'}
# -0.106596 (0.025175) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.0, 'model__optimizer': 'adamax'}
# -0.107266 (0.026381) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.0, 'model__optimizer': 'rmsprop'}
# -0.119836 (0.031241) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.0, 'model__optimizer': 'sgd'}
# -0.104690 (0.026593) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.104719 (0.024221) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.104927 (0.025455) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.117674 (0.026252) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.104211 (0.026036) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.104399 (0.024652) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.104163 (0.025434) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.122389 (0.035141) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.104448 (0.025577) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.103883 (0.024660) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.103391 (0.025441) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.124377 (0.027810) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.104485 (0.024924) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.104234 (0.024746) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.103598 (0.025219) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.122317 (0.028958) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.104497 (0.025517) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.104233 (0.025290) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.103495 (0.026180) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.119496 (0.028947) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'elu', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}
# -0.106277 (0.024824) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.0, 'model__optimizer': 'adam'}
# -0.106378 (0.024808) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.0, 'model__optimizer': 'adamax'}
# -0.106319 (0.023886) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.0, 'model__optimizer': 'rmsprop'}
# -0.126210 (0.032995) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.0, 'model__optimizer': 'sgd'}
# -0.124496 (0.031921) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'adam'}
# -0.116414 (0.028656) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'adamax'}
# -0.123485 (0.030495) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'rmsprop'}
# -0.136507 (0.030994) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.05, 'model__optimizer': 'sgd'}
# -0.128351 (0.029034) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'adam'}
# -0.129299 (0.031819) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'adamax'}
# -0.130029 (0.031012) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'rmsprop'}
# -0.133724 (0.030642) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.1, 'model__optimizer': 'sgd'}
# -0.127472 (0.030321) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'adam'}
# -0.131734 (0.033117) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'adamax'}
# -0.131535 (0.032573) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'rmsprop'}
# -0.136474 (0.031778) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.15, 'model__optimizer': 'sgd'}
# -0.132859 (0.033971) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'adam'}
# -0.132281 (0.033339) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'adamax'}
# -0.132874 (0.033788) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'rmsprop'}
# -0.136757 (0.033878) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.2, 'model__optimizer': 'sgd'}
# -0.128604 (0.030450) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'adam'}
# -0.134247 (0.032795) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'adamax'}
# -0.134674 (0.032359) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'rmsprop'}
# -0.134605 (0.028338) with: {'batch_size': 32, 'epochs': 2000, 'model__activation': 'softplus', 'model__dropout_rate': 0.25, 'model__optimizer': 'sgd'}

# %%
# result = pd.concat([pd.DataFrame(grid_search.cv_results_["params"]),pd.DataFrame(grid_search.cv_results_["mean_test_score"], columns=["score"])],axis=1)

# %%
# result.sort_values(by="score", ascending=False)

# %%
# result.sort_values(by="score", ascending=False).to_csv('gridsearch_percobaan1.csv',index=False)

# %% [markdown]
# ### Evaluasi Model LSTM-RNN

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 04:44:45.16

# %%
len(params)
# Out:
# 720
