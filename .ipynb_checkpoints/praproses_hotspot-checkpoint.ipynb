# %% [markdown]
# ## Pra Proses Data Hotspot Sensor MODIS

# %%
# => load file lain
from ipynb.fs.full.class_akuisisi_data import *
from ipynb.fs.full.class_praproses_data import *
from ipynb.fs.full.class_visualisasi_data import *

# %% [markdown]
# ### Membaca dataset hotspot MODIS

# %%
# => proses membaca dataset
# 2001 - 2020
df_hotspot_modis = data_hotspot("modis_indonesia_2001_2020.csv")

# %%
df_hotspot_modis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413327 entries, 0 to 1413326
# Data columns (total 15 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   latitude    1413327 non-null  float64
#  1   longitude   1413327 non-null  float64
#  2   brightness  1413327 non-null  float64
#  3   scan        1413327 non-null  float64
#  4   track       1413327 non-null  float64
#  5   acq_date    1413327 non-null  datetime64[ns]
#  6   acq_time    1413327 non-null  int64
#  7   satellite   1413327 non-null  object
#  8   instrument  1413327 non-null  object
#  9   confidence  1413327 non-null  int64
#  10  version     1413327 non-null  float64
#  11  bright_t31  1413327 non-null  float64
#  12  frp         1413327 non-null  float64
#  13  daynight    1413327 non-null  object
#  14  type        1413327 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(3)
# memory usage: 172.5+ MB

# %%
df_hotspot_modis
# Out:
#          latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0         -4.0082   121.7859       312.0   2.3    1.5 2001-01-01       258
# 1         -8.4164   117.5434       320.0   1.3    1.1 2001-01-01       259
# 2         -8.1135   112.9281       359.1   1.1    1.0 2001-01-01       259
# 3         -8.1127   112.9221       309.8   1.0    1.0 2001-01-01      1516
# 4         -6.9726   107.6152       314.3   1.4    1.2 2001-01-02       342
# ...           ...        ...         ...   ...    ...        ...       ...
# 1413321   -2.9151   129.2944       314.7   1.1    1.1 2020-12-31       451
# 1413322   -3.3010   128.9608       316.6   1.2    1.1 2020-12-31       451
# 1413323   -2.5754   121.3848       313.9   1.2    1.1 2020-12-31      1416
# 1413324   -2.5768   121.3746       347.1   1.2    1.1 2020-12-31      1416
# 1413326   -1.4573   127.4369       316.1   1.1    1.1 2020-12-31      1713
#
#         satellite instrument  confidence  version  bright_t31   frp daynight  \
# 0           Terra      MODIS          57     6.03       291.7  22.9        D
# 1           Terra      MODIS          39     6.03       305.8  13.1        D
# 2           Terra      MODIS          99     6.03       310.8  84.3        D
# 3           Terra      MODIS          78     6.03       276.7  13.3        N
# 4           Terra      MODIS          62     6.03       284.7  11.4        D
# ...           ...        ...         ...      ...         ...   ...      ...
# 1413321      Aqua      MODIS          54     6.03       299.5   9.6        D
# 1413322      Aqua      MODIS          32     6.03       299.0   9.2        D
# 1413323     Terra      MODIS          84     6.03       281.1  17.3        N
# 1413324     Terra      MODIS         100     6.03       281.9  73.0        N
# 1413326      Aqua      MODIS          90     6.03       292.1  15.4        N
#
#          type
# 0           0
# 1           0
# 2           1
# 3           1
# 4           2
# ...       ...
# 1413321     2
# 1413322     0
# 1413323     2
# 1413324     2
# 1413326     2
#
# [1413327 rows x 15 columns]

# %% [markdown]
# ### Aggregasi data hotspot MODIS Indonesia

# %% [markdown]
# - Data harian

# %%
df_hotspot_modis_indo_harian = hotspot_harian(df_hotspot_modis)
df_hotspot_modis_indo_harian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7222 entries, 2001-01-01 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  7222 non-null   int64
# dtypes: int64(1)
# memory usage: 112.8 KB

# %%
df_hotspot_modis_indo_harian
# Out:
#             hotspot
# acq_date
# 2001-01-01        4
# 2001-01-02        1
# 2001-01-03        2
# 2001-01-04        1
# 2001-01-05        1
# ...             ...
# 2020-12-27       25
# 2020-12-28        5
# 2020-12-29        1
# 2020-12-30        6
# 2020-12-31        8
#
# [7222 rows x 1 columns]

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_indo_harian.index.values,
                   df_hotspot_modis_indo_harian["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot harian", "Hotspot Indonesia tahun 2001 - 2020", "True")

# %% [markdown]
# - Data Bulanan

# %%
df_hotspot_modis_indo_bulanan = hotspot_bulanan(df_hotspot_modis)
df_hotspot_modis_indo_bulanan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  240 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8 KB

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_indo_bulanan.index.values,
                   df_hotspot_modis_indo_bulanan["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot bulanan", "Hotspot Indonesia tahun 2001 - 2020", "True")

# %% [markdown]
# - Data Tahunan

# %%
df_hotspot_modis_indo_tahunan = hotspot_tahunan(df_hotspot_modis)
df_hotspot_modis_indo_tahunan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2001-12-31 to 2020-12-31
# Freq: A-DEC
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  20 non-null     int64
# dtypes: int64(1)
# memory usage: 320.0 bytes

# %%
df_hotspot_modis_indo_tahunan
# Out:
#             hotspot
# acq_date
# 2001-12-31    15078
# 2002-12-31   123327
# 2003-12-31    62751
# 2004-12-31   107117
# 2005-12-31    74797
# 2006-12-31   154985
# 2007-12-31    43224
# 2008-12-31    41161
# 2009-12-31   102344
# 2010-12-31    20792
# 2011-12-31    62431
# 2012-12-31    71135
# 2013-12-31    53852
# 2014-12-31   115121
# 2015-12-31   178578
# 2016-12-31    24061
# 2017-12-31    17823
# 2018-12-31    38074
# 2019-12-31    90475
# 2020-12-31    16201

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_indo_tahunan.index.values,
                   df_hotspot_modis_indo_tahunan["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot Tahunan", "Hotspot Indonesia tahun 2001 - 2020", "True")

# %% [markdown]
# ### Membaca data hotspot MODIS Riau

# %%
df_hotspot_modis_riau = data_hotspot("modis_riau.csv")
df_hotspot_modis_riau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209469 entries, 118366 to 150488
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    209469 non-null  float64
#  1   longitude   209469 non-null  float64
#  2   brightness  209469 non-null  float64
#  3   scan        209469 non-null  float64
#  4   track       209469 non-null  float64
#  5   acq_date    209469 non-null  datetime64[ns]
#  6   acq_time    209469 non-null  int64
#  7   satellite   209469 non-null  object
#  8   instrument  209469 non-null  object
#  9   confidence  209469 non-null  int64
#  10  version     209469 non-null  object
#  11  bright_t31  209469 non-null  float64
#  12  frp         209469 non-null  float64
#  13  daynight    209469 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(4)
# memory usage: 24.0+ MB

# %%
df_hotspot_modis_riau
# Out:
#         latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 118366    0.0546   101.7350       312.4   1.5    1.2 2001-01-05       411
# 164483    2.0100   100.4560       314.3   1.0    1.0 2001-01-07       358
# 101155   -0.3251   102.1828       308.6   1.1    1.0 2001-01-09       346
# 118367    0.6915   101.0278       308.3   1.2    1.1 2001-01-09       346
# 101156   -0.3618   101.8677       314.1   1.7    1.3 2001-01-11       334
# ...          ...        ...         ...   ...    ...        ...       ...
# 164480    0.5380   101.9480       315.1   1.2    1.1 2020-12-22       635
# 150487    0.8440   102.2810       312.0   2.7    1.6 2020-12-25       410
# 164481    0.7150   102.1070       308.3   2.6    1.6 2020-12-25       410
# 164482    0.7200   102.1140       307.6   2.6    1.6 2020-12-25       410
# 150488    1.0030   102.7120       312.9   1.6    1.3 2020-12-27       355
#
#        satellite instrument  confidence version  bright_t31   frp daynight
# 118366     Terra      MODIS          60    6.03       284.5  12.7        D
# 164483     Terra      MODIS          66    6.03       300.4   7.5        D
# 101155     Terra      MODIS          47    6.03       288.2   6.5        D
# 118367     Terra      MODIS          37    6.03       286.4   5.0        D
# 101156     Terra      MODIS          61    6.03       293.6  14.6        D
# ...          ...        ...         ...     ...         ...   ...      ...
# 164480      Aqua      MODIS          42  6.0NRT       297.0   9.1        D
# 150487     Terra      MODIS          65  6.0NRT       289.4  28.1        D
# 164481     Terra      MODIS          50  6.0NRT       284.6  21.3        D
# 164482     Terra      MODIS          45  6.0NRT       285.2  18.4        D
# 150488     Terra      MODIS          41  6.0NRT       294.3  14.8        D
#
# [209469 rows x 14 columns]

# %% [markdown]
# ### Aggregasi data hotspot MODIS Riau

# %%
df_hotspot_modis_riau_bulanan = hotspot_bulanan(df_hotspot_modis_riau)
df_hotspot_modis_riau_bulanan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  240 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8 KB

# %%
df_hotspot_modis_riau_bulanan
# Out:
#             hotspot
# acq_date
# 2001-01-31       17
# 2001-02-28      159
# 2001-03-31      479
# 2001-04-30       45
# 2001-05-31       81
# ...             ...
# 2020-08-31      107
# 2020-09-30       31
# 2020-10-31       42
# 2020-11-30       25
# 2020-12-31       35
#
# [240 rows x 1 columns]

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_riau_bulanan.index.values,
                   df_hotspot_modis_riau_bulanan["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot bulanan", "Hotspot Provinsi Riau tahun 2001 - 2020", "True")

# %% [markdown]
# ### Membaca data hotspot MODIS Sumatra Selatan

# %%
df_hotspot_modis_sumsel = data_hotspot("modis_sumsel_v1.csv")
df_hotspot_modis_sumsel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155661 entries, 127864 to 27085
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    155661 non-null  float64
#  1   longitude   155661 non-null  float64
#  2   brightness  155661 non-null  float64
#  3   scan        155661 non-null  float64
#  4   track       155661 non-null  float64
#  5   acq_date    155661 non-null  datetime64[ns]
#  6   acq_time    155661 non-null  int64
#  7   satellite   155661 non-null  object
#  8   instrument  155661 non-null  object
#  9   confidence  155661 non-null  int64
#  10  version     155661 non-null  float64
#  11  bright_t31  155661 non-null  float64
#  12  frp         155661 non-null  float64
#  13  daynight    155661 non-null  object
#  14  type        155661 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(3)
# memory usage: 19.0+ MB

# %%
df_hotspot_modis_sumsel
# Out:
#         latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 127864   -2.8277   104.0809       313.9   1.9    1.3 2001-01-14       405
# 127863   -2.8225   104.0882       313.2   1.9    1.3 2001-01-14       405
# 127862   -2.8201   104.0716       307.4   1.9    1.3 2001-01-14       405
# 127865   -2.8246   104.0782       302.3   1.8    1.3 2001-02-10      1607
# 127866   -2.8216   104.0829       306.1   1.2    1.1 2001-02-23      1536
# ...          ...        ...         ...   ...    ...        ...       ...
# 127842   -2.5987   102.6988       313.5   1.0    1.0 2020-12-04       648
# 154995   -2.6521   103.7410       315.6   1.1    1.0 2020-12-04       648
# 154996   -2.1625   104.3411       311.7   1.0    1.0 2020-12-08       328
# 154997   -1.9285   104.2109       310.6   1.4    1.2 2020-12-08       624
# 27085    -3.7903   103.5361       318.0   1.7    1.3 2020-12-08       623
#
#        satellite instrument  confidence  version  bright_t31   frp daynight  \
# 127864     Terra      MODIS          68     6.03       290.8  19.4        D
# 127863     Terra      MODIS          68     6.03       290.7  17.7        D
# 127862     Terra      MODIS          41     6.03       288.7   7.6        D
# 127865     Terra      MODIS          48     6.03       279.1  11.8        N
# 127866     Terra      MODIS          67     6.03       290.8   7.3        N
# ...          ...        ...         ...      ...         ...   ...      ...
# 127842      Aqua      MODIS          52     6.03       298.4   4.2        D
# 154995      Aqua      MODIS          41     6.03       296.4  10.0        D
# 154996     Terra      MODIS          58     6.03       290.4   5.9        D
# 154997      Aqua      MODIS          33     6.03       291.5   6.7        D
# 27085       Aqua      MODIS          45     6.03       297.7  21.0        D
#
#         type
# 127864     2
# 127863     2
# 127862     2
# 127865     2
# 127866     2
# ...      ...
# 127842     0
# 154995     0
# 154996     0
# 154997     0
# 27085      2
#
# [155661 rows x 15 columns]

# %%
df_hotspot_modis_sumsel_bulanan = hotspot_bulanan(df_hotspot_modis_sumsel)
df_hotspot_modis_sumsel_bulanan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   hotspot  240 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8 KB

# %%
df_hotspot_modis_sumsel_bulanan
# Out:
#             hotspot
# acq_date
# 2001-01-31        3
# 2001-02-28        5
# 2001-03-31       10
# 2001-04-30       20
# 2001-05-31       39
# ...             ...
# 2020-08-31       65
# 2020-09-30       29
# 2020-10-31       40
# 2020-11-30       30
# 2020-12-31        8
#
# [240 rows x 1 columns]

# %%
# Menampilkan plot time serie
visual_time_series(df_hotspot_modis_sumsel_bulanan.index.values,
                   df_hotspot_modis_sumsel_bulanan["hotspot"],
                   "Tanggal", "Frekuensi", "Data hotspot bulanan", "Hotspot Provinsi Sumatra Selatan tahun 2001 - 2020", "True")

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (20,7))

# membuat time series plot
ax.plot(df_hotspot_modis_sumsel_bulanan.index.values, df_hotspot_modis_sumsel_bulanan["hotspot"],
        color="tab:blue", label="Data titik panas bulanan", linewidth=2.5)

# membuat label-label
ax.set_title("Hotspot Provinsi Sumatra Selatan tahun 2001 - 2020", fontsize=14)
ax.set_xlabel("Bulan", fontsize=12)
ax.set_ylabel("Frekuensi", fontsize=12)
ax.legend(loc='upper left')
ax.grid(True)

# Define the date format
date_form = DateFormatter("%b-%Y")
ax.xaxis.set_major_formatter(date_form)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Dekomposisi Musiman Riau

# %%
from jcopml.time_series.decomposition import additive_decomposition
from jcopml.time_series.decomposition import multiplicative_decomposition
from jcopml.time_series.decomposition import stl_decomposition

# %%
dekomposisi_riau = data_hotspot("modis_riau_bulanan.csv")
dekomposisi_riau = dekomposisi_riau.set_index("acq_date")
dekomposisi_riau = dekomposisi_riau.hotspot

# %%
hasil = additive_decomposition(dekomposisi_riau, plot=True)

# %%
hasil = multiplicative_decomposition(dekomposisi_riau, plot=True)

# %%
hasil = stl_decomposition(dekomposisi_riau, plot=True)

# %% [markdown]
# ### Dekomposisi Musiman Sumsel

# %%
dekomposisi_sumsel = data_hotspot("modis_sumsel_bulanan_v2.csv")
dekomposisi_sumsel = dekomposisi_sumsel.set_index("acq_date")
dekomposisi_sumsel = dekomposisi_sumsel.hotspot

# %%
hasil = additive_decomposition(dekomposisi_sumsel, plot=True)

# %%
hasil = multiplicative_decomposition(dekomposisi_sumsel, plot=True)

# %%
hasil = stl_decomposition(dekomposisi_sumsel, plot=True)
