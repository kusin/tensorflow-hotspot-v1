# %% [markdown]
# ## How to Grid Search Hyperparameters for Deep Learning Models in Python with Keras

# %% [markdown]
# - https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %%
# Use scikit-learn to grid search the number of neurons
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.constraints import MaxNorm

# %%
# Function to create model, required for KerasClassifier
def create_model(neurons):
    # create model
    model = Sequential()
    model.add(Dense(neurons, input_shape=(8,), kernel_initializer='uniform', activation='linear', kernel_constraint=MaxNorm(4)))
    model.add(Dropout(0.2))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # return values
    return model

# %%
# fix random seed for reproducibility
tf.random.set_seed(seed = 7)

# %%
# load dataset
dataset = np.loadtxt("dataset/diabetes.csv", delimiter=",")

# %%
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# show to dataset
pd.concat([
    pd.DataFrame(X, columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']),
    pd.DataFrame(Y, columns=['Y'])
], axis=1)
# Out:
#        x1     x2    x3    x4     x5    x6     x7    x8    Y
# 0     6.0  148.0  72.0  35.0    0.0  33.6  0.627  50.0  1.0
# 1     1.0   85.0  66.0  29.0    0.0  26.6  0.351  31.0  0.0
# 2     8.0  183.0  64.0   0.0    0.0  23.3  0.672  32.0  1.0
# 3     1.0   89.0  66.0  23.0   94.0  28.1  0.167  21.0  0.0
# 4     0.0  137.0  40.0  35.0  168.0  43.1  2.288  33.0  1.0
# ..    ...    ...   ...   ...    ...   ...    ...   ...  ...
# 763  10.0  101.0  76.0  48.0  180.0  32.9  0.171  63.0  0.0
# 764   2.0  122.0  70.0  27.0    0.0  36.8  0.340  27.0  0.0
# 765   5.0  121.0  72.0  23.0  112.0  26.2  0.245  30.0  0.0
# 766   1.0  126.0  60.0   0.0    0.0  30.1  0.349  47.0  1.0
# 767   1.0   93.0  70.0  31.0    0.0  30.4  0.315  23.0  0.0
#
# [768 rows x 9 columns]

# %%
# create model
model = KerasClassifier(model=create_model, epochs=100, batch_size=10, verbose=1)

# %%
# define the grid search parameters
neurons = [1, 5, 10, 15, 20, 25, 30]

# %%
param_grid = dict(model__neurons=neurons)

# %%
param_grid
# Out:
# {'model__neurons': [1, 5, 10, 15, 20, 25, 30]}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
grid_result = grid.fit(X, Y)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 3ms/step - loss: 0.6684 - accuracy: 0.6432
# Epoch 2/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6509 - accuracy: 0.6615
# Epoch 3/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6628
# Epoch 4/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6332 - accuracy: 0.6615
# Epoch 5/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6365 - accuracy: 0.6562
# Epoch 6/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.6654
# Epoch 7/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.6732
# Epoch 8/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6260 - accuracy: 0.6745
# Epoch 9/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6171 - accuracy: 0.6810
# Epoch 10/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6200 - accuracy: 0.6836
# Epoch 11/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6157 - accuracy: 0.6758
# Epoch 12/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6089 - accuracy: 0.6823
# Epoch 13/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6162 - accuracy: 0.6940
# Epoch 14/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6120 - accuracy: 0.6797
# Epoch 15/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6072 - accuracy: 0.6810
# Epoch 16/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6081 - accuracy: 0.6901
# Epoch 17/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6024 - accuracy: 0.6862
# Epoch 18/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6181 - accuracy: 0.6940
# Epoch 19/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6170 - accuracy: 0.6823
# Epoch 20/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6025 - accuracy: 0.6914
# Epoch 21/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6002 - accuracy: 0.6901
# Epoch 22/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6091 - accuracy: 0.6758
# Epoch 23/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5950 - accuracy: 0.6901
# Epoch 24/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6035 - accuracy: 0.6992
# Epoch 25/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6044 - accuracy: 0.6927
# Epoch 26/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5957 - accuracy: 0.7083
# Epoch 27/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5935 - accuracy: 0.6940
# Epoch 28/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.6914
# Epoch 29/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.7018
# Epoch 30/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5925 - accuracy: 0.6940
# Epoch 31/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5967 - accuracy: 0.7005
# Epoch 32/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5959 - accuracy: 0.6992
# Epoch 33/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.6953
# Epoch 34/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5885 - accuracy: 0.7122
# Epoch 35/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5907 - accuracy: 0.7057
# Epoch 36/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5937 - accuracy: 0.6966
# Epoch 37/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5892 - accuracy: 0.7057
# Epoch 38/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5871 - accuracy: 0.7057
# Epoch 39/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5929 - accuracy: 0.7057
# Epoch 40/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.6953
# Epoch 41/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.6966
# Epoch 42/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.7070
# Epoch 43/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5844 - accuracy: 0.7109
# Epoch 44/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5847 - accuracy: 0.7135
# Epoch 45/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.6953
# Epoch 46/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.7005
# Epoch 47/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5802 - accuracy: 0.7122
# Epoch 48/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5805 - accuracy: 0.7031
# Epoch 49/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5908 - accuracy: 0.6992
# Epoch 50/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5742 - accuracy: 0.7227
# Epoch 51/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5825 - accuracy: 0.7044
# Epoch 52/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5730 - accuracy: 0.7279
# Epoch 53/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5760 - accuracy: 0.6888
# Epoch 54/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5744 - accuracy: 0.7201
# Epoch 55/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7109
# Epoch 56/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5774 - accuracy: 0.7096
# Epoch 57/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5970 - accuracy: 0.6927
# Epoch 58/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7070
# Epoch 59/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.7057
# Epoch 60/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5719 - accuracy: 0.7161
# Epoch 61/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5729 - accuracy: 0.7148
# Epoch 62/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5707 - accuracy: 0.7292
# Epoch 63/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.7031
# Epoch 64/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.7227
# Epoch 65/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5696 - accuracy: 0.7188
# Epoch 66/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5761 - accuracy: 0.7018
# Epoch 67/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5677 - accuracy: 0.7279
# Epoch 68/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5694 - accuracy: 0.7253
# Epoch 69/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5674 - accuracy: 0.7135
# Epoch 70/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5688 - accuracy: 0.7240
# Epoch 71/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5683 - accuracy: 0.7148
# Epoch 72/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5682 - accuracy: 0.7083
# Epoch 73/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5660 - accuracy: 0.7161
# Epoch 74/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.7109
# Epoch 75/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5618 - accuracy: 0.7305
# Epoch 76/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5693 - accuracy: 0.7174
# Epoch 77/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5721 - accuracy: 0.7161
# Epoch 78/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5682 - accuracy: 0.7005
# Epoch 79/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5692 - accuracy: 0.7122
# Epoch 80/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5727 - accuracy: 0.7161
# Epoch 81/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5636 - accuracy: 0.7240
# Epoch 82/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7240
# Epoch 83/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7122
# Epoch 84/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5663 - accuracy: 0.7266
# Epoch 85/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5661 - accuracy: 0.7266
# Epoch 86/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5628 - accuracy: 0.7161
# Epoch 87/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5600 - accuracy: 0.7214
# Epoch 88/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5576 - accuracy: 0.7161
# Epoch 89/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5621 - accuracy: 0.7214
# Epoch 90/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5597 - accuracy: 0.7122
# Epoch 91/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.5680 - accuracy: 0.7240
# Epoch 92/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5641 - accuracy: 0.7174
# Epoch 93/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5650 - accuracy: 0.7188
# Epoch 94/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.7370
# Epoch 95/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5564 - accuracy: 0.7240
# Epoch 96/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5609 - accuracy: 0.7227
# Epoch 97/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.7383
# Epoch 98/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5501 - accuracy: 0.7305
# Epoch 99/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5571 - accuracy: 0.7318
# Epoch 100/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5451 - accuracy: 0.7279

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.716146 using {'model__neurons': 20}

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 0.707031 (0.005524) with: {'model__neurons': 1}
# 0.713542 (0.017566) with: {'model__neurons': 5}
# 0.708333 (0.012075) with: {'model__neurons': 10}
# 0.712240 (0.010253) with: {'model__neurons': 15}
# 0.716146 (0.018688) with: {'model__neurons': 20}
# 0.701823 (0.012890) with: {'model__neurons': 25}
# 0.704427 (0.010253) with: {'model__neurons': 30}
