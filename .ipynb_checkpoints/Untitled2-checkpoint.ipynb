# %%
# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library configuration date and time
import time
from datetime import datetime

# library data visualization
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib import pyplot
from matplotlib import pyplot as plt

# library analysis acf and pacf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# library algorithm lstm-rnn with keras
import tensorflow as tf
from tensorflow.keras import models
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# Early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# library evaluation model
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### 1. Akuisisi Data

# %%
# fix random seed for reproducibility
np.random.seed(1234)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
# set index tanggal
dataset = dataset.set_index("tanggal")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sst             240 non-null    float64
#  1   soi             240 non-null    float64
#  2   oni             240 non-null    float64
#  3   curah_hujan     240 non-null    float64
#  4   hotspot_sumsel  240 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.2 KB

# %%
dataset.describe()
# Out:
#               sst         soi         oni  curah_hujan  hotspot_sumsel
# count  240.000000  240.000000  240.000000   240.000000      240.000000
# mean     0.037917    0.167500    0.002708   232.780420      648.587500
# std      0.748704    0.909564    0.789896   121.096391     1747.365812
# min     -1.590000   -3.100000   -1.640000     9.900001        1.000000
# 25%     -0.480000   -0.400000   -0.505000   129.325006       21.750000
# 50%     -0.010000    0.100000   -0.050000   229.400002       59.500000
# 75%      0.500000    0.700000    0.472500   326.424995      313.250000
# max      2.720000    2.900000    2.640000   537.400024    14416.000000

# %%
print(dataset.head())
# Out:
#              sst  soi   oni  curah_hujan  hotspot_sumsel
# tanggal
# 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 2001-05-31 -0.46 -0.5 -0.25   116.900002              39

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, dataset["hotspot_sumsel"], color="tab:blue", label="Hotspot Sumsel", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
hotspot = list(dataset["hotspot_sumsel"])

# %%
print("Nilai terendah adalah", min(dataset["hotspot_sumsel"]));
# Out:
# Nilai terendah adalah 1

# %%
print("Index nilai terendah", hotspot.index(1))
# Out:
# Index nilai terendah 156

# %%
print("Nilai tertinggi adalah", max(dataset["hotspot_sumsel"]));
# Out:
# Nilai tertinggi adalah 14416

# %%
print("Index nilai tertinggi", hotspot.index(14416))
# Out:
# Index nilai tertinggi 177

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, dataset["curah_hujan"], color="tab:blue", label="Rainfall", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
rainfall = list(dataset["curah_hujan"])

# %%
print("Nilai terendah adalah", np.round(min(dataset["curah_hujan"]), 2));
# Out:
# Nilai terendah adalah 9.9

# %%
print("Index nilai terendah", rainfall.index(9.90000057220459))
# Out:
# Index nilai terendah 43

# %%
print("Nilai tertinggi adalah", np.round(max(dataset["curah_hujan"]), 2));
# Out:
# Nilai tertinggi adalah 537.4

# %%
print("Index nilai tertinggi", rainfall.index(537.4000244140625))
# Out:
# Index nilai tertinggi 11

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, dataset["sst"], color="tab:blue", label="SST Nina 3.4", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
sst = list(dataset["sst"])
print("---------------------------------------------------------------");
print("Nilai terendah adalah", np.round(min(dataset["sst"]), 2));
print("Index nilai terendah", sst.index(-1.59))

print("---------------------------------------------------------------");
print("Nilai tertinggi adalah", np.round(max(dataset["sst"]), 2));
print("Index nilai tertinggi", sst.index(2.72))
# Out:
# ---------------------------------------------------------------
# Nilai terendah adalah -1.59
# Index nilai terendah 84
# ---------------------------------------------------------------
# Nilai tertinggi adalah 2.72
# Index nilai tertinggi 178

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, dataset["soi"], color="tab:blue", label="Index SOI", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
soi = list(dataset["soi"])
print("---------------------------------------------------------------");
print("Nilai terendah adalah", np.round(min(dataset["soi"]), 2));
print("Index nilai terendah", soi.index(-3.1))

print("---------------------------------------------------------------");
print("Nilai tertinggi adalah", np.round(max(dataset["soi"]), 2));
print("Index nilai tertinggi", soi.index(2.9))
# Out:
# ---------------------------------------------------------------
# Nilai terendah adalah -3.1
# Index nilai terendah 49
# ---------------------------------------------------------------
# Nilai tertinggi adalah 2.9
# Index nilai tertinggi 119

# %% [markdown]
# ### 2. Praproses Data

# %%
# ensure all data is float
values = dataset.values
values = values.astype('float64')

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(values)

# %%
np.round(scaled[:5],6)
# Out:
# array([[-0.614849,  0.366667, -0.551402,  0.549573, -0.999723],
#        [-0.522042,  0.6     , -0.476636,  0.082464, -0.999445],
#        [-0.433875,  0.333333, -0.439252,  0.329668, -0.998751],
#        [-0.522042,  0.1     , -0.392523,  0.493081, -0.997364],
#        [-0.475638, -0.133333, -0.350467, -0.594313, -0.994728]])

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, scaled[:, :1], color="tab:blue", label="SST Nina 3.4", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, scaled[:, 1:2], color="tab:blue", label="Index SOI", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, scaled[:, 3:4], color="tab:blue", label="Rainfall", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
# make a frame
fig, ax = plt.subplots(figsize = (10,5))

# make a time series plot
ax.plot(dataset.index.values, scaled[:, 4:5], color="tab:blue", label="Hotspot Sumsel", linewidth=2.5)

# make are labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# show plot time series
plt.show()

# %%
if 0.002 < 0.05 :
    print("A")
# Out:
# A

# %%
dataset = dataset.reset_index()

# %%
df = dataset[["sst", "soi", "curah_hujan", "hotspot_sumsel"]]

# %%
df
# Out:
#       sst  soi  curah_hujan  hotspot_sumsel
# 0   -0.76  1.0   418.600006               3
# 1   -0.56  1.7   295.399994               5
# 2   -0.37  0.9   360.600006              10
# 3   -0.56  0.2   403.700012              20
# 4   -0.46 -0.5   116.900002              39
# ..    ...  ...          ...             ...
# 235 -0.52  1.1    82.700005              65
# 236 -0.64  0.9   211.800003              29
# 237 -1.13  0.5   437.300018              40
# 238 -1.23  0.7   237.400009              30
# 239 -0.99  1.8   405.800018               8
#
# [240 rows x 4 columns]

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1,1))
scaled = scaler.fit_transform(df)

# %%
pd.DataFrame(scaled)
# Out:
#             0         1         2         3
# 0   -0.614849  0.366667  0.549573 -0.999723
# 1   -0.522042  0.600000  0.082464 -0.999445
# 2   -0.433875  0.333333  0.329668 -0.998751
# 3   -0.522042  0.100000  0.493081 -0.997364
# 4   -0.475638 -0.133333 -0.594313 -0.994728
# ..        ...       ...       ...       ...
# 235 -0.503480  0.400000 -0.723981 -0.991120
# 236 -0.559165  0.333333 -0.234502 -0.996115
# 237 -0.786543  0.200000  0.620474 -0.994589
# 238 -0.832947  0.266667 -0.137441 -0.995976
# 239 -0.721578  0.633333  0.501043 -0.999029
#
# [240 rows x 4 columns]
