# %% [markdown]
# ## Bivariate LSTM-RNN Sumatera Selatan Percobaan 2

# %% [markdown]
# ### 1. Deklarasi Pustaka

# %%
# library manipulation dataset
import pandas as pd
from pandas import concat
from pandas import DataFrame
from pandas import read_csv
from pandas import read_excel

# library manipulation array
import numpy as np
from numpy import concatenate
from numpy import array

# library configuration date and time
import time
from datetime import datetime

# library data visualization
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib import pyplot
from matplotlib import pyplot as plt

# library analysis acf and pacf
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# library normalize data with max-min algorithm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# library algorithm lstm-rnn with keras
import tensorflow as tf
from tensorflow.keras import models
from keras.models import Sequential
from keras.layers import RNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD
from keras.layers import LeakyReLU

# Early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# library evaluation model
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from epftoolbox.evaluation import sMAPE

# %% [markdown]
# ### 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
# fix random seed for reproducibility
np.random.seed(1234)

# %%
# membaca dataset
dataset = read_excel("dataset/dataset.xlsx")

# %%
# set index tanggal
dataset = dataset.set_index("tanggal")

# %%
# menampilkan metadata dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2001-01-31 to 2020-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sst             240 non-null    float64
#  1   soi             240 non-null    float64
#  2   oni             240 non-null    float64
#  3   curah_hujan     240 non-null    float64
#  4   hotspot_sumsel  240 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.2 KB

# %%
print(dataset.head())
# Out:
#              sst  soi   oni  curah_hujan  hotspot_sumsel
# tanggal
# 2001-01-31 -0.76  1.0 -0.68   418.600006               3
# 2001-02-28 -0.56  1.7 -0.52   295.399994               5
# 2001-03-31 -0.37  0.9 -0.44   360.600006              10
# 2001-04-30 -0.56  0.2 -0.34   403.700012              20
# 2001-05-31 -0.46 -0.5 -0.25   116.900002              39

# %% [markdown]
# ### 3. Exploration Data Analysis

# %% [markdown]
# - Data Visualization

# %%
# make frame
fig, ax = plt.subplots(figsize = (20,6))

# make time series plot
ax.plot(dataset.index, dataset["hotspot_sumsel"], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Sum of hostpot", fontsize=12)
ax.legend(loc='best')
ax.grid(True)

# show plot time series
plt.show()

# %% [markdown]
# - Analysis ACF and PACF

# %%
# make frame
fig, ax= plt.subplots(nrows=1, ncols=2, facecolor="#F0F0F0", figsize = (20,5))

# plot acf
plot_acf(dataset["hotspot_sumsel"], lags=24, ax=ax[0])
ax[0].grid(True)

# plot pacf
plot_pacf(dataset["hotspot_sumsel"],lags=24, ax=ax[1], method="yw")
ax[1].grid(True)

# show plot acf and pacf
plt.show()

# %% [markdown]
# ### 4. Praproses Data

# %% [markdown]
# - 1. feature selection (studi kasus sumatera selatan dan curah hujan)

# %%
# memilih area studi
df_sumsel = dataset[["hotspot_sumsel", "curah_hujan"]]

# %%
# ensure all data is float
df_sumsel = df_sumsel.values
df_sumsel = df_sumsel.astype('float64')

# %%
# show a dataset
np.round(df_sumsel[:5],4)
# Out:
# array([[  3. , 418.6],
#        [  5. , 295.4],
#        [ 10. , 360.6],
#        [ 20. , 403.7],
#        [ 39. , 116.9]])

# %%
# view a dimension dataset
df_sumsel.shape
# Out:
# (240, 2)

# %%
# membuat frame
fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, facecolor="#f0f0f0", figsize=(20, 5))
# ----------------------------------------------------------------------------------------------------

# make time series plot
ax1.plot(dataset.index, df_sumsel[:,0:1], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax1.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax1.set_xlabel("Year", fontsize=12)
ax1.set_ylabel("Sum of hostpot", fontsize=12)
ax1.legend(loc='best')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# make time series plot
ax2.plot(dataset.index, df_sumsel[:,1:2], color="tab:blue", label="curah hujan sumsel 2001-2020", linewidth=2.5)

# make are labels
ax2.set_title("Curah Hujan Sumsel 2001-2020", fontsize=14)
ax2.set_xlabel("Year", fontsize=12)
ax2.set_ylabel("Sum of rainfall", fontsize=12)
ax2.legend(loc='best')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.12, hspace=0.25)

# show plot time series
plt.show()

# %% [markdown]
# - 2. Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
df_sumsel = scaler.fit_transform(df_sumsel)

# %%
np.round(df_sumsel[:5],4)
# Out:
# array([[-0.9997,  0.5496],
#        [-0.9994,  0.0825],
#        [-0.9988,  0.3297],
#        [-0.9974,  0.4931],
#        [-0.9947, -0.5943]])

# %%
# view a dimension dataset after normalize
df_sumsel.shape
# Out:
# (240, 2)

# %%
# membuat frame
fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, facecolor="#f0f0f0", figsize=(20, 5))
# ----------------------------------------------------------------------------------------------------

# make time series plot
ax1.plot(dataset.index, df_sumsel[:,0:1], color="tab:blue", label="hotspot sumsel 2001-2020", linewidth=2.5)

# make are labels
ax1.set_title("Hotspot Sumsel 2001-2020", fontsize=14)
ax1.set_xlabel("Year", fontsize=12)
ax1.set_ylabel("Sum of hostpot", fontsize=12)
ax1.legend(loc='best')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# make time series plot
ax2.plot(dataset.index, df_sumsel[:,1:2], color="tab:blue", label="curah hujan sumsel 2001-2020", linewidth=2.5)

# make are labels
ax2.set_title("Curah Hujan Sumsel 2001-2020", fontsize=14)
ax2.set_xlabel("Year", fontsize=12)
ax2.set_ylabel("Sum of rainfall", fontsize=12)
ax2.legend(loc='best')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.12, hspace=0.25)

# show plot time series
plt.show()

# %% [markdown]
# - 3. set data train and data test

# %%
# set data train
train_size = int(len(df_sumsel) * 0.8)

# %%
# set loc data train
train = df_sumsel[0:train_size,:]

# %%
# show data train
np.round(train[:5],4)
# Out:
# array([[-0.9997,  0.5496],
#        [-0.9994,  0.0825],
#        [-0.9988,  0.3297],
#        [-0.9974,  0.4931],
#        [-0.9947, -0.5943]])

# %%
# view dimension of data train
train.shape
# Out:
# (192, 2)

# %%
# set data test
test_size = len(df_sumsel) - train_size

# %%
# set loc data test
test = df_sumsel[train_size:len(df_sumsel),:]

# %%
# show data test
np.round(test[:5],4)
# Out:
# array([[-0.9985,  0.106 ],
#        [-0.9997,  0.0844],
#        [-0.9975,  0.0885],
#        [-0.9974,  0.2   ],
#        [-0.9945, -0.2785]])

# %%
# view dimension of data test
test.shape
# Out:
# (48, 2)

# %%
# membuat frame
fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, facecolor="#f0f0f0", figsize=(20, 5))
# ----------------------------------------------------------------------------------------------------

# make time series plot
ax1.plot(
    dataset.iloc[0:train_size].index, train[:,0:1],
    color="tab:blue", label="data latih", linewidth=2.5
)
ax1.plot(
    dataset.iloc[train_size:len(dataset)].index, test[:,0:1],
    color="tab:red", label="data uji", linewidth=2.5
)

# make are labels
ax1.set_title("Hotspot Sumsel Sensor MODIS 2001-2020", fontsize=14)
ax1.set_xlabel("Year", fontsize=12)
ax1.set_ylabel("Sum of Hostpot", fontsize=12)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# make time series plot
ax2.plot(
    dataset.iloc[0:train_size].index, train[:,1:2],
    color="tab:blue", label="data latih", linewidth=2.5
)
ax2.plot(
    dataset.iloc[train_size:len(dataset)].index, test[:,1:2],
    color="tab:red", label="data uji", linewidth=2.5
)

# make are labels
ax2.set_title("Curah Hujan Sumsel 2001-2020", fontsize=14)
ax2.set_xlabel("Year", fontsize=12)
ax2.set_ylabel("Sum of rainfall", fontsize=12)
ax2.legend(loc='best')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.12, hspace=0.25)

# show plot time series
plt.show()

# %% [markdown]
# ### 5. Supervised Learning

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    
    # return value
    return agg

# %% [markdown]
# - process supervised learning, with look back t-1 into X=t and Y=t+1

# %%
# set supervised learning for data train
reframed_train = series_to_supervised(train, 1, 1)

# %%
# drop columns we don't want to predict
reframed_train.drop(reframed_train.columns[[3]], axis=1, inplace=True)

# %%
# split into input and outputs
trainX, trainY = reframed_train.iloc[:, :-1], reframed_train.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(trainX.shape, trainY.shape)
# Out:
# (191, 2) (191,)

# %%
# set supervised learning for data test
reframed_test = series_to_supervised(test, 1, 1)

# %%
# drop columns we don't want to predict
reframed_test.drop(reframed_test.columns[[3]], axis=1, inplace=True)

# %%
# split into input and outputs
testX, testY = reframed_test.iloc[:, :-1], reframed_test.iloc[:, -1]

# %%
# view a dimension dataset after supervised learning
print(testX.shape, testY.shape)
# Out:
# (47, 2) (47,)

# %% [markdown]
# - Check data train, for result supervised learning

# %%
temp_trainX = pd.DataFrame(trainX)
temp_trainY = pd.DataFrame(trainY)

# %%
hasil_train = pd.concat([temp_trainX, temp_trainY], axis=1)
hasil_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 1 to 191
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  191 non-null    float64
#  1   var2(t-1)  191 non-null    float64
#  2   var1(t)    191 non-null    float64
# dtypes: float64(3)
# memory usage: 6.0 KB

# %%
hasil_train.head()
# Out:
#    var1(t-1)  var2(t-1)   var1(t)
# 1  -0.999723   0.549573 -0.999445
# 2  -0.999445   0.082464 -0.998751
# 3  -0.998751   0.329668 -0.997364
# 4  -0.997364   0.493081 -0.994728
# 5  -0.994728  -0.594313 -0.999029

# %% [markdown]
# - Check data test, for result supervised learning

# %%
temp_testX = pd.DataFrame(testX)
temp_testY = pd.DataFrame(testY)

# %%
hasil_test = pd.concat([temp_testX, temp_testY], axis=1)
hasil_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1 to 47
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   var1(t-1)  47 non-null     float64
#  1   var2(t-1)  47 non-null     float64
#  2   var1(t)    47 non-null     float64
# dtypes: float64(3)
# memory usage: 1.5 KB

# %%
hasil_test.head()
# Out:
#    var1(t-1)  var2(t-1)   var1(t)
# 1  -0.998474   0.105972 -0.999723
# 2  -0.999723   0.084360 -0.997503
# 3  -0.997503   0.088531 -0.997364
# 4  -0.997364   0.200000 -0.994450
# 5  -0.994450  -0.278483 -0.991537

# %% [markdown]
# - reshape input for samples, time steps, features

# %%
# reshape data train
trainX = np.reshape(np.array(trainX), (trainX.shape[0], 1, trainX.shape[1]))

# %%
print(trainX.shape, trainY.shape)
# Out:
# (191, 1, 2) (191,)

# %%
# reshape data test
testX = np.reshape(np.array(testX), (testX.shape[0], 1, testX.shape[1]))

# %%
print(testX.shape, testY.shape)
# Out:
# (47, 1, 2) (47,)

# %% [markdown]
# ### 6. Modeling LSTM-RNN

# %% [markdown]
# - Kondisi Hyperparameter

# %%
# reset of session model
tf.keras.backend.clear_session()

# design network grid serach
model = Sequential()

# first lstm-rnn layer with dropout regularisation
model.add(
    LSTM(
        units=10,
        activation="selu",
        input_shape=(trainX.shape[1], trainX.shape[2])
    )
)
model.add(Dropout(0.15))

# the output layer
model.add(Dense(1))

# model compile
model.compile(
    optimizer="rmsprop",
    loss="mae",
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.MeanSquaredError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# %%
# fit network
history = model.fit(trainX, trainY, epochs=2000, batch_size=32,
                    validation_data=(testX, testY), use_multiprocessing=True,
                    verbose=1, shuffle=False)
# Out:
# Epoch 1/2000
# 6/6 [==============================] - 2s 73ms/step - loss: 0.8483 - mean_absolute_error: 0.8483 - mean_squared_error: 0.7476 - root_mean_squared_error: 0.8647 - val_loss: 0.8429 - val_mean_absolute_error: 0.8429 - val_mean_squared_error: 0.7219 - val_root_mean_squared_error: 0.8497
# Epoch 2/2000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7721 - mean_absolute_error: 0.7721 - mean_squared_error: 0.6224 - root_mean_squared_error: 0.7889 - val_loss: 0.7915 - val_mean_absolute_error: 0.7915 - val_mean_squared_error: 0.6374 - val_root_mean_squared_error: 0.7984
# Epoch 3/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7434 - mean_absolute_error: 0.7434 - mean_squared_error: 0.5791 - root_mean_squared_error: 0.7610 - val_loss: 0.7455 - val_mean_absolute_error: 0.7455 - val_mean_squared_error: 0.5665 - val_root_mean_squared_error: 0.7526
# Epoch 4/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6960 - mean_absolute_error: 0.6960 - mean_squared_error: 0.5098 - root_mean_squared_error: 0.7140 - val_loss: 0.7022 - val_mean_absolute_error: 0.7022 - val_mean_squared_error: 0.5035 - val_root_mean_squared_error: 0.7096
# Epoch 5/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6621 - mean_absolute_error: 0.6621 - mean_squared_error: 0.4643 - root_mean_squared_error: 0.6814 - val_loss: 0.6603 - val_mean_absolute_error: 0.6603 - val_mean_squared_error: 0.4463 - val_root_mean_squared_error: 0.6680
# Epoch 6/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6189 - mean_absolute_error: 0.6189 - mean_squared_error: 0.4127 - root_mean_squared_error: 0.6424 - val_loss: 0.6194 - val_mean_absolute_error: 0.6194 - val_mean_squared_error: 0.3939 - val_root_mean_squared_error: 0.6276
# Epoch 7/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5780 - mean_absolute_error: 0.5780 - mean_squared_error: 0.3606 - root_mean_squared_error: 0.6005 - val_loss: 0.5787 - val_mean_absolute_error: 0.5787 - val_mean_squared_error: 0.3450 - val_root_mean_squared_error: 0.5873
# Epoch 8/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5412 - mean_absolute_error: 0.5412 - mean_squared_error: 0.3219 - root_mean_squared_error: 0.5673 - val_loss: 0.5367 - val_mean_absolute_error: 0.5367 - val_mean_squared_error: 0.2981 - val_root_mean_squared_error: 0.5460
# Epoch 9/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4933 - mean_absolute_error: 0.4933 - mean_squared_error: 0.2692 - root_mean_squared_error: 0.5188 - val_loss: 0.4948 - val_mean_absolute_error: 0.4948 - val_mean_squared_error: 0.2548 - val_root_mean_squared_error: 0.5047
# Epoch 10/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4658 - mean_absolute_error: 0.4658 - mean_squared_error: 0.2465 - root_mean_squared_error: 0.4965 - val_loss: 0.4552 - val_mean_absolute_error: 0.4552 - val_mean_squared_error: 0.2153 - val_root_mean_squared_error: 0.4640
# Epoch 11/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4339 - mean_absolute_error: 0.4339 - mean_squared_error: 0.2201 - root_mean_squared_error: 0.4692 - val_loss: 0.4156 - val_mean_absolute_error: 0.4156 - val_mean_squared_error: 0.1794 - val_root_mean_squared_error: 0.4235
# Epoch 12/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4014 - mean_absolute_error: 0.4014 - mean_squared_error: 0.1949 - root_mean_squared_error: 0.4414 - val_loss: 0.3764 - val_mean_absolute_error: 0.3764 - val_mean_squared_error: 0.1464 - val_root_mean_squared_error: 0.3827
# Epoch 13/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3706 - mean_absolute_error: 0.3706 - mean_squared_error: 0.1710 - root_mean_squared_error: 0.4135 - val_loss: 0.3381 - val_mean_absolute_error: 0.3381 - val_mean_squared_error: 0.1173 - val_root_mean_squared_error: 0.3425
# Epoch 14/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3206 - mean_absolute_error: 0.3206 - mean_squared_error: 0.1356 - root_mean_squared_error: 0.3682 - val_loss: 0.2984 - val_mean_absolute_error: 0.2984 - val_mean_squared_error: 0.0908 - val_root_mean_squared_error: 0.3013
# Epoch 15/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2916 - mean_absolute_error: 0.2916 - mean_squared_error: 0.1233 - root_mean_squared_error: 0.3512 - val_loss: 0.2571 - val_mean_absolute_error: 0.2571 - val_mean_squared_error: 0.0672 - val_root_mean_squared_error: 0.2591
# Epoch 16/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - mean_squared_error: 0.0977 - root_mean_squared_error: 0.3126 - val_loss: 0.2149 - val_mean_absolute_error: 0.2149 - val_mean_squared_error: 0.0470 - val_root_mean_squared_error: 0.2168
# Epoch 17/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2242 - mean_absolute_error: 0.2242 - mean_squared_error: 0.0892 - root_mean_squared_error: 0.2987 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749 - val_mean_squared_error: 0.0317 - val_root_mean_squared_error: 0.1781
# Epoch 18/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1835 - mean_absolute_error: 0.1835 - mean_squared_error: 0.0758 - root_mean_squared_error: 0.2753 - val_loss: 0.1369 - val_mean_absolute_error: 0.1369 - val_mean_squared_error: 0.0207 - val_root_mean_squared_error: 0.1439
# Epoch 19/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - mean_squared_error: 0.0711 - root_mean_squared_error: 0.2667 - val_loss: 0.1246 - val_mean_absolute_error: 0.1246 - val_mean_squared_error: 0.0179 - val_root_mean_squared_error: 0.1337
# Epoch 20/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1784 - mean_absolute_error: 0.1784 - mean_squared_error: 0.0771 - root_mean_squared_error: 0.2776 - val_loss: 0.1138 - val_mean_absolute_error: 0.1138 - val_mean_squared_error: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 21/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1691 - mean_absolute_error: 0.1691 - mean_squared_error: 0.0679 - root_mean_squared_error: 0.2605 - val_loss: 0.1024 - val_mean_absolute_error: 0.1024 - val_mean_squared_error: 0.0135 - val_root_mean_squared_error: 0.1160
# Epoch 22/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - mean_squared_error: 0.0662 - root_mean_squared_error: 0.2573 - val_loss: 0.1132 - val_mean_absolute_error: 0.1132 - val_mean_squared_error: 0.0154 - val_root_mean_squared_error: 0.1242
# Epoch 23/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - mean_squared_error: 0.0706 - root_mean_squared_error: 0.2657 - val_loss: 0.1124 - val_mean_absolute_error: 0.1124 - val_mean_squared_error: 0.0150 - val_root_mean_squared_error: 0.1227
# Epoch 24/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - mean_squared_error: 0.0660 - root_mean_squared_error: 0.2568 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957 - val_mean_squared_error: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 25/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1638 - mean_absolute_error: 0.1638 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2595 - val_loss: 0.1101 - val_mean_absolute_error: 0.1101 - val_mean_squared_error: 0.0146 - val_root_mean_squared_error: 0.1206
# Epoch 26/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - mean_squared_error: 0.0653 - root_mean_squared_error: 0.2555 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989 - val_mean_squared_error: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 27/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1601 - mean_absolute_error: 0.1601 - mean_squared_error: 0.0615 - root_mean_squared_error: 0.2480 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993 - val_mean_squared_error: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 28/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1561 - mean_absolute_error: 0.1561 - mean_squared_error: 0.0632 - root_mean_squared_error: 0.2515 - val_loss: 0.1013 - val_mean_absolute_error: 0.1013 - val_mean_squared_error: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 29/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1713 - mean_absolute_error: 0.1713 - mean_squared_error: 0.0696 - root_mean_squared_error: 0.2638 - val_loss: 0.0933 - val_mean_absolute_error: 0.0933 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 30/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - mean_squared_error: 0.0693 - root_mean_squared_error: 0.2632 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985 - val_mean_squared_error: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 31/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1611 - mean_absolute_error: 0.1611 - mean_squared_error: 0.0697 - root_mean_squared_error: 0.2640 - val_loss: 0.1109 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0144 - val_root_mean_squared_error: 0.1200
# Epoch 32/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1571 - mean_absolute_error: 0.1571 - mean_squared_error: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 0.0939 - val_mean_absolute_error: 0.0939 - val_mean_squared_error: 0.0114 - val_root_mean_squared_error: 0.1070
# Epoch 33/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1574 - mean_absolute_error: 0.1574 - mean_squared_error: 0.0610 - root_mean_squared_error: 0.2470 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832 - val_mean_squared_error: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 34/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1743 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0703 - root_mean_squared_error: 0.2651 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 35/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1688 - mean_absolute_error: 0.1688 - mean_squared_error: 0.0681 - root_mean_squared_error: 0.2611 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005 - val_mean_squared_error: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 36/2000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - mean_squared_error: 0.0591 - root_mean_squared_error: 0.2430 - val_loss: 0.0885 - val_mean_absolute_error: 0.0885 - val_mean_squared_error: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 37/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - mean_squared_error: 0.0673 - root_mean_squared_error: 0.2595 - val_loss: 0.0861 - val_mean_absolute_error: 0.0861 - val_mean_squared_error: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 38/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1495 - mean_absolute_error: 0.1495 - mean_squared_error: 0.0589 - root_mean_squared_error: 0.2426 - val_loss: 0.0769 - val_mean_absolute_error: 0.0769 - val_mean_squared_error: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 39/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0705 - root_mean_squared_error: 0.2655 - val_loss: 0.0809 - val_mean_absolute_error: 0.0809 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 40/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1543 - mean_absolute_error: 0.1543 - mean_squared_error: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 0.0866 - val_mean_absolute_error: 0.0866 - val_mean_squared_error: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 41/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - mean_squared_error: 0.0669 - root_mean_squared_error: 0.2587 - val_loss: 0.1032 - val_mean_absolute_error: 0.1032 - val_mean_squared_error: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 42/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - mean_squared_error: 0.0659 - root_mean_squared_error: 0.2567 - val_loss: 0.0818 - val_mean_absolute_error: 0.0818 - val_mean_squared_error: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 43/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1500 - mean_absolute_error: 0.1500 - mean_squared_error: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0916 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 44/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1535 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0605 - root_mean_squared_error: 0.2459 - val_loss: 0.1022 - val_mean_absolute_error: 0.1022 - val_mean_squared_error: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 45/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - mean_squared_error: 0.0601 - root_mean_squared_error: 0.2452 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 46/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1539 - mean_absolute_error: 0.1539 - mean_squared_error: 0.0621 - root_mean_squared_error: 0.2491 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969 - val_mean_squared_error: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 47/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1559 - mean_absolute_error: 0.1559 - mean_squared_error: 0.0611 - root_mean_squared_error: 0.2472 - val_loss: 0.0824 - val_mean_absolute_error: 0.0824 - val_mean_squared_error: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 48/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1568 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 0.0871 - val_mean_absolute_error: 0.0871 - val_mean_squared_error: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 49/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1420 - mean_absolute_error: 0.1420 - mean_squared_error: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0820 - val_mean_absolute_error: 0.0820 - val_mean_squared_error: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 50/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1550 - mean_absolute_error: 0.1550 - mean_squared_error: 0.0632 - root_mean_squared_error: 0.2515 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704 - val_mean_squared_error: 0.0083 - val_root_mean_squared_error: 0.0911
# Epoch 51/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - mean_squared_error: 0.0630 - root_mean_squared_error: 0.2511 - val_loss: 0.0761 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 52/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - mean_squared_error: 0.0608 - root_mean_squared_error: 0.2466 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649 - val_mean_squared_error: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 53/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1516 - mean_absolute_error: 0.1516 - mean_squared_error: 0.0598 - root_mean_squared_error: 0.2445 - val_loss: 0.0867 - val_mean_absolute_error: 0.0867 - val_mean_squared_error: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 54/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1558 - mean_absolute_error: 0.1558 - mean_squared_error: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - val_mean_squared_error: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 55/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1406 - mean_absolute_error: 0.1406 - mean_squared_error: 0.0564 - root_mean_squared_error: 0.2375 - val_loss: 0.0777 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 56/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1446 - mean_absolute_error: 0.1446 - mean_squared_error: 0.0603 - root_mean_squared_error: 0.2456 - val_loss: 0.0842 - val_mean_absolute_error: 0.0842 - val_mean_squared_error: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 57/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1400 - mean_absolute_error: 0.1400 - mean_squared_error: 0.0532 - root_mean_squared_error: 0.2307 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628 - val_mean_squared_error: 0.0076 - val_root_mean_squared_error: 0.0870
# Epoch 58/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1521 - mean_absolute_error: 0.1521 - mean_squared_error: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704 - val_mean_squared_error: 0.0082 - val_root_mean_squared_error: 0.0907
# Epoch 59/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1414 - mean_absolute_error: 0.1414 - mean_squared_error: 0.0577 - root_mean_squared_error: 0.2402 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732 - val_mean_squared_error: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 60/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1356 - mean_absolute_error: 0.1356 - mean_squared_error: 0.0546 - root_mean_squared_error: 0.2338 - val_loss: 0.0798 - val_mean_absolute_error: 0.0798 - val_mean_squared_error: 0.0093 - val_root_mean_squared_error: 0.0963
# Epoch 61/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1516 - mean_absolute_error: 0.1516 - mean_squared_error: 0.0613 - root_mean_squared_error: 0.2476 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - val_mean_squared_error: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 62/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - mean_squared_error: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701 - val_mean_squared_error: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 63/2000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - mean_squared_error: 0.0569 - root_mean_squared_error: 0.2386 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - val_mean_squared_error: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 64/2000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0545 - root_mean_squared_error: 0.2335 - val_loss: 0.0761 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 65/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1434 - mean_absolute_error: 0.1434 - mean_squared_error: 0.0561 - root_mean_squared_error: 0.2368 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 66/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1294 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0553 - root_mean_squared_error: 0.2352 - val_loss: 0.0795 - val_mean_absolute_error: 0.0795 - val_mean_squared_error: 0.0092 - val_root_mean_squared_error: 0.0962
# Epoch 67/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1375 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0583 - root_mean_squared_error: 0.2415 - val_loss: 0.0771 - val_mean_absolute_error: 0.0771 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0946
# Epoch 68/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0637 - root_mean_squared_error: 0.2524 - val_loss: 0.0765 - val_mean_absolute_error: 0.0765 - val_mean_squared_error: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 69/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1385 - mean_absolute_error: 0.1385 - mean_squared_error: 0.0549 - root_mean_squared_error: 0.2342 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - val_mean_squared_error: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 70/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1311 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0495 - root_mean_squared_error: 0.2224 - val_loss: 0.0866 - val_mean_absolute_error: 0.0866 - val_mean_squared_error: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 71/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1391 - mean_absolute_error: 0.1391 - mean_squared_error: 0.0562 - root_mean_squared_error: 0.2371 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644 - val_mean_squared_error: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 72/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1388 - mean_absolute_error: 0.1388 - mean_squared_error: 0.0571 - root_mean_squared_error: 0.2389 - val_loss: 0.0725 - val_mean_absolute_error: 0.0725 - val_mean_squared_error: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 73/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1405 - mean_absolute_error: 0.1405 - mean_squared_error: 0.0568 - root_mean_squared_error: 0.2383 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700 - val_mean_squared_error: 0.0082 - val_root_mean_squared_error: 0.0903
# Epoch 74/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1451 - mean_absolute_error: 0.1451 - mean_squared_error: 0.0595 - root_mean_squared_error: 0.2440 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701 - val_mean_squared_error: 0.0082 - val_root_mean_squared_error: 0.0904
# Epoch 75/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - mean_squared_error: 0.0597 - root_mean_squared_error: 0.2443 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 76/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1452 - mean_absolute_error: 0.1452 - mean_squared_error: 0.0597 - root_mean_squared_error: 0.2444 - val_loss: 0.0798 - val_mean_absolute_error: 0.0798 - val_mean_squared_error: 0.0092 - val_root_mean_squared_error: 0.0962
# Epoch 77/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1374 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0571 - root_mean_squared_error: 0.2389 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0840
# Epoch 78/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - mean_squared_error: 0.0548 - root_mean_squared_error: 0.2341 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - val_mean_squared_error: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 79/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1390 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0612 - root_mean_squared_error: 0.2473 - val_loss: 0.0833 - val_mean_absolute_error: 0.0833 - val_mean_squared_error: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 80/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1303 - mean_absolute_error: 0.1303 - mean_squared_error: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 81/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0572 - root_mean_squared_error: 0.2391 - val_loss: 0.0622 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 82/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0553 - root_mean_squared_error: 0.2351 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - val_mean_squared_error: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 83/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1415 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0558 - root_mean_squared_error: 0.2362 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 84/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1411 - mean_absolute_error: 0.1411 - mean_squared_error: 0.0581 - root_mean_squared_error: 0.2410 - val_loss: 0.0622 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 85/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0532 - root_mean_squared_error: 0.2307 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 86/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0572 - root_mean_squared_error: 0.2393 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 87/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1383 - mean_absolute_error: 0.1383 - mean_squared_error: 0.0560 - root_mean_squared_error: 0.2366 - val_loss: 0.0669 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 88/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1375 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0561 - root_mean_squared_error: 0.2369 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644 - val_mean_squared_error: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 89/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1378 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0572 - root_mean_squared_error: 0.2392 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 90/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1404 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0587 - root_mean_squared_error: 0.2424 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0849
# Epoch 91/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1301 - mean_absolute_error: 0.1301 - mean_squared_error: 0.0496 - root_mean_squared_error: 0.2227 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 92/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1348 - mean_absolute_error: 0.1348 - mean_squared_error: 0.0524 - root_mean_squared_error: 0.2288 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 93/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1240 - mean_absolute_error: 0.1240 - mean_squared_error: 0.0483 - root_mean_squared_error: 0.2197 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - val_mean_squared_error: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 94/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1284 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0520 - root_mean_squared_error: 0.2281 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 95/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1364 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0561 - root_mean_squared_error: 0.2368 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 96/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1273 - mean_absolute_error: 0.1273 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2275 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 97/2000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1299 - mean_absolute_error: 0.1299 - mean_squared_error: 0.0557 - root_mean_squared_error: 0.2359 - val_loss: 0.0598 - val_mean_absolute_error: 0.0598 - val_mean_squared_error: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 98/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1228 - mean_absolute_error: 0.1228 - mean_squared_error: 0.0519 - root_mean_squared_error: 0.2277 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - val_mean_squared_error: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 99/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1375 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0575 - root_mean_squared_error: 0.2397 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - val_mean_squared_error: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 100/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1368 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0573 - root_mean_squared_error: 0.2394 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 101/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1283 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0487 - root_mean_squared_error: 0.2207 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 102/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1292 - mean_absolute_error: 0.1292 - mean_squared_error: 0.0508 - root_mean_squared_error: 0.2254 - val_loss: 0.0611 - val_mean_absolute_error: 0.0611 - val_mean_squared_error: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 103/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1318 - mean_absolute_error: 0.1318 - mean_squared_error: 0.0572 - root_mean_squared_error: 0.2391 - val_loss: 0.0475 - val_mean_absolute_error: 0.0475 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 104/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1269 - mean_absolute_error: 0.1269 - mean_squared_error: 0.0556 - root_mean_squared_error: 0.2357 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634 - val_mean_squared_error: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 105/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0558 - root_mean_squared_error: 0.2361 - val_loss: 0.0460 - val_mean_absolute_error: 0.0460 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 106/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1228 - mean_absolute_error: 0.1228 - mean_squared_error: 0.0535 - root_mean_squared_error: 0.2313 - val_loss: 0.0483 - val_mean_absolute_error: 0.0483 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 107/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1242 - mean_absolute_error: 0.1242 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2321 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 108/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1272 - mean_absolute_error: 0.1272 - mean_squared_error: 0.0548 - root_mean_squared_error: 0.2342 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 109/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - mean_squared_error: 0.0523 - root_mean_squared_error: 0.2287 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 110/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1274 - mean_absolute_error: 0.1274 - mean_squared_error: 0.0563 - root_mean_squared_error: 0.2372 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 111/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1184 - mean_absolute_error: 0.1184 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2274 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 112/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1242 - mean_absolute_error: 0.1242 - mean_squared_error: 0.0509 - root_mean_squared_error: 0.2256 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 113/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1305 - mean_absolute_error: 0.1305 - mean_squared_error: 0.0526 - root_mean_squared_error: 0.2292 - val_loss: 0.0474 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0809
# Epoch 114/2000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1235 - mean_absolute_error: 0.1235 - mean_squared_error: 0.0506 - root_mean_squared_error: 0.2249 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - val_mean_squared_error: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 115/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1218 - mean_absolute_error: 0.1218 - mean_squared_error: 0.0527 - root_mean_squared_error: 0.2295 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 116/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1277 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0532 - root_mean_squared_error: 0.2306 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 117/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1250 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2321 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 118/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - mean_squared_error: 0.0562 - root_mean_squared_error: 0.2370 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 119/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1229 - mean_absolute_error: 0.1229 - mean_squared_error: 0.0495 - root_mean_squared_error: 0.2225 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 120/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1306 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0525 - root_mean_squared_error: 0.2292 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 121/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1216 - mean_absolute_error: 0.1216 - mean_squared_error: 0.0532 - root_mean_squared_error: 0.2306 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0818
# Epoch 122/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1295 - mean_absolute_error: 0.1295 - mean_squared_error: 0.0540 - root_mean_squared_error: 0.2325 - val_loss: 0.0567 - val_mean_absolute_error: 0.0567 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 123/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1288 - mean_absolute_error: 0.1288 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2318 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 124/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1221 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0518 - root_mean_squared_error: 0.2277 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0073 - val_root_mean_squared_error: 0.0855
# Epoch 125/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1270 - mean_absolute_error: 0.1270 - mean_squared_error: 0.0501 - root_mean_squared_error: 0.2238 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 126/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1214 - mean_absolute_error: 0.1214 - mean_squared_error: 0.0556 - root_mean_squared_error: 0.2357 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 127/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1175 - mean_absolute_error: 0.1175 - mean_squared_error: 0.0507 - root_mean_squared_error: 0.2252 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 128/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1283 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0569 - root_mean_squared_error: 0.2386 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 129/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1214 - mean_absolute_error: 0.1214 - mean_squared_error: 0.0514 - root_mean_squared_error: 0.2267 - val_loss: 0.0485 - val_mean_absolute_error: 0.0485 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 130/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1253 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0541 - root_mean_squared_error: 0.2325 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 131/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1200 - mean_absolute_error: 0.1200 - mean_squared_error: 0.0524 - root_mean_squared_error: 0.2289 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 132/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - mean_squared_error: 0.0548 - root_mean_squared_error: 0.2340 - val_loss: 0.0631 - val_mean_absolute_error: 0.0631 - val_mean_squared_error: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 133/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1298 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0548 - root_mean_squared_error: 0.2341 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 134/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1243 - mean_absolute_error: 0.1243 - mean_squared_error: 0.0545 - root_mean_squared_error: 0.2335 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 135/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1252 - mean_absolute_error: 0.1252 - mean_squared_error: 0.0525 - root_mean_squared_error: 0.2292 - val_loss: 0.0391 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 136/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1234 - mean_absolute_error: 0.1234 - mean_squared_error: 0.0531 - root_mean_squared_error: 0.2304 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 137/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1171 - mean_absolute_error: 0.1171 - mean_squared_error: 0.0530 - root_mean_squared_error: 0.2301 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 138/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1203 - mean_absolute_error: 0.1203 - mean_squared_error: 0.0505 - root_mean_squared_error: 0.2248 - val_loss: 0.0418 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 139/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1188 - mean_absolute_error: 0.1188 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2317 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 140/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1168 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2203 - val_loss: 0.0405 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0062 - val_root_mean_squared_error: 0.0788
# Epoch 141/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1198 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0537 - root_mean_squared_error: 0.2317 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0062 - val_root_mean_squared_error: 0.0788
# Epoch 142/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1177 - mean_absolute_error: 0.1177 - mean_squared_error: 0.0525 - root_mean_squared_error: 0.2292 - val_loss: 0.0440 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 143/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1176 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0530 - root_mean_squared_error: 0.2302 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 144/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1226 - mean_absolute_error: 0.1226 - mean_squared_error: 0.0555 - root_mean_squared_error: 0.2355 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 145/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1230 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0527 - root_mean_squared_error: 0.2296 - val_loss: 0.0460 - val_mean_absolute_error: 0.0460 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 146/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1192 - mean_absolute_error: 0.1192 - mean_squared_error: 0.0529 - root_mean_squared_error: 0.2300 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 147/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1195 - mean_absolute_error: 0.1195 - mean_squared_error: 0.0509 - root_mean_squared_error: 0.2256 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - val_mean_squared_error: 0.0072 - val_root_mean_squared_error: 0.0849
# Epoch 148/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1202 - mean_absolute_error: 0.1202 - mean_squared_error: 0.0526 - root_mean_squared_error: 0.2293 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 149/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1204 - mean_absolute_error: 0.1204 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2274 - val_loss: 0.0474 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 150/2000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1174 - mean_absolute_error: 0.1174 - mean_squared_error: 0.0524 - root_mean_squared_error: 0.2290 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488 - val_mean_squared_error: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 151/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1181 - mean_absolute_error: 0.1181 - mean_squared_error: 0.0501 - root_mean_squared_error: 0.2239 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 152/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - mean_squared_error: 0.0513 - root_mean_squared_error: 0.2264 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 153/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1202 - mean_absolute_error: 0.1202 - mean_squared_error: 0.0554 - root_mean_squared_error: 0.2354 - val_loss: 0.0434 - val_mean_absolute_error: 0.0434 - val_mean_squared_error: 0.0064 - val_root_mean_squared_error: 0.0802
# Epoch 154/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1228 - mean_absolute_error: 0.1228 - mean_squared_error: 0.0540 - root_mean_squared_error: 0.2323 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 155/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1122 - mean_absolute_error: 0.1122 - mean_squared_error: 0.0502 - root_mean_squared_error: 0.2241 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 156/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1133 - mean_absolute_error: 0.1133 - mean_squared_error: 0.0520 - root_mean_squared_error: 0.2280 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 157/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1120 - mean_absolute_error: 0.1120 - mean_squared_error: 0.0513 - root_mean_squared_error: 0.2266 - val_loss: 0.0429 - val_mean_absolute_error: 0.0429 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 158/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1094 - mean_absolute_error: 0.1094 - mean_squared_error: 0.0468 - root_mean_squared_error: 0.2162 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 159/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1215 - mean_absolute_error: 0.1215 - mean_squared_error: 0.0539 - root_mean_squared_error: 0.2321 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - val_mean_squared_error: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 160/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1153 - mean_absolute_error: 0.1153 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2242 - val_loss: 0.0443 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0065 - val_root_mean_squared_error: 0.0806
# Epoch 161/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1130 - mean_absolute_error: 0.1130 - mean_squared_error: 0.0523 - root_mean_squared_error: 0.2287 - val_loss: 0.0483 - val_mean_absolute_error: 0.0483 - val_mean_squared_error: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 162/2000
# ...
# Epoch 1948/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0756 - mean_absolute_error: 0.0756 - mean_squared_error: 0.0405 - root_mean_squared_error: 0.2011 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 1949/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0723 - mean_absolute_error: 0.0723 - mean_squared_error: 0.0370 - root_mean_squared_error: 0.1923 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 1950/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0696 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0334 - root_mean_squared_error: 0.1828 - val_loss: 0.0254 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 1951/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0714 - mean_absolute_error: 0.0714 - mean_squared_error: 0.0364 - root_mean_squared_error: 0.1907 - val_loss: 0.0248 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 1952/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0696 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0358 - root_mean_squared_error: 0.1892 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 1953/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0685 - mean_absolute_error: 0.0685 - mean_squared_error: 0.0360 - root_mean_squared_error: 0.1899 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 1954/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0728 - mean_absolute_error: 0.0728 - mean_squared_error: 0.0406 - root_mean_squared_error: 0.2016 - val_loss: 0.0258 - val_mean_absolute_error: 0.0258 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 1955/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0678 - mean_absolute_error: 0.0678 - mean_squared_error: 0.0339 - root_mean_squared_error: 0.1841 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 1956/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0725 - mean_absolute_error: 0.0725 - mean_squared_error: 0.0374 - root_mean_squared_error: 0.1934 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 1957/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0745 - mean_absolute_error: 0.0745 - mean_squared_error: 0.0390 - root_mean_squared_error: 0.1974 - val_loss: 0.0258 - val_mean_absolute_error: 0.0258 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 1958/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0699 - mean_absolute_error: 0.0699 - mean_squared_error: 0.0344 - root_mean_squared_error: 0.1855 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0051 - val_root_mean_squared_error: 0.0711
# Epoch 1959/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0745 - mean_absolute_error: 0.0745 - mean_squared_error: 0.0409 - root_mean_squared_error: 0.2023 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 1960/2000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0680 - mean_absolute_error: 0.0680 - mean_squared_error: 0.0305 - root_mean_squared_error: 0.1746 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 1961/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0729 - mean_absolute_error: 0.0729 - mean_squared_error: 0.0355 - root_mean_squared_error: 0.1883 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 1962/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0734 - mean_absolute_error: 0.0734 - mean_squared_error: 0.0383 - root_mean_squared_error: 0.1958 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 1963/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0673 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0330 - root_mean_squared_error: 0.1818 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 1964/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0696 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0355 - root_mean_squared_error: 0.1884 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 1965/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0678 - mean_absolute_error: 0.0678 - mean_squared_error: 0.0337 - root_mean_squared_error: 0.1837 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 1966/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0707 - mean_absolute_error: 0.0707 - mean_squared_error: 0.0360 - root_mean_squared_error: 0.1898 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 1967/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0736 - mean_absolute_error: 0.0736 - mean_squared_error: 0.0377 - root_mean_squared_error: 0.1941 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 1968/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0698 - mean_absolute_error: 0.0698 - mean_squared_error: 0.0347 - root_mean_squared_error: 0.1864 - val_loss: 0.0284 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 1969/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0700 - mean_absolute_error: 0.0700 - mean_squared_error: 0.0336 - root_mean_squared_error: 0.1832 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 1970/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0696 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0338 - root_mean_squared_error: 0.1838 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 1971/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0707 - mean_absolute_error: 0.0707 - mean_squared_error: 0.0347 - root_mean_squared_error: 0.1862 - val_loss: 0.0243 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 1972/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0703 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0348 - root_mean_squared_error: 0.1865 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0050 - val_root_mean_squared_error: 0.0706
# Epoch 1973/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0699 - mean_absolute_error: 0.0699 - mean_squared_error: 0.0352 - root_mean_squared_error: 0.1877 - val_loss: 0.0251 - val_mean_absolute_error: 0.0251 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 1974/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0720 - mean_absolute_error: 0.0720 - mean_squared_error: 0.0362 - root_mean_squared_error: 0.1903 - val_loss: 0.0247 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 1975/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0729 - mean_absolute_error: 0.0729 - mean_squared_error: 0.0358 - root_mean_squared_error: 0.1893 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 1976/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0690 - mean_absolute_error: 0.0690 - mean_squared_error: 0.0313 - root_mean_squared_error: 0.1770 - val_loss: 0.0250 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 1977/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0707 - mean_absolute_error: 0.0707 - mean_squared_error: 0.0341 - root_mean_squared_error: 0.1847 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 1978/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0757 - mean_absolute_error: 0.0757 - mean_squared_error: 0.0410 - root_mean_squared_error: 0.2025 - val_loss: 0.0247 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 1979/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0696 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0327 - root_mean_squared_error: 0.1809 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 1980/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0709 - mean_absolute_error: 0.0709 - mean_squared_error: 0.0380 - root_mean_squared_error: 0.1950 - val_loss: 0.0243 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 1981/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0731 - mean_absolute_error: 0.0731 - mean_squared_error: 0.0411 - root_mean_squared_error: 0.2028 - val_loss: 0.0260 - val_mean_absolute_error: 0.0260 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 1982/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0720 - mean_absolute_error: 0.0720 - mean_squared_error: 0.0385 - root_mean_squared_error: 0.1963 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 1983/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0677 - mean_absolute_error: 0.0677 - mean_squared_error: 0.0323 - root_mean_squared_error: 0.1798 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 1984/2000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0701 - mean_absolute_error: 0.0701 - mean_squared_error: 0.0358 - root_mean_squared_error: 0.1892 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 1985/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0683 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0325 - root_mean_squared_error: 0.1803 - val_loss: 0.0257 - val_mean_absolute_error: 0.0257 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 1986/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0688 - mean_absolute_error: 0.0688 - mean_squared_error: 0.0332 - root_mean_squared_error: 0.1821 - val_loss: 0.0260 - val_mean_absolute_error: 0.0260 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0689
# Epoch 1987/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0743 - mean_absolute_error: 0.0743 - mean_squared_error: 0.0386 - root_mean_squared_error: 0.1964 - val_loss: 0.0255 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 1988/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0721 - mean_absolute_error: 0.0721 - mean_squared_error: 0.0378 - root_mean_squared_error: 0.1943 - val_loss: 0.0252 - val_mean_absolute_error: 0.0252 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 1989/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0707 - mean_absolute_error: 0.0707 - mean_squared_error: 0.0363 - root_mean_squared_error: 0.1905 - val_loss: 0.0255 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 1990/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0688 - mean_absolute_error: 0.0688 - mean_squared_error: 0.0361 - root_mean_squared_error: 0.1899 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0050 - val_root_mean_squared_error: 0.0708
# Epoch 1991/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0716 - mean_absolute_error: 0.0716 - mean_squared_error: 0.0380 - root_mean_squared_error: 0.1950 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 1992/2000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0682 - mean_absolute_error: 0.0682 - mean_squared_error: 0.0341 - root_mean_squared_error: 0.1846 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 1993/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0658 - mean_absolute_error: 0.0658 - mean_squared_error: 0.0291 - root_mean_squared_error: 0.1705 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240 - val_mean_squared_error: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 1994/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0674 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0313 - root_mean_squared_error: 0.1768 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 1995/2000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0702 - mean_absolute_error: 0.0702 - mean_squared_error: 0.0332 - root_mean_squared_error: 0.1823 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 1996/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0722 - mean_absolute_error: 0.0722 - mean_squared_error: 0.0355 - root_mean_squared_error: 0.1884 - val_loss: 0.0273 - val_mean_absolute_error: 0.0273 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 1997/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0730 - mean_absolute_error: 0.0730 - mean_squared_error: 0.0391 - root_mean_squared_error: 0.1977 - val_loss: 0.0246 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 1998/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0698 - mean_absolute_error: 0.0698 - mean_squared_error: 0.0331 - root_mean_squared_error: 0.1819 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 1999/2000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0700 - mean_absolute_error: 0.0700 - mean_squared_error: 0.0325 - root_mean_squared_error: 0.1803 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 2000/2000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0715 - mean_absolute_error: 0.0715 - mean_squared_error: 0.0361 - root_mean_squared_error: 0.1901 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0049 - val_root_mean_squared_error: 0.0698

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                520
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (8,4))

# membuat time series plot
ax.plot(history.history['loss'], color="tab:blue", label="data train", linewidth=1.5)
ax.plot(history.history['val_loss'], color="tab:orange", label="data test", linewidth=1.5)

# membuat label-label
ax.set_title("Grafik Loss Function")
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %%
# 5. make predictions
predictions = model.predict(testX, verbose=0)
print(predictions[:, 0])
# Out:
# [-0.99548936 -0.99547666 -0.9953221  -0.9957414  -0.99011135 -0.9715157
#  -0.9600313  -0.9557027  -0.98395264 -0.9942623  -0.9962148  -0.9959702
#  -0.99028826 -0.9955239  -0.9969753  -0.995406   -0.9903016  -0.9805315
#  -0.99524546 -0.944958   -0.98034304 -0.973683   -0.9956317  -0.9955868
#  -0.9950706  -0.99566436 -0.9953526  -0.99594617 -0.9732786  -0.9763913
#  -0.955711   -0.75768185 -0.48248708 -0.46537828 -0.7934197  -0.99682325
#  -0.9938129  -0.99099237 -0.9956142  -0.99536836 -0.9909964  -0.9895315
#  -0.9895239  -0.9677813  -0.9913556  -0.9967257  -0.9928032 ]

# %% [markdown]
# ### 7. Evaluasi Model LSTM-RNN

# %%
scores = model.evaluate(trainX, trainY)
scores
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0681 - mean_absolute_error: 0.0681 - mean_squared_error: 0.0345 - root_mean_squared_error: 0.1858
# [0.06805405765771866,
#  0.06805405765771866,
#  0.03453653305768967,
#  0.18584007024765015]

# %%
scores = model.evaluate(testX, testY)
scores
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0244 - mean_absolute_error: 0.0244 - mean_squared_error: 0.0049 - root_mean_squared_error: 0.0698
# [0.02439900115132332,
#  0.02439900115132332,
#  0.004873098339885473,
#  0.06980758160352707]

# %% [markdown]
# - MAE

# %%
mae = mean_absolute_error(testY, predictions)
print('Test MAE: %.4f' % mae)
# Out:
# Test MAE: 0.0244

# %% [markdown]
# - MSE

# %%
mse = mean_squared_error(testY, predictions)
print('Test MSE: %.4f' % mse)
# Out:
# Test MSE: 0.0049

# %% [markdown]
# - RMSE

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(testY , predictions))
print('Test RMSE: %.4f' % rmse)
# Out:
# Test RMSE: 0.0698

# %% [markdown]
# - MAPE

# %%
mape = mean_absolute_percentage_error(testY, predictions)
print('Test MAPE: %.4f' % mape)
# Out:
# Test MAPE: 0.0352

# %% [markdown]
# - sMAPE

# %%
smape = sMAPE(np.array(testY), np.array(predictions))
print('Test sMAPE: %.4f' % smape)
# Out:
# Test sMAPE: 0.0850

# %% [markdown]
# - korelasi dan signifikansi

# %%
hasil = np.stack((testY,predictions.reshape(-1)),axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0    -0.999723 -0.995489
# 1    -0.997503 -0.995477
# 2    -0.997364 -0.995322
# 3    -0.994450 -0.995741
# 4    -0.991537 -0.990111

# %%
import scipy.stats as sc
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.8077 dengan signifikansi 0.0000

# %% [markdown]
# - Waktu komputasi

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:03:05.36

# %% [markdown]
# ### 8. Visualisasi Hasil Prediksi

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testY, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(x, predictions, color="tab:red", label="hasil prediksi", linewidth=2.5)

# membuat label-label
# ax.set_title("Hotspot Sumsel Sensor MODIS 2018-2020", fontsize=14)
ax.set_xlabel("Tanggal", fontsize=12)
ax.set_ylabel("Jumlah Hostpot", fontsize=12)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### 9. Inverse Transform

# %%
df_sumsel = np.array(dataset["hotspot_sumsel"])

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
df_sumsel = scaler.fit_transform(df_sumsel.reshape(-1,1))

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)
testActual = scaler.inverse_transform(np.array(testY).reshape(-1, 1))

# %%
# generate urutan data sesuai panjang datanya
x = pd.date_range(start="2017-01-01", periods=len(testY), freq='MS')

# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(x, testActual, color="tab:blue", label="actual data", linewidth=2.5)
ax.plot(x, testPredictions, color="tab:red", label="prediction data", linewidth=2.5)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
#  shift test predictions for plotting
testPredictionsPlot = np.empty_like(df_sumsel)
testPredictionsPlot[:, :] = np.nan
testPredictionsPlot[(len(dataset) - testPredictions.shape[0]):len(dataset), :] = testPredictions

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(df_sumsel), color="tab:blue", label="actual data", linewidth=2)
ax.plot(dataset.index.values, testPredictionsPlot, color="tab:red", label="predictions data", linewidth=2)

# membuat label-label
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %%
temp_aktual = pd.DataFrame(scaler.inverse_transform(df_sumsel), columns=['Aktual'])
temp_prediksi = pd.DataFrame(testPredictionsPlot, columns=['Percobaan 2'])

# %%
hasil_percobaan_2 = pd.concat([temp_aktual, temp_prediksi], axis=1)

# %%
hasil_percobaan_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Aktual       240 non-null    float64
#  1   Percobaan 2  47 non-null     float64
# dtypes: float64(2)
# memory usage: 3.9 KB

# %%
hasil_percobaan_2.head()
# Out:
#    Aktual  Percobaan 2
# 0     3.0          NaN
# 1     5.0          NaN
# 2    10.0          NaN
# 3    20.0          NaN
# 4    39.0          NaN

# %%
hasil_percobaan_2.to_csv('hasil_percobaan_2.csv',index=False)
