# %% [markdown]
# ## How to Grid Search Hyperparameters for Deep Learning Models in Python with Keras

# %% [markdown]
# - https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier

# %%
# Function to create model, required for KerasClassifier
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(12, input_shape=(8,), activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
   
    # return model without compile
    
    # return values
    return model

# %%
# fix random seed for reproducibility
tf.random.set_seed(seed=1234)

# %%
# load dataset
dataset = np.loadtxt("dataset/diabetes.csv", delimiter=",")

# %%
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# show to dataset
pd.concat([
    pd.DataFrame(X, columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']),
    pd.DataFrame(Y, columns=['Y'])
], axis=1)
# Out:
#        x1     x2    x3    x4     x5    x6     x7    x8    Y
# 0     6.0  148.0  72.0  35.0    0.0  33.6  0.627  50.0  1.0
# 1     1.0   85.0  66.0  29.0    0.0  26.6  0.351  31.0  0.0
# 2     8.0  183.0  64.0   0.0    0.0  23.3  0.672  32.0  1.0
# 3     1.0   89.0  66.0  23.0   94.0  28.1  0.167  21.0  0.0
# 4     0.0  137.0  40.0  35.0  168.0  43.1  2.288  33.0  1.0
# ..    ...    ...   ...   ...    ...   ...    ...   ...  ...
# 763  10.0  101.0  76.0  48.0  180.0  32.9  0.171  63.0  0.0
# 764   2.0  122.0  70.0  27.0    0.0  36.8  0.340  27.0  0.0
# 765   5.0  121.0  72.0  23.0  112.0  26.2  0.245  30.0  0.0
# 766   1.0  126.0  60.0   0.0    0.0  30.1  0.349  47.0  1.0
# 767   1.0   93.0  70.0  31.0    0.0  30.4  0.315  23.0  0.0
#
# [768 rows x 9 columns]

# %%
# create model
model = KerasClassifier(model=create_model, loss="binary_crossentropy", epochs=100, batch_size=10, verbose=1)

# %%
model
# Out:
# KerasClassifier(
# 	model=<function create_model at 0x00000233CB524AF0>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=binary_crossentropy
# 	metrics=None
# 	batch_size=10
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=100
# 	class_weight=None
# )

# %%
# define the grid search parameters
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']

# %%
param_grid = dict(optimizer=optimizer)

# %%
param_grid
# Out:
# {'optimizer': ['SGD',
#   'RMSprop',
#   'Adagrad',
#   'Adadelta',
#   'Adam',
#   'Adamax',
#   'Nadam']}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
grid_result = grid.fit(X, Y)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 3ms/step - loss: 6.9319
# Epoch 2/100
# 77/77 [==============================] - 0s 2ms/step - loss: 3.2164
# Epoch 3/100
# 77/77 [==============================] - 0s 3ms/step - loss: 2.0853
# Epoch 4/100
# 77/77 [==============================] - 0s 3ms/step - loss: 1.3213
# Epoch 5/100
# 77/77 [==============================] - 0s 3ms/step - loss: 1.0035
# Epoch 6/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8745
# Epoch 7/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.8315
# Epoch 8/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8497
# Epoch 9/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8109
# Epoch 10/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.7622
# Epoch 11/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7534
# Epoch 12/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7386
# Epoch 13/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.7227
# Epoch 14/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7251
# Epoch 15/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7047
# Epoch 16/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7180
# Epoch 17/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6878
# Epoch 18/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7215
# Epoch 19/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6714
# Epoch 20/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6833
# Epoch 21/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6814
# Epoch 22/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6606
# Epoch 23/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6452
# Epoch 24/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6394
# Epoch 25/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6657
# Epoch 26/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6420
# Epoch 27/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.6951
# Epoch 28/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6427
# Epoch 29/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6221
# Epoch 30/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6354
# Epoch 31/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6309
# Epoch 32/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6569
# Epoch 33/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6481
# Epoch 34/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6451
# Epoch 35/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6365
# Epoch 36/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6446
# Epoch 37/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6028
# Epoch 38/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6374
# Epoch 39/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6680
# Epoch 40/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6256
# Epoch 41/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.6288
# Epoch 42/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6204
# Epoch 43/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5941
# Epoch 44/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6214
# Epoch 45/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5948
# Epoch 46/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6163
# Epoch 47/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6247
# Epoch 48/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6140
# Epoch 49/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5921
# Epoch 50/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6621
# Epoch 51/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5928
# Epoch 52/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5839
# Epoch 53/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6092
# Epoch 54/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5997
# Epoch 55/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5837
# Epoch 56/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5794
# Epoch 57/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5976
# Epoch 58/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5805
# Epoch 59/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5889
# Epoch 60/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6094
# Epoch 61/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5718
# Epoch 62/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5883
# Epoch 63/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5814
# Epoch 64/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5748
# Epoch 65/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5885
# Epoch 66/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5783
# Epoch 67/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5818
# Epoch 68/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6051
# Epoch 69/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6052
# Epoch 70/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5843
# Epoch 71/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5566
# Epoch 72/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5814
# Epoch 73/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5549
# Epoch 74/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5684
# Epoch 75/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5667
# Epoch 76/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6312
# Epoch 77/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5686
# Epoch 78/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5835
# Epoch 79/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5739
# Epoch 80/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5566
# Epoch 81/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5676
# Epoch 82/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5580
# Epoch 83/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5515
# Epoch 84/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5499
# Epoch 85/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6099
# Epoch 86/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5637
# Epoch 87/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5492
# Epoch 88/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5944
# Epoch 89/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5634
# Epoch 90/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5438
# Epoch 91/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5591
# Epoch 92/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5540
# Epoch 93/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5595
# Epoch 94/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5490
# Epoch 95/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5577
# Epoch 96/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5456
# Epoch 97/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6057
# Epoch 98/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5489
# Epoch 99/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5635
# Epoch 100/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5707

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.718750 using {'optimizer': 'Adam'}
# 0.651042 (0.001841) with: {'optimizer': 'SGD'}
# 0.638021 (0.041134) with: {'optimizer': 'RMSprop'}
# 0.570312 (0.019401) with: {'optimizer': 'Adagrad'}
# 0.588542 (0.065390) with: {'optimizer': 'Adadelta'}
# 0.718750 (0.003189) with: {'optimizer': 'Adam'}
# 0.657552 (0.015073) with: {'optimizer': 'Adamax'}
# 0.677083 (0.062608) with: {'optimizer': 'Nadam'}
